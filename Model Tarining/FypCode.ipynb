# %% [markdown]
# **Mount Google Drive where have data and csv**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install soundfile
import wave
import os
import librosa
import soundfile as sf
import pandas as pd
import numpy as np

key=[] #For Storing Name of Audio File
duration=[] # For Storing Duration of Audio File
text=[] # For Storing Transcription of Audio File
# Out:
# Collecting soundfile
#   Downloading https://files.pythonhosted.org/packages/eb/f2/3cbbbf3b96fb9fa91582c438b574cff3f45b29c772f94c400e2c99ef5db9/SoundFile-0.10.3.post1-py2.py3-none-any.whl
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile) (1.14.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile) (2.20)
# Installing collected packages: soundfile
# Successfully installed soundfile-0.10.3.post1

# %% [markdown]
# ***Created csv files of DataSet ***

# %%
# file = open('/content/drive/MyDrive/SpeakCV/CombinedData/Transcript.txt')
# data_=file.readlines()
# # for count,i in enumerate(data_):
# #     location='/content/drive/MyDrive/SpeakCV/SpecificData/'+str(count+1)+'.wav' #Original Files

# #     x,_ = librosa.load(location, sr=16000)
# #     sf.write('/content/drive/MyDrive/SpeakCV/CorrectedFiles/'+str(count+1)+'.wav', x, 16000) #Corrected files

# #     if (count%500==0):#to see progress
# #       print(count)
# #     else:
# #       print(count, end =", ")
# # file.close()
    


# for count,i in enumerate(data_):
#     location='/content/drive/MyDrive/SpeakCV/CombinedData/'+str(count+1)+'.wav'
#     audio = wave.open(location)
#     key.append(location)
#     text.append(i)
#     frames = audio.getnframes()
#     rate = audio.getframerate()
#     dur = frames / float(rate)
#     audio.close()
#     duration.append(dur)
#     print(count)
# file.close()

# %% [markdown]
# The shell below will generate csv file of rumi and csalt dataset and will split them in train,validate and test (60%,20%,20%) set which i shared through google drive (this may help in creatiion of more dataset)

# %%
# di = {'key':key,'duration':duration,'text':text}
# df = pd.DataFrame(di)
# df.to_csv("/content/drive/MyDrive/SpeakCV/CombinedDataFiles/Data.csv",index=False)
# train, validate, test = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])
# train.to_csv("/content/drive/MyDrive/SpeakCV/CombinedDataFiles/train_data.csv",index=False)
# validate.to_csv("/content/drive/MyDrive/SpeakCV/CombinedDataFiles/validate_data.csv",index=False)
# test.to_csv("/content/drive/MyDrive/SpeakCV/CombinedDataFiles/test_data.csv",index=False)

# %%
df
# Out:
#                                                     key  ...                                               text
# 0     /content/drive/MyDrive/SpeakCV/CombinedData/1.wav  ...               بسم اللہ الرحمن الرحیم اسلام علیکم\n
# 1     /content/drive/MyDrive/SpeakCV/CombinedData/2.wav  ...   ورچوئل یونیورسٹی اف پاکستان کے فاصلاتی سلسلہ ...
# 2     /content/drive/MyDrive/SpeakCV/CombinedData/3.wav  ...  کے افتتاحی لیکچر کے ساتھ میں ہوں فیصل کمال حید...
# 3     /content/drive/MyDrive/SpeakCV/CombinedData/4.wav  ...                            عزیز طلباء زندہ قومیں\n
# 4     /content/drive/MyDrive/SpeakCV/CombinedData/5.wav  ...      اپنے جداگانہ تشخص کی بنیاد پر زندہ رہا کرتی\n
# ...                                                 ...  ...                                                ...
# 9504  /content/drive/MyDrive/SpeakCV/CombinedData/95...  ...                                        چھیانوے\t\n
# 9505  /content/drive/MyDrive/SpeakCV/CombinedData/95...  ...                                         ستانوے\t\n
# 9506  /content/drive/MyDrive/SpeakCV/CombinedData/95...  ...                                        اٹھانوے\t\n
# 9507  /content/drive/MyDrive/SpeakCV/CombinedData/95...  ...                                         ننانوے\t\n
# 9508  /content/drive/MyDrive/SpeakCV/CombinedData/95...  ...                                                 سو
#
# [9509 rows x 3 columns]

# %% [markdown]
# when model reached at WER of 0.3 model wass suffering to train further on this data then i added test set into training set and generate a new csv file which now have 80% of data in training and 20% in validation set.

# %%
test="/content/drive/MyDrive/SpeakCV/CombinedDataFiles/test_data.csv"
train="/content/drive/MyDrive/SpeakCV/CombinedDataFiles/train_data.csv"
test_ = pd.read_csv(test)
train_ = pd.read_csv(train)
merge=pd.concat([train_,test_], ignore_index=True)
merge.to_csv("/content/drive/MyDrive/SpeakCV/CombinedDataFiles/traintest_data.csv", index=False)

# %% [markdown]
# ________________________________________________________________________________
#
#
# ># **Traing Code starts from here**

# %%
# !pip install pympler
# !pip install python_speech_features
# !pip install aubio
# !pip install kenlm
# !pip install soundfile
# !pip uninstall tensorflow tensorflow-gpu protocol --yes

# !pip install tensorflow-gpu==1.14.0

# !pip install keras==2.2.0
# Out:
# Collecting pympler
#   Downloading https://files.pythonhosted.org/packages/e8/e2/2f3a086701bb62b1c478a3921836271177838a3c98cdc6b82c3bb36d3854/Pympler-0.9.tar.gz (178kB)
#      |████████████████████████████████| 184kB 12.6MB/s
# Building wheels for collected packages: pympler
#   Building wheel for pympler (setup.py) ... done
#   Created wheel for pympler: filename=Pympler-0.9-cp36-none-any.whl size=164805 sha256=8c5ff19c7b6ab0ee98204ebb9d37d7f0e10be4476c5190c5374b2cbb899accca
#   Stored in directory: /root/.cache/pip/wheels/23/15/5a/90dd23b3ceffcf8463dc737fba4fad3e295d1da52622bbb74f
# Successfully built pympler
# Installing collected packages: pympler
# Successfully installed pympler-0.9
# Collecting python_speech_features
#   Downloading https://files.pythonhosted.org/packages/ff/d1/94c59e20a2631985fbd2124c45177abaa9e0a4eee8ba8a305aa26fc02a8e/python_speech_features-0.6.tar.gz
# Building wheels for collected packages: python-speech-features
#   Building wheel for python-speech-features (setup.py) ... done
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-cp36-none-any.whl size=5890 sha256=d0953789e4acdbd5c547f6a732bc0359f5cebc4d6599d123659e23a1172c2b95
#   Stored in directory: /root/.cache/pip/wheels/3c/42/7c/f60e9d1b40015cd69b213ad90f7c18a9264cd745b9888134be
# Successfully built python-speech-features
# Installing collected packages: python-speech-features
# Successfully installed python-speech-features-0.6
# Collecting aubio
#   Downloading https://files.pythonhosted.org/packages/cd/80/302d89240603e5347c7f8026c8b02c59f8dfaec66c91a743d82de7c86006/aubio-0.4.9.tar.gz (479kB)
#      |████████████████████████████████| 481kB 12.6MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from aubio) (1.19.4)
# Building wheels for collected packages: aubio
#   Building wheel for aubio (setup.py) ... done
#   Created wheel for aubio: filename=aubio-0.4.9-cp36-cp36m-linux_x86_64.whl size=386264 sha256=cdd894bd5f85a655c878079045572c66f6eb9d97a7d5a6528bedf9e64539860e
#   Stored in directory: /root/.cache/pip/wheels/ac/93/da/33a0041dff56d6c1faf82c83ff487cf669442b7087db20a995
# Successfully built aubio
# Installing collected packages: aubio
# Successfully installed aubio-0.4.9
# Collecting kenlm
#   Downloading https://files.pythonhosted.org/packages/57/54/0cc492b8d7aceb17a9164c6e6b9c9afc2c73706bb39324e8f6fa02f7134a/kenlm-0.tar.gz (1.4MB)
#      |████████████████████████████████| 1.5MB 13.1MB/s
# Building wheels for collected packages: kenlm
#   Building wheel for kenlm (setup.py) ... done
#   Created wheel for kenlm: filename=kenlm-0.0.0-cp36-cp36m-linux_x86_64.whl size=2276655 sha256=0833ccd7b8bec7cf8361f357592379a1da51fbef656ac6d4ae80905cd200252d
#   Stored in directory: /root/.cache/pip/wheels/e9/cf/f4/1a1aab56f87f4132667a7a47045a750384f19d646099ab4858
# Successfully built kenlm
# Installing collected packages: kenlm
# Successfully installed kenlm-0.0.0
# Requirement already satisfied: soundfile in /usr/local/lib/python3.6/dist-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile) (1.14.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile) (2.20)
# Uninstalling tensorflow-2.4.0:
#   Successfully uninstalled tensorflow-2.4.0
# WARNING: Skipping tensorflow-gpu as it is not installed.
# WARNING: Skipping protocol as it is not installed.
# Collecting tensorflow-gpu==1.14.0
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 45kB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.12.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 50.0MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.15.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.19.4)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.36.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (3.12.4)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.32.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.10.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 55.5MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.2.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.3.3)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 9.1MB/s
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (50.3.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.7.4.3)
# Installing collected packages: tensorboard, tensorflow-estimator, keras-applications, tensorflow-gpu
#   Found existing installation: tensorboard 2.4.0
#     Uninstalling tensorboard-2.4.0:
#       Successfully uninstalled tensorboard-2.4.0
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0
# Collecting keras==2.2.0
#   Downloading https://files.pythonhosted.org/packages/68/12/4cabc5c01451eb3b413d19ea151f36e33026fc0efb932bf51bcaf54acbf5/Keras-2.2.0-py2.py3-none-any.whl (300kB)
#      |████████████████████████████████| 307kB 13.3MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.0) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.0) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.0) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.0) (1.19.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.0) (3.13)
# Collecting keras-preprocessing==1.0.1
#   Downloading https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# Collecting keras-applications==1.0.2
#   Downloading https://files.pythonhosted.org/packages/e2/60/c557075e586e968d7a9c314aa38c236b37cb3ee6b37e8d57152b1a5e0b47/Keras_Applications-1.0.2-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 9.1MB/s
# ERROR: fancyimpute 0.4.3 requires tensorflow, which is not installed.
# ERROR: tensorflow-gpu 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.2 which is incompatible.
# ERROR: tensorflow-gpu 1.14.0 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# Installing collected packages: keras-preprocessing, keras-applications, keras
#   Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.0 keras-applications-1.0.2 keras-preprocessing-1.0.1

# %% [markdown]
# When all module are installed click this link:-
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py
# a file will appear, after line no. 4194 add this line:
# **ignore_longer_outputs_than_inputs=True,**

# %% [markdown]
# Declearation of our Urdu Vocablary

# %%
char_map_str = """
<SPACE> 0
ا 1
آ 2
ب 3
پ 4
ت 5
ٹ 6
ث 7
ج 8
چ 9
ح 10
خ 11
د 12
ڈ 13
ذ 14
ر 15
ڑ 16
ز 17
ژ 18
س 19
ش 20
ص 21
ض 22
ط 23
ظ 24
ع 25
غ 26
ف 27
ق 28
ک 29
گ 30
ل 31
م 32
ن 33
ں 34
و 35
ہ 36
ھ 37
38 ء
ئ 39
ی 40
ے  41
'

"""

char_map = {}
index_map = {}

for line in char_map_str.strip().split('\n')[0:-1]:
    try:
        ch, index = line.split()
    #     print('ch ',ch,' index ',index)
        char_map[ch.strip()] = int(index)
        index_map[int(index)] = ch.strip()
    except:
        # print('ch ',ch,' index ',index)
        char_map[index.strip()] = int(ch) 
        index_map[int(ch)] = index.strip()
       
#         break

index_map[0] = ' '

# %% [markdown]
# **This will read csv files of audio dataset and its transcription**

# %%
import fnmatch
import os
import pandas as pd
# import char_map
# from utils import text_to_int_sequence


#######################################################

def clean(word):
    # token = re.compile("[\w-]+|'m|'t|'ll|'ve|'d|'s|\'")
    ## LC ALL & strip fullstop, comma and semi-colon which are not required
    new = word.lower().replace('.', '')
    new = new.replace(',', '')
    new = new.replace(';', '')
    new = new.replace('"', '')
    new = new.replace('!', '')
    new = new.replace('?', '')
    new = new.replace(':', '')
    new = new.replace('-', '')
    return new


def combine_all_wavs_and_trans_from_csvs(csvslist, sortagrad=True, createwordlist=False, delBigTranscripts=True,start=-100,end=100):
    '''Assume that data is in csv already exists with data in form
        path, size, transcript
        this is best approach for loading in moz deepspeech processed files.
    '''

    df_all = pd.DataFrame()
  
    for csv in csvslist.split(','):
        print("Reading csv:",csv)

        if os.path.isfile(csv):
            try:
                df_new = pd.read_csv(csv, sep=',', encoding='ascii')
            except:
                print("NOT - ASCII, use UTF-8")
                df_new = pd.read_csv(csv, sep=',', encoding='utf-8')
                # df_new.text.replace({r'[^\x00-\x7F]+': ''}, regex=True, inplace=True)

            df_all = df_all.append(df_new)
    # df_all=df_all[0:100]
    print("Finished reading in data")

    if delBigTranscripts:
        print("removing any sentences that are too big- tweetsize")
        df_final = df_all[df_all['text'].map(len) <= 140]
    else:
        df_final = df_all

    # can output the word list here if required
    if createwordlist:
        df_final['text'].to_csv("./lm/df_all_word_list.csv", sep=',', header=False, index=False)  # reorder + out

    listcomb = df_all['text'].tolist()
    print("Total number of files:", len(listcomb))


    listcomb = df_final['text'].tolist()
    print("Total number of files (after reduction):", len(listcomb))

    comb = []

    for t in listcomb:
        #s = t.decode('utf-8').encode('ascii', errors='ignore')
        comb.append(' '.join(t.split()))

    # print("Train/Test/Valid:",len(train_list_wavs), len(test_list_wavs), len(valid_list_wavs))
    # 6300 TIMIT
    # (4620, 840, 840) TIMIT



    ## SIZE CHECKS
    max_intseq_length = get_max_intseq(comb)
    num_classes = get_number_of_char_classes()

    print("max_intseq_length:", max_intseq_length)
    print("numclasses:", num_classes)

    # VOCAB CHECKS
    all_words, max_trans_charlength = get_words(comb)
    print("max_trans_charlength:", max_trans_charlength)
    # ('max_trans_charlength:', 80)

    ## TODO could readd the mfcc checks for safety
    # ('max_mfcc_len:', 778, 'at comb index:', 541)

    all_vocab = set(all_words)
    print("Words:", len(all_words))
    print("Vocab:", len(all_vocab))

    dataproperties = {
        'target': "timit+librispeech",
        'num_classes': num_classes,
        'all_words': all_words,
        'all_vocab': all_vocab,
        'max_trans_charlength': max_trans_charlength,
        'max_intseq_length': max_intseq_length
    }

    if sortagrad:
        df_final = df_final.sort_values(by='duration', ascending=True)
    else:
        df_final = df_final.sample(frac=1).reset_index(drop=True)

    #remove mem
    del df_all
    del listcomb

    return dataproperties, df_final


##DATA CHECKS RUN ALL OF THESE

def get_words(comb):
    max_trans_charlength = 0
    all_words = []

    for count, sent in enumerate(comb):
        # count length
        if len(sent) > max_trans_charlength:
            max_trans_charlength = len(sent)
        # build vocab
        for w in sent.split():
            all_words.append(clean(w))

    return all_words, max_trans_charlength

def get_max_intseq(comb):
    max_intseq_length = 0
    for x in comb:
        try:
            y = text_to_int_sequence(x)
            if len(y) > max_intseq_length:
                max_intseq_length = len(y)
        except:
            print("error at:", x)
    return max_intseq_length

def get_number_of_char_classes():
    ## TODO would be better to check with dataset (once cleaned)
    num_classes = len(char_map)+1 ##need +1 for ctc null char +1 pad
    return num_classes

# %% [markdown]
# **Following functions will convert text to integer list ,integer list to text and load previous saved models.**

# %%
# from char_map import char_map, index_map


from pympler import muppy, summary, tracker, classtracker
from pympler.garbagegraph import GarbageGraph, start_debug_garbage
from pympler.web import start_profiler, start_in_background
import types

import resource
import tensorflow as tf
import keras
from keras.models import model_from_json, load_model
import keras.backend as K

import inspect
import re
import sys

import h5py
import yaml

# from model import clipped_relu, selu

# these text/int characters are modified
# from the DS2 github.com/baidu-research/ba-dls-deepspeech

def text_to_int_sequence(text):
    """ Use a character map and convert text to an integer sequence """
    int_sequence = []
    
    for c in text:

      append=True    
      if c == ' ':
          ch = char_map['<SPACE>']
      else:
          try:
              ch = char_map[c]
          except:
              append=False
      if append:
          int_sequence.append(ch)
    return int_sequence

def int_to_text_sequence(seq):
    """ Use a index map and convert int to a text sequence
        >>> from utils import int_to_text_sequence
        >>> a = [2,22,10,11,21,2,13,11,6,1,21,2,8,20,17]
        >>> b = int_to_text_sequence(a)
    """
    text_sequence = []
    for c in seq:
        if c == 42: #ctc/pad char
            ch = ''
        else:
            ch = index_map[c]
        text_sequence.append(ch)
    return text_sequence




def save_trimmed_model(model, name):

    jsonfilename = str(name) + ".json"
    weightsfilename = str(name) + ".h5"

    # # serialize model to JSON
    with open(jsonfilename, "w") as json_file:
        json_file.write(model.to_json())

    # # serialize weights to HDF5
    model.save_weights(weightsfilename)

    return

def save_model(model, name):

    if name:
        jsonfilename = str(name) + "/model.json"
        weightsfilename = str(name) + "/model.h5"

        # # serialize model to JSON
        with open(jsonfilename, "w") as json_file:
            json_file.write(model.to_json())

        print("Saving model at:", jsonfilename, weightsfilename)
        model.save_weights(weightsfilename)

        #save model as combined in single file - contrains arch/weights/config/state
        model.save(str(name)+"/cmodel.h5")

    return

def load_model_checkpoint(path, summary=True):

   
    from keras.utils.generic_utils import get_custom_objects
    # get_custom_objects().update({"tf": tf})
    get_custom_objects().update({"clipped_relu": clipped_relu})
    get_custom_objects().update({"selu": selu})
    # get_custom_objects().update({"TF_NewStatus": None})

    jsonfilename = path+".json"
    weightsfilename = path+".h5"

    json_file = open(jsonfilename, 'r')
    loaded_model_json = json_file.read()
    json_file.close()

    K.set_learning_phase(1)
    loaded_model = model_from_json(loaded_model_json)

    # load weights into loaded model
    loaded_model.load_weights(weightsfilename)
    # loaded_model = load_model(path, custom_objects=custom_objects)


    if(summary):
        loaded_model.summary()

    return loaded_model

def load_cmodel_checkpoint(path, summary=True):

    
    from keras.utils.generic_utils import get_custom_objects
    # get_custom_objects().update({"tf": tf})
    get_custom_objects().update({"clipped_relu": clipped_relu})
    get_custom_objects().update({"selu": selu})
    # get_custom_objects().update({"TF_NewStatus": None})

    cfilename = path+".h5"

    K.set_learning_phase(1)
    loaded_model = load_model(cfilename)


    if(summary):
        loaded_model.summary()

    return loaded_model


memlist = []
class MemoryCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, log={}):
        x = resource.getrusage(resource.RUSAGE_SELF).ru_maxrss
        web_browser_debug = True
        print(x)

        if x > 40000:
            if web_browser_debug:
                if epoch==0:
                    start_in_background()
                    tr = tracker.SummaryTracker()
                    tr.print_diff()
            else:
                global memlist
                all_objects = muppy.get_objects(include_frames=True)
                # print(len(all_objects))
                sum1 = summary.summarize(all_objects)
                memlist.append(sum1)
                summary.print_(sum1)
                if len(memlist) > 1:
                    # compare with last - prints the difference per epoch
                    diff = summary.get_diff(memlist[-2], memlist[-1])
                    summary.print_(diff)
                my_types = muppy.filter(all_objects, Type=types.ClassType)

                for t in my_types:
                    print(t)


    #########################################################
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# **Some import and ctc loss**

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
import keras.backend as K
from keras.models import Model
from keras.layers import Input
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Lambda
from keras.layers import Dropout
from keras.regularizers import l2
from keras.initializers import random_normal
from keras.utils.conv_utils import conv_output_length
from keras.layers import GaussianNoise

'''
This file builds the models


'''

import numpy as np

from keras import backend as K
from keras.models import Model, Sequential
from keras.layers.recurrent import SimpleRNN
from keras.layers import Dense, Activation, Bidirectional, Reshape,Flatten, Lambda, Input,\
    Masking, Convolution1D, BatchNormalization, GRU, Conv1D, RepeatVector, Conv2D,LSTM
from keras.optimizers import SGD, Adam
from keras.layers import ZeroPadding1D, Convolution1D, ZeroPadding2D, Convolution2D, MaxPooling2D, GlobalMaxPooling2D
from keras.layers import TimeDistributed, Dropout
from keras.layers.merge import add  # , # concatenate BAD FOR COREML
from keras.utils.conv_utils import conv_output_length
from keras.activations import relu

import tensorflow as tf

def selu(x):
    # from Keras 2.0.6 - does not exist in 2.0.4
    """Scaled Exponential Linear Unit. (Klambauer et al., 2017)
    # Arguments
       x: A tensor or variable to compute the activation function for.
    # References
       - [Self-Normalizing Neural Networks](https://arxiv.org/abs/1706.02515)
    """
    alpha = 1.6732632423543772848170429916717
    scale = 1.0507009873554804934193349852946
    return scale * K.elu(x, alpha)

def clipped_relu(x):
    return relu(x, max_value=20)

# Define CTC loss
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    
    # hack for load_model
    import tensorflow as tf

    ''' from TF: Input requirements
    1. sequence_length(b) <= time for all b
    2. max(labels.indices(labels.indices[:, 1] == b, 2)) <= sequence_length(b) for all b.
    '''

    # print("CTC lambda inputs / shape")
    # print("y_pred:",y_pred.shape)  # (?, 778, 30)
    # print("labels:",labels.shape)  # (?, 80)
    # print("input_length:",input_length.shape)  # (?, 1)
    # print("label_length:",label_length.shape)  # (?, 1)


    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)


def ctc(y_true, y_pred):
    return y_pred

# %% [markdown]
# **Batch Generator and feature collection of batch**

# %%
import numpy as np
from numpy.lib.stride_tricks import as_strided
from sklearn.utils import shuffle

import python_speech_features as p
import scipy.io.wavfile as wav
import soundfile
import scipy
# from aubio import source, pvoc, mfcc
from numpy import vstack, zeros, diff




from keras.preprocessing.sequence import pad_sequences

# from utils import text_to_int_sequence

# Data batch generator, responsible for providing the data to fit_generator

class BatchGenerator(object):
    def __init__(self, dataframe, dataproperties, training, batch_size=16, model_input_type="mfcc"):
        self.training_data = training
        self.model_input_type = model_input_type ##mfcc, mfcc-aubio, spectrogram, spectrogram-img
        # self.aubio = False
        self.df = dataframe.copy()
        #['wav_filesize','transcript','wav_filename']
        self.wavpath = self.df['key'].tolist()
        self.transcript = self.df['text'].tolist()
        self.finish = self.df['duration'].tolist()
        self.start = np.zeros(len(self.finish))
        self.length = self.finish
        self.shuffling = True

        self.batch_size = batch_size
        self.cur_index = 0

        self.feats_std = 0
        self.feats_mean = 0

        self.set_of_all_int_outputs_used = None

        #Free up memory of unneeded data
        del dataframe
        del dataproperties
        self.df = None
        del self.df

    def normalise(self, feature, eps=1e-14):
        return (feature - self.feats_mean) / (self.feats_std + eps)

    def get_batch(self, idx):

        batch_x = self.wavpath[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y_trans = self.transcript[idx * self.batch_size:(idx + 1) * self.batch_size]

        try:
            assert (len(batch_x) == self.batch_size)
            assert (len(batch_y_trans) == self.batch_size)
        except Exception as e:
            print(e)
            print(batch_x)
            print(batch_y_trans)

        # 1. X_data (the MFCC's for the batch)
        if(self.model_input_type == "spectrogram"):
            # 0. get the maximum time length of the batch
            x_val = [get_max_specto_time(file_name) for file_name in batch_x]
            max_val = max(x_val)
            # print("Max batch time value is:", max_val)
            X_data = np.array([make_specto_shape(file_name, padlen=max_val) for file_name in batch_x])
            assert (X_data.shape == (self.batch_size, max_val, 161))

        elif(self.model_input_type == "mfcc-aubio"):
            x_val = [get_max_aubio(file_name) for file_name in batch_x]
            max_val = max(x_val)
            # print("Max batch time value is:", max_val)
            X_data = np.array([make_aubio_shape(file_name, padlen=max_val) for file_name in batch_x])
            # print(X_data.shape)
            assert (X_data.shape == (self.batch_size, max_val, 26))

        elif(self.model_input_type == "mfcc"):
            # 0. get the maximum time length of the batch
            x_val = [get_max_time(file_name) for file_name in batch_x]
            max_val = max(x_val)
            # print("Max batch time value is:", max_val)

            X_data = np.array([make_mfcc_shape(file_name, padlen=max_val) for file_name in batch_x])
            assert (X_data.shape == (self.batch_size, max_val, 26))
        # print("1. X_data shape:", X_data.shape)
        # print("1. X_data:", X_data)


        # 2. labels (made numerical)
        # get max label length
        y_val = [get_maxseq_len(l) for l in batch_y_trans]
        # print(y_val)
        max_y = max(y_val)
        # print(max_y)
        labels = np.array([get_intseq(l, max_intseq_length=max_y) for l in batch_y_trans])
        # print("2. labels shape:", labels.shape)
        # print("2. labels values=", labels)
        assert(labels.shape == (self.batch_size, max_y))

        # 3. input_length (required for CTC loss)
        # this is the time dimension of CTC (batch x time x mfcc)
        #input_length = np.array([get_xsize(mfcc) for mfcc in X_data])
        input_length = np.array(x_val)
        # print("3. input_length shape:", input_length.shape)
        # print("3. input_length =", input_length)
        assert(input_length.shape == (self.batch_size,))

        # 4. label_length (required for CTC loss)
        # this is the length of the number of label of a sequence
        #label_length = np.array([len(l) for l in labels])
        label_length = np.array(y_val)
        # print("4. label_length shape:", label_length.shape)
        # print("4. label_length =", label_length)
        assert(label_length.shape == (self.batch_size,))

        # 5. source_str (used for human readable output on callback)
        source_str = np.array([l for l in batch_y_trans])



        inputs = {
            'the_input': X_data,
            'the_labels': labels,
            'input_length': input_length,
            'label_length': label_length,
            'source_str': source_str
        }

        outputs = {'ctc': np.zeros([self.batch_size])}

        return (inputs, outputs)

    def next_batch(self):
        while 1:
            assert (self.batch_size <= len(self.wavpath))

            if (self.cur_index + 1) * self.batch_size >= len(self.wavpath) - self.batch_size:

                self.cur_index = 0

                if(self.shuffling==True):
                    print("SHUFFLING as reached end of data")
                    self.genshuffle()

            try:
                ret = self.get_batch(self.cur_index)
            except:
                print("data error - this shouldn't happen - try next batch")
                self.cur_index += 1
                ret = self.get_batch(self.cur_index)

            self.cur_index += 1

            yield ret

    def genshuffle(self):
        self.wavpath, self.transcript, self.finish = shuffle(self.wavpath,
                                                             self.transcript,
                                                             self.finish)


    def export_test_mfcc(self):
        # this is used to export data e.g. into iOS

        testset = next(self.next_batch())[0]
        mfcc = testset['the_input'][0:self.batch_size]  ## export all mfcc's in batch #26 x 29 ?
        words = testset['source_str'][0:self.batch_size]
        labels = testset['the_labels'][0:self.batch_size]

        print("exporting:", type(mfcc))
        print(mfcc.shape)
        print(words.shape)
        print(labels.shape)

        # we save each mfcc/words/label as it's own csv file
        for i in range(0, mfcc.shape[0]):
            np.savetxt('./Archive/test_spectro/test_spectro_{}.csv'.format(i), mfcc[i, :, :], delimiter=',')

        print(words)
        print(labels)

        return



def get_normalise(self, k_samples=100):
    # todo use normalise from DS2 - https://github.com/baidu-research/ba-dls-deepspeech
    """ Estimate the mean and std of the features from the training set
    Params:
        k_samples (int): Use this number of samples for estimation
    """
    # k_samples = min(k_samples, len(self.train_audio_paths))
    # samples = self.rng.sample(self.train_audio_paths, k_samples)
    # feats = [self.featurize(s) for s in samples]
    # feats = np.vstack(feats)
    # self.feats_mean = np.mean(feats, axis=0)
    # self.feats_std = np.std(feats, axis=0)
    pass

def get_maxseq_len(trans):
    # PAD
    t = text_to_int_sequence(trans)
    return len(t)

def get_intseq(trans, max_intseq_length=80):
    # PAD
    t = text_to_int_sequence(trans)
    while (len(t) < max_intseq_length):
        t.append(27)  # replace with a space char to pad
    # print(t)
    return t

def get_max_time(filename):
    fs, audio = wav.read(filename)
    r = p.mfcc(audio, samplerate=fs, numcep=26)  # 2D array -> timesamples x mfcc_features
    # print(r.shape)
    return r.shape[0]  #

def get_max_specto_time(filename):
    r = spectrogram_from_file(filename)
    # print(r.shape)
    return r.shape[0]  #


def get_max_aubio(filename):
    r = aubio(filename)  # 2D array -> timesamples x mfcc_features
    # print(r.shape)

    return r.shape[0]  #

def make_specto_shape(filename, padlen=778):
    r = spectrogram_from_file(filename)
    t = np.transpose(r)  # 2D array ->  spec x timesamples
    X = pad_sequences(t, maxlen=padlen, dtype='float', padding='post', truncating='post').T

    return X  # MAXtimesamples x specto {max x 161}

def make_aubio_shape(filename, padlen=778):
    r = aubio(filename)
    t = np.transpose(r)  # 2D array ->  mfcc_features x timesamples
    X = pad_sequences(t, maxlen=padlen, dtype='float', padding='post', truncating='post').T
    return X  # 2D array -> MAXtimesamples x mfcc_features {778 x 26}

def make_mfcc_shape(filename, padlen=778):
    fs, audio = wav.read(filename)
    r = p.mfcc(audio, samplerate=fs, numcep=26)  # 2D array -> timesamples x mfcc_features
    t = np.transpose(r)  # 2D array ->  mfcc_features x timesamples
    X = pad_sequences(t, maxlen=padlen, dtype='float', padding='post', truncating='post').T
    return X  # 2D array -> MAXtimesamples x mfcc_features {778 x 26}

def get_xsize(val):
    return val.shape[0]

def shuffle_data(self):
    self.wavpath, self.transcript, self.finish = shuffle(self.wavpath,
                                                         self.transcript,
                                                         self.finish)
    return


def aubio(source_filename):

    # print("Usage: %s <source_filename> [samplerate] [win_s] [hop_s] [mode]" % sys.argv[0])
    # print("  where [mode] can be 'delta' or 'ddelta' for first and second derivatives")7

    n_filters = 40  # must be 40 for mfcc
    n_coeffs = 26
    win_s = 512
    hop_s = win_s // 4
    # mode = "default"
    samplerate = 0

    s = source(source_filename, samplerate, hop_s)
    samplerate = s.samplerate
    p = pvoc(win_s, hop_s)
    m = mfcc(win_s, n_filters, n_coeffs, samplerate)

    mfccs = zeros([n_coeffs, ])
    frames_read = 0
    while True:
        samples, read = s()
        spec = p(samples)
        mfcc_out = m(spec)
        mfccs = vstack((mfccs, mfcc_out))
        frames_read += read
        if read < hop_s: break

    return mfccs

##Require for DS2 - source: https://github.com/baidu-research/ba-dls-deepspeech
##############################################################################

def spectrogram(samples, fft_length=256, sample_rate=2, hop_length=128):
    """
    Compute the spectrogram for a real signal.
    The parameters follow the naming convention of
    matplotlib.mlab.specgram

    Args:
        samples (1D array): input audio signal
        fft_length (int): number of elements in fft window
        sample_rate (scalar): sample rate
        hop_length (int): hop length (relative offset between neighboring
            fft windows).

    Returns:
        x (2D array): spectrogram [frequency x time]
        freq (1D array): frequency of each row in x

    Note:
        This is a truncating computation e.g. if fft_length=10,
        hop_length=5 and the signal has 23 elements, then the
        last 3 elements will be truncated.
    """
    assert not np.iscomplexobj(samples), "Must not pass in complex numbers"

    window = np.hanning(fft_length)[:, None]
    window_norm = np.sum(window**2)

    # The scaling below follows the convention of
    # matplotlib.mlab.specgram which is the same as
    # matlabs specgram.
    scale = window_norm * sample_rate

    trunc = (len(samples) - fft_length) % hop_length
    x = samples[:len(samples) - trunc]

    # "stride trick" reshape to include overlap
    nshape = (fft_length, (len(x) - fft_length) // hop_length + 1)
    nstrides = (x.strides[0], x.strides[0] * hop_length)
    x = as_strided(x, shape=nshape, strides=nstrides)

    # window stride sanity check
    assert np.all(x[:, 1] == samples[hop_length:(hop_length + fft_length)])

    # broadcast window, compute fft over columns and square mod
    x = np.fft.rfft(x * window, axis=0)
    x = np.absolute(x)**2

    # scale, 2.0 for everything except dc and fft_length/2
    x[1:-1, :] *= (2.0 / scale)
    x[(0, -1), :] /= scale

    freqs = float(sample_rate) / fft_length * np.arange(x.shape[0])

    return x, freqs


def spectrogram_from_file(filename, step=10, window=20, max_freq=None,
                          eps=1e-14):
    """ Calculate the log of linear spectrogram from FFT energy
    Params:
        filename (str): Path to the audio file
        step (int): Step size in milliseconds between windows
        window (int): FFT window size in milliseconds
        max_freq (int): Only FFT bins corresponding to frequencies between
            [0, max_freq] are returned
        eps (float): Small value to ensure numerical stability (for ln(x))
    """
    with soundfile.SoundFile(filename) as sound_file:
        audio = sound_file.read(dtype='float32')
        sample_rate = sound_file.samplerate
        if audio.ndim >= 2:
            audio = np.mean(audio, 1)
        if max_freq is None:
            max_freq = sample_rate / 2
        if max_freq > sample_rate / 2:
            raise ValueError("max_freq must not be greater than half of "
                             " sample rate")
        if step > window:
            raise ValueError("step size must not be greater than window size")
        hop_length = int(0.001 * step * sample_rate)
        fft_length = int(0.001 * window * sample_rate)
        pxx, freqs = spectrogram(
            audio, fft_length=fft_length, sample_rate=sample_rate,
            hop_length=hop_length)
        ind = np.where(freqs <= max_freq)[0][-1] + 1
    return np.transpose(np.log(pxx[:ind, :] + eps))

def featurise(audio_clip):
    """ For a given audio clip, calculate the log of its Fourier Transform
    Params:
        audio_clip(str): Path to the audio clip
    """

    step = 10
    window = 20
    max_freq = 8000

    return spectrogram_from_file(
        audio_clip, step=step, window=window,
        max_freq=max_freq)

# %% [markdown]
# **Functions to calculate WER, LER and to correct predicted transcript from KenLM language model**

# %%
# this file is an adaptation from the work at mozilla deepspeech github.com/mozilla/DeepSpeech


import kenlm
import re
from heapq import heapify

def wer(original, result):
    r"""
    The WER is defined as the editing/Levenshtein distance on word level
    divided by the amount of words in the original text.
    In case of the original having more words (N) than the result and both
    being totally different (all N words resulting in 1 edit operation each),
    the WER will always be 1 (N / N = 1).
    """
    # The WER ist calculated on word (and NOT on character) level.
    # Therefore we split the strings into words first:
    original = original.split()
    result = result.split()
    return levenshtein(original, result) / float(len(original))

def wers(originals, results):
    count = len(originals)
    try:
        assert count > 0
    except:
        print(originals)
        raise("ERROR assert count>0 - looks like data is missing")
    rates = []
    mean = 0.0
    assert count == len(results)
    for i in range(count):
        rate = wer(originals[i], results[i])
        mean = mean + rate
        rates.append(rate)
    return rates, mean / float(count)

def lers(originals, results):
    count = len(originals)
    assert count > 0
    rates = []
    norm_rates = []

    mean = 0.0
    norm_mean = 0.0

    assert count == len(results)
    for i in range(count):
        rate = levenshtein(originals[i], results[i])
        mean = mean + rate

        normrate = (float(rate) / len(originals[i]))

        norm_mean = norm_mean + normrate

        rates.append(rate)
        norm_rates.append(round(normrate, 4))

    return rates, (mean / float(count)), norm_rates, (norm_mean/float(count))


# The following code is from: http://hetland.org/coding/python/levenshtein.py
def levenshtein(a,b):
    "Calculates the Levenshtein distance between a and b."
    n, m = len(a), len(b)
    if n > m:
        # Make sure n <= m, to use O(min(n,m)) space
        a,b = b,a
        n,m = m,n

    current = list(range(n+1))
    for i in range(1,m+1):
        previous, current = current, [i]+[0]*n
        for j in range(1,n+1):
            add, delete = previous[j]+1, current[j-1]+1
            change = previous[j-1]
            if a[j-1] != b[i-1]:
                change = change + 1
            current[j] = min(add, delete, change)

    return current[n]



# Lazy-load language model (TED corpus, Kneser-Ney, 4-gram, 30k word LM)
def get_model():
    global MODEL
    if MODEL is None:
        #MODEL = kenlm.Model('./lm/timit-lm.klm')
        MODEL = kenlm.Model('/content/drive/My Drive/SpeakCV/CombinedData/text.arpa')
    return MODEL


def words(text):
    "List of words in text."
    return re.findall(r'\w+', text.lower())


def log_probability(sentence):
    "Log base 10 probability of `sentence`, a list of words"
    return get_model().score(' '.join(sentence), bos=False, eos=False)


def correction(sentence):
    "Most probable spelling correction for sentence."
    BEAM_WIDTH = 1024
    layer = [(0, [])]
    for word in words(sentence):
        layer = [(-log_probability(node + [cword]), node + [cword]) for cword in candidate_words(word) for
                 priority, node in layer]
        heapify(layer)
        layer = layer[:BEAM_WIDTH]
    return ' '.join(layer[0][1])


def candidate_words(word):
    "Generate possible spelling corrections for word."
    return (known_words([word]) or known_words(edits1(word)) or known_words(edits2(word)) or [word])


def known_words(words):
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)


def edits1(word):
    "All edits that are one edit away from `word`."
    letters = "".join(list(char_map.keys())[1:])
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [L + R[1:] for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
    inserts = [L + c + R for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)


def edits2(word):
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# globals

MODEL = None
# Load known word set
with open('/content/drive/MyDrive/SpeakCV/CombinedData/Transcript.txt') as f:
    WORDS = set(words(f.read()))

# %% [markdown]
# Call after every epoch to calculate WER from validation set

# %%
from keras import callbacks
# from text import *

import itertools
import numpy as np
import os
import socket
import sys
import keras.backend as K

# from utils import save_model, int_to_text_sequence

class ReportCallback(callbacks.Callback):
    def __init__(self, test_func, validdata, model, runtimestr, save):
        self.test_func = test_func

        self.validdata = validdata
        self.validdata_next_val = self.validdata.next_batch()
        self.batch_size = validdata.batch_size
        self.save = save

        # useful if you want to decrease amount in validation
        self.valid_test_devide = 1  # 1=no reduce, 10 = 1/10th
        #if socket.gethostname().lower() in 'rs-e5550'.lower(): self.valid_test_devide = 50

        self.val_best_mean_ed = 0
        self.val_best_norm_mean_ed = 0

        self.lm = get_model()

        self.model = model
        self.runtimestr = runtimestr

        self.mean_wer_log = []
        self.mean_ler_log = []
        self.norm_mean_ler_log = []

        self.earlystopping = True
        self.shuffle_epoch_end = True
        self.force_output = False

    def validate_epoch_end(self, verbose=0):

        originals = []
        results = []
        count = 0
        self.validdata.cur_index = 0  # reset index

        if self.valid_test_devide: #check not zero
            allvalid = (len(self.validdata.wavpath) // self.validdata.batch_size) // self.valid_test_devide


        #make a pass through all the validation data and assess score
        for c in range(0, allvalid):

            word_batch = next(self.validdata_next_val)[0]
            decoded_res = decode_batch(self.test_func,
                                       word_batch['the_input'][0:self.batch_size],
                                       self.batch_size)

            for j in range(0, self.batch_size):
                # print(c,j)
                count += 1
                decode_sent = decoded_res[j]
                corrected = correction(decode_sent)
                label = word_batch['source_str'][j]
                #print(label)

                if verbose:
                    cor_wer = wer(label, corrected)
                    dec_wer = wer(label, decode_sent)

                    if(dec_wer < 0.4 or cor_wer < 0.4 or self.force_output):
                        print("\n{}.GroundTruth:{}\n{}.Transcribed:{}\n{}.LMCorrected:{}".format(str(j), label,
                                                                                     str(j), decode_sent,
                                                                                     str(j), corrected))

                    # print("Sample Decoded WER:{}, Corrected LM WER:{}".format(dec_wer, cor_wer))

                originals.append(label)
                results.append(corrected)

        print("########################################################")
        print("Completed Validation Test: WER & LER results")
        rates, mean = wers(originals, results)
        # print("WER rates     :", rates)
        lrates, lmean, norm_lrates, norm_lmean = lers(originals, results)
        # print("LER rates     :", lrates)
        # print("LER norm rates:", norm_lrates)
        # print("########################################################")
        print("Test WER average is   :", mean)
        print("Test LER average is   :", lmean)
        print("Test normalised LER is:", norm_lmean)
        print("########################################################")
        # print("(note both WER and LER use LanguageModel not raw output)")

        self.mean_wer_log.append(mean)
        self.mean_ler_log.append(lmean)
        self.norm_mean_ler_log.append(norm_lmean)

        #delete all values?
        # del originals, results, count, allvalid
        # del word_batch, decoded_res
        # del decode_sent,


    def on_epoch_end(self, epoch, logs=None):
        K.set_learning_phase(0)

        if(self.shuffle_epoch_end):
            print("shuffle_epoch_end")
            self.validdata.genshuffle()


        self.validate_epoch_end(verbose=1)

        if self.save:
            #check to see lowest wer/ler on prev values
            # if(len(self.mean_wer_log)>=2):
            #     lastWER = self.mean_wer_log[-1]
            #     allWER = np.min(self.mean_wer_log[:-1])
            #     lastLER = self.mean_ler_log[-1]
            #     allLER = np.min(self.mean_ler_log[:-1])

                # if(lastLER < allLER or lastWER < allWER):
            savedir = "/content/drive/My Drive/SpeakCV/CombinedDataModels/epochs/LER-WER-best-{}".format(self.runtimestr+'-'+str(round(self.mean_wer_log[-1],2)))
            print("better ler/wer at:", savedir)
            if not os.path.isdir(savedir):
                os.makedirs(savedir)
            try:
                save_model(self.model, name=savedir)
            except Exception as e:
                print("couldn't save error:", e)

            #early stopping if VAL WER worse 4 times in a row
            if(len(self.mean_wer_log)>10 and self.earlystopping):
                if(earlyStopCheck(self.mean_wer_log[-10:])):
                    print("EARLY STOPPING")

                    print("Mean WER   :", self.mean_wer_log)
                    print("Mean LER   :", self.mean_ler_log)
                    print("NormMeanLER:", self.norm_mean_ler_log)

                    sys.exit()


        #activate learning phase - incase keras doesn't
        K.set_learning_phase(1)


def decode_batch(test_func, word_batch, batch_size):
    ret = []
    output = test_func([word_batch])[0] #16xTIMEx29 = batch x time x classes
    greedy = True
    merge_chars = True

    for j in range(batch_size):  # 0:batch_size

        if greedy:
            out = output[j]
            best = list(np.argmax(out, axis=1))

            if merge_chars:
                merge = [k for k,g in itertools.groupby(best)]

            else:
                raise ("not implemented no merge")

        else:
            pass
            raise("not implemented beam")

        try:
            outStr = int_to_text_sequence(merge)
            # print("outStr ",outStr)

        except Exception as e:
            print("Unrecognised character on decode error:", e)
            outStr = "DECODE ERROR:"+str(best)
            raise("DECODE ERROR2")

        ret.append(''.join(outStr))

    return ret

def earlyStopCheck(array):
    last = array[-1]
    rest = array[:-1]
    print(last, " vs ", rest)

    #in other words- the last element is bigger than all 4 of the previous, therefore early stopping required
    if all(i <= last for i in rest):
        return True
    else:
        return False

# %%
import argparse
import datetime
import os
import socket

import keras
from keras.callbacks import TensorBoard
from keras.optimizers import Adam, Nadam

# from data import combine_all_wavs_and_trans_from_csvs
# from generator import BatchGenerator
# from model import *
# from report import ReportCallback
# from utils import load_model_checkpoint, save_model, MemoryCallback

#####################################################


#######################################################

# Prevent pool_allocator message
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
train_files="/content/drive/MyDrive/SpeakCV/CombinedDataFiles/traintest_data.csv"
valid_files="/content/drive/MyDrive/SpeakCV/CombinedDataFiles/validate_data.csv"
train_dataprops, df_train = combine_all_wavs_and_trans_from_csvs(train_files, sortagrad=True,start=-100,delBigTranscripts=True)
valid_dataprops, df_valid = combine_all_wavs_and_trans_from_csvs(valid_files, sortagrad=True,start=-100,delBigTranscripts=True)

model_arch=2
# check any special data model requirments e.g. a spectrogram
if(model_arch == 1):
    model_input_type = "mfcc"
elif(model_arch == 2 or args.model_arch == 5):
    print("Spectrogram required")
    # spectrogram = True
    model_input_type = "spectrogram"
else:
    model_input_type = "mfcc"


## 2. init data generators
print("Creating data batch generators")
batchsize=16
traindata = BatchGenerator(dataframe=df_train, dataproperties=train_dataprops,
                          training=True, batch_size=batchsize, model_input_type=model_input_type)
validdata = BatchGenerator(dataframe=df_valid, dataproperties=valid_dataprops,
                          training=False, batch_size=batchsize, model_input_type=model_input_type)
# Out:
# Reading csv: /content/drive/MyDrive/SpeakCV/CombinedDataFiles/traintest_data.csv
# NOT - ASCII, use UTF-8
# Finished reading in data
# removing any sentences that are too big- tweetsize
# Total number of files: 7607
# Total number of files (after reduction): 7280
# max_intseq_length: 138
# numclasses: 43
# max_trans_charlength: 138
# Words: 34407
# Vocab: 2994
# Reading csv: /content/drive/MyDrive/SpeakCV/CombinedDataFiles/validate_data.csv
# NOT - ASCII, use UTF-8
# Finished reading in data
# removing any sentences that are too big- tweetsize
# Total number of files: 1902
# Total number of files (after reduction): 1808
# max_intseq_length: 137
# numclasses: 43
# max_trans_charlength: 137
# Words: 8296
# Vocab: 1374
# Spectrogram required
# Creating data batch generators

# %% [markdown]
#  **Our Model**

# %%
# def cnn_output_length(input_length, filter_size, border_mode, stride, dilation=1):
#     """ Compute the length of the output sequence after 1D convolution along
#         time. Note that this function is in line with the function used in
#         Convolution1D class from Keras.
#     Params:
#         input_length (int): Length of the input sequence.
#         filter_size (int): Width of the convolution kernel.
#         border_mode (str): `same`, `valid`, `causal`.
#         stride (int): Stride size used in 1D convolution.
#         dilation (int)
#     """
#     if input_length is None:
#         return None
#     assert border_mode in {'same', 'valid', 'causal'}
#     if border_mode == 'same' or border_mode == 'valid': dilation = 1
#     dilated_filter_size = filter_size + (filter_size - 1) * (dilation - 1)
#     if border_mode == 'same':
#         output_length = input_length
#     elif border_mode == 'valid' or border_mode == 'causal':
#         output_length = input_length - dilated_filter_size + 1
#     return (output_length + stride - 1) // stride
def ds2_gru_model(input_dim=161, fc_size=1024, rnn_size=512, output_dim=29, initialization='glorot_uniform',
                  conv_layers=1, gru_layers=2, use_conv=False):
    """ DeepSpeech 2 implementation

    Architecture:
        Input Spectrogram TIMEx161
        1 Batch Normalisation layer on input
        1-3 Convolutional Layers
        1 Batch Normalisation layer
        1-7 BiDirectional GRU Layers
        1 Batch Normalisation layer
        1 Fully connected Dense
        1 Softmax output

    Details:
       - Uses Spectrogram as input rather than MFCC
       - Did not use BN on the first input
       - Network does not dynamically adapt to maximum audio size in the first convolutional layer. Max conv
          length padded at 2048 chars, otherwise use_conv=False

    Reference:
        https://arxiv.org/abs/1512.02595
    """

    K.set_learning_phase(1)

    input_data = Input(shape=(None, input_dim), name='the_input')
    x = BatchNormalization(axis=-1, momentum=0.99, epsilon=1e-3, center=True, scale=True)(input_data)

    if use_conv:
        x = ZeroPadding1D(padding=(0, 2048))(x)
        for l in range(conv_layers):
            x = Conv1D(filters=fc_size[l], name='conv_{}'.format(l+1), kernel_size=11, padding='valid', activation='relu', strides=2)(x)
    else:
        for l in range(conv_layers):
            x = TimeDistributed(Dense(fc_size[l], name='fc_{}'.format(l + 1), activation='relu'))(x)  # >>(?, time, fc_size)
    # conv=x
    x = BatchNormalization(axis=-1, momentum=0.99, epsilon=1e-3, center=True, scale=True)(x)

    for l in range(gru_layers):
        x = Bidirectional(GRU(rnn_size[l], name='fc_{}'.format(l + 1), return_sequences=True, activation='relu', kernel_initializer=initialization),
                      merge_mode='sum')(x)

    x = BatchNormalization(axis=-1, momentum=0.99, epsilon=1e-3, center=True, scale=True)(x)
    # x,_=AttentionLayer()([conv,x])
    # Last Layer 5+6 Time Dist Dense Layer & Softmax
    x = TimeDistributed(Dense(fc_size[-1], activation=clipped_relu))(x)
    y_pred = TimeDistributed(Dense(output_dim, name="y_pred", activation="softmax"))(x)
    model_ = Model(inputs=input_data, outputs=y_pred)
    # model_.output_length = lambda x: cnn_output_length(x, 11, 'valid', 2)
    # print(model_.output_length)
    # labels = K.placeholder(name='the_labels', ndim=1, dtype='int32')
    labels = Input(name='the_labels', shape=[None,], dtype='int32')
    input_length = Input(name='input_length', shape=[1], dtype='int32')
    label_length = Input(name='label_length', shape=[1], dtype='int32')
    # output_lengths = Lambda(model_.output_length)(input_length)
    # print(output_lengths.shape)
    # print(input_length.shape)
    # Keras doesn't currently support loss funcs with extra parameters
    # so CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred,
                                                                       labels,
                                                                       input_length,
                                                                       label_length])

    model = Model(inputs=[input_data, labels, input_length, label_length], outputs=loss_out)

    return model

# %%
runtime = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')
name="DS"+str(2)+"_"+runtime
output_dir = os.path.join('/content/drive/MyDrive/SpeakCV/CombinedDataModels',
                              'model%s_%s' % (model_arch,
                                          name))
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)


## 3. Load existing or create new model
loadcheckpointpath='/drive/MyDrive/SpeakCV/CombinedDataModels/epochs/LER-WER-best-DS2_2020-12-22_13-07-0.4'
if False:
  print('lodaing checkpoint')
  # load existing
  print("Loading model")
  # cp = loadcheckpointpath
  
  assert(os.path.isdir(loadcheckpointpath))

  model_path = os.path.join(loadcheckpointpath, "model")
    # assert(os.path.isfile(model_path))

  model = load_model_checkpoint(model_path)
else:
  model = ds2_gru_model(input_dim=161, fc_size=[256] ,rnn_size=[256,512], output_dim=43)
# model = ds1(input_dim=26, fc_size=512, rnn_size=512, output_dim=43)

print(model.summary(line_length=80))

#required to save the JSON
# save_model(model, output_dir)
opt='sgd'
if (opt.lower() == 'sgd'):
    opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True, clipnorm=5)
elif (opt.lower() == 'adam'):
    opt = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-8, clipnorm=5)
elif (opt.lower() == 'nadam'):
    opt = Nadam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-8, clipnorm=5)
else:
    raise "optimiser not recognised"

model.compile(optimizer=opt, loss=ctc,metrics=['mse'])

## 4. train
train_steps=0
if train_steps == 0:
    train_steps = len(df_train.index) // batchsize
    # print(args.train_steps)
# we use 1/xth of the validation data at each epoch end to test val score
valid_steps=0
if valid_steps == 0:

    valid_steps = (len(df_valid.index) // batchsize)
    # print(args.valid_steps)

memcheck=False
if memcheck:
    cb_list = [MemoryCallback()]
else:
    cb_list = []
tensorboard=True
if tensorboard:
    tb_cb = TensorBoard(log_dir='/content/drive/MyDrive/SpeakCV/CombinedDatatensorboard/{}/'.format(name), write_graph=False, write_images=True)
    cb_list.append(tb_cb)

name
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:150: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:514: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4076: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4187: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4191: The name tf.log is deprecated. Please use tf.math.log instead.
#
# ________________________________________________________________________________
# Layer (type)              Output Shape      Param #  Connected to
# ================================================================================
# the_input (InputLayer)    (None, None, 161) 0
# ________________________________________________________________________________
# batch_normalization_1 (Ba (None, None, 161) 644      the_input[0][0]
# ________________________________________________________________________________
# time_distributed_1 (TimeD (None, None, 256) 41472    batch_normalization_1[0][0]
# ________________________________________________________________________________
# batch_normalization_2 (Ba (None, None, 256) 1024     time_distributed_1[0][0]
# ________________________________________________________________________________
# bidirectional_1 (Bidirect (None, None, 256) 787968   batch_normalization_2[0][0]
# ________________________________________________________________________________
# bidirectional_2 (Bidirect (None, None, 512) 2362368  bidirectional_1[0][0]
# ________________________________________________________________________________
# batch_normalization_3 (Ba (None, None, 512) 2048     bidirectional_2[0][0]
# ________________________________________________________________________________
# time_distributed_2 (TimeD (None, None, 256) 131328   batch_normalization_3[0][0]
# ________________________________________________________________________________
# time_distributed_3 (TimeD (None, None, 43)  11051    time_distributed_2[0][0]
# ________________________________________________________________________________
# the_labels (InputLayer)   (None, None)      0
# ________________________________________________________________________________
# input_length (InputLayer) (None, 1)         0
# ________________________________________________________________________________
# label_length (InputLayer) (None, 1)         0
# ________________________________________________________________________________
# ctc (Lambda)              (None, 1)         0        time_distributed_3[0][0]
#                                                      the_labels[0][0]
#                                                      input_length[0][0]
#                                                      label_length[0][0]
# ================================================================================
# Total params: 3,337,903
# Trainable params: 3,336,045
# Non-trainable params: 1,858
# ________________________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 'DS2_2020-12-22_13-07'

# %% [markdown]
# > **Training will start after running the cell below**

# %%
y_pred = model.get_layer('ctc').input[0]
input_data = model.get_layer('the_input').input

report = K.function([input_data, K.learning_phase()], [y_pred])
report_cb = ReportCallback(report, validdata, model, name, save=True)
#model.load_weights("/content/drive/MyDrive/SpeakCV/Models/epochs/LER-WER-best-DS2_2020-12-20_11-12-0.26/model.h5")
cb_list.append(report_cb)
history=model.fit_generator(generator=traindata.next_batch(),
                    steps_per_epoch=train_steps,
                    epochs=10,
                    callbacks=cb_list,
                    validation_data=validdata.next_batch(),
                    validation_steps=valid_steps,
                    initial_epoch=0,
                    verbose=1,
                    class_weight=None,
                    max_q_size=10,
                    workers=1,
                    pickle_safe=False
                    )

# K.clear_seggsion()

## These are the most important metrics
print("Mean WER   :", report_cb.mean_wer_log)
print("Mean LER   :", report_cb.mean_ler_log)
print("NormMeanLER:", report_cb.norm_mean_ler_log)

# export to csv?
K.clear_session()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(generator=<generator..., steps_per_epoch=455, epochs=10, callbacks=[<keras.ca..., validation_data=<generator..., validation_steps=113, initial_epoch=0, verbose=1, class_weight=None, workers=1, use_multiprocessing=False, max_queue_size=10)`
# Streaming output truncated to the last 5000 lines.
#
# 4.Transcribed:بیالیس
# 4.LMCorrected:بیالیس
#
# 5.GroundTruth:چودہ
#
# 5.Transcribed:چودہ
# 5.LMCorrected:چودہ
#
# 6.GroundTruth:چوہتر
#
# 6.Transcribed:چوہتر
# 6.LMCorrected:چوہتر
#
# 9.GroundTruth:چھیاسی
#
# 9.Transcribed:چھیاسی
# 9.LMCorrected:چھیاسی
#
# 10.GroundTruth:انتیس
#
# 10.Transcribed:پنتیس
# 10.LMCorrected:انتیس
#
# 11.GroundTruth:انيس سو پچاسی
#
# 11.Transcribed:انس سو پچاسی
# 11.LMCorrected:انس سو پچاسی
#
# 12.GroundTruth:پندرہ
#
# 12.Transcribed:پندرہ
# 12.LMCorrected:پندرہ
#
# 15.GroundTruth:پچاسی
#
# 15.Transcribed:پچاسی
# 15.LMCorrected:پچاسی
#
# 0.GroundTruth:میں نے ایف ایس سی کیا ہے
#
# 0.Transcribed:میں نے ایف  ایس سی کیا ہے
# 0.LMCorrected:میں نے ایف ایس سی کیا ہے
#
# 1.GroundTruth:صرف میر کے لیے نہیں تھے
#
# 1.Transcribed:سص میر کے لییے ندہیں تھے
# 1.LMCorrected:سے میر کے لیے نہیں تھے
#
# 2.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 2.Transcribed:میں کارپینٹر کا کام جانتا ہوں
# 2.LMCorrected:میں کارپینٹر کا کام جانتا ہوں
#
# 4.GroundTruth:دو ہزار پندرہ
#
# 4.Transcribed:دو ہزار پندہ
# 4.LMCorrected:دو ہزار پندرہ
#
# 5.GroundTruth:میں ڈیلیوری بوائے کا کام جانتا ہوں
#
# 5.Transcribed:میں ڈلیوری بوائے کا کام جانتا ہوں
# 5.LMCorrected:میں ڈلیوری بوائے کا کام جانتا ہوں
#
# 6.GroundTruth:چھیاسی
#
# 6.Transcribed:چھیاسی
# 6.LMCorrected:چھیاسی
#
# 12.GroundTruth:دو ہزار دس
#
# 12.Transcribed:دو ہزار س
# 12.LMCorrected:دو ہزار س
#
# 13.GroundTruth:اکبر اس بات پر بالکل کلیئر تھے ان پر یہ بات بالکل واضح تھی
#
# 13.Transcribed:اکپر اس بات پر بلکول لر تھے ان پر یہ بات بی کون وازے تھی
# 13.LMCorrected:اکبر اس بات پر بلکل پر تھے ان پر یہ بات بی کون والے تھی
#
# 14.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 14.Transcribed:میرا اس کام میں کوئی تربہ نہیں ہے
# 14.LMCorrected:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 2.GroundTruth:انيس سو چھیانوے
#
# 2.Transcribed:انس سو چھیانوے
# 2.LMCorrected:انس سو چھیانوے
#
# 3.GroundTruth:چھیاسی
#
# 3.Transcribed:چھیاسی
# 3.LMCorrected:چھیاسی
#
# 6.GroundTruth:میں پلمبر کا کام جانتا ہوں
#
# 6.Transcribed:میں پلمبر کا کام جانتا ہوں
# 6.LMCorrected:میں پلمبر کا کام جانتا ہوں
#
# 7.GroundTruth:چھیاسٹھ
#
# 7.Transcribed:چھیاسٹھ
# 7.LMCorrected:چھیاسٹھ
#
# 8.GroundTruth:ستائیس
#
# 8.Transcribed:ستایس
# 8.LMCorrected:ستائیس
#
# 11.GroundTruth:انيس سو ترانوے
#
# 11.Transcribed:انس سو ترانوے
# 11.LMCorrected:انس سو ترانوے
#
# 13.GroundTruth:چوراسی
#
# 13.Transcribed:چوراسی
# 13.LMCorrected:چوراسی
#
# 0.GroundTruth:اٹھہتر
#
# 0.Transcribed:اٹھہترر
# 0.LMCorrected:اٹھہتر
#
# 1.GroundTruth:سینتیس
#
# 1.Transcribed:سینتیس
# 1.LMCorrected:سینتیس
#
# 3.GroundTruth:انيس سو ستانوے
#
# 3.Transcribed:انس سو ستانوے
# 3.LMCorrected:انس سو ستانوے
#
# 4.GroundTruth:میں  لاہور میں رہتا ہوں
#
# 4.Transcribed:میں لہیر میں ریرتا ہوں
# 4.LMCorrected:میں لہر میں رہتا ہوں
#
# 7.GroundTruth:تراسی
#
# 7.Transcribed:تراسی
# 7.LMCorrected:تراسی
#
# 8.GroundTruth:چھببیس
#
# 8.Transcribed:چھببیس
# 8.LMCorrected:چھببیس
#
# 9.GroundTruth:میں ڈرائیور ہوں
#
# 9.Transcribed:میں ڈرائیورے ہوں
# 9.LMCorrected:میں ڈرائیور ہوں
#
# 10.GroundTruth:میں ان پڑھ ہوں
#
# 10.Transcribed:میں آاننم پارڑھ ہوں
# 10.LMCorrected:میں ماننا پڑھ ہوں
#
# 11.GroundTruth:انسٹھ
#
# 11.Transcribed:انتٹھ
# 11.LMCorrected:انسٹھ
#
# 13.GroundTruth:انيس سو نواسی
#
# 13.Transcribed:انس سو ناسی
# 13.LMCorrected:انس سو نواسی
#
# 14.GroundTruth:پچپن
#
# 14.Transcribed:پچپن
# 14.LMCorrected:پچپن
#
# 2.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 2.Transcribed:میرا اس کام میں کوئی تجربہ ں ہے
# 2.LMCorrected:میرا اس کام میں کوئی تجربہ و ہے
#
# 3.GroundTruth:دو ہزار بارہ
#
# 3.Transcribed:دو ہزار بارہ
# 3.LMCorrected:دو ہزار بارہ
#
# 4.GroundTruth:میں ان پڑھ ہوں
#
# 4.Transcribed:میں ان پڑھ ہوں
# 4.LMCorrected:میں ان پڑھ ہوں
#
# 6.GroundTruth:نوے
#
# 6.Transcribed:نوے
# 6.LMCorrected:نوے
#
# 7.GroundTruth:بہتر
#
# 7.Transcribed:باہتر
# 7.LMCorrected:بہتر
#
# 8.GroundTruth:انيس سو ترانوے
#
# 8.Transcribed:انس سو ترانوے
# 8.LMCorrected:انس سو ترانوے
#
# 9.GroundTruth:میں نے  دو ہزار چودہ میں میٹرک  کیا ہے
#
# 9.Transcribed:میں نے دو ہزار چود میں میٹرک کیا ہے
# 9.LMCorrected:میں نے دو ہزار چودہ میں میٹرک کیا ہے
#
# 14.GroundTruth:پندرہ
#
# 14.Transcribed:پندرہ
# 14.LMCorrected:پندرہ
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed:سولہ
# 0.LMCorrected:سولہ
#
# 1.GroundTruth:تین
#
# 1.Transcribed:تین
# 1.LMCorrected:تین
#
# 2.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 2.Transcribed:میں کارپینٹر کا کام جانتا ہں
# 2.LMCorrected:میں کارپینٹر کا کام جانتا ہوں
#
# 3.GroundTruth:پچانوے
#
# 3.Transcribed:پچانوے
# 3.LMCorrected:پچانوے
#
# 5.GroundTruth:انيس سو چھیانوے
#
# 5.Transcribed:انس سو چھانوے
# 5.LMCorrected:انس سو چھیانوے
#
# 6.GroundTruth:سترہ
#
# 6.Transcribed:پترہ
# 6.LMCorrected:سترہ
#
# 7.GroundTruth:دو ہزار پندرہ
#
# 7.Transcribed:دو ہزار پدرہ
# 7.LMCorrected:دو ہزار پندرہ
#
# 8.GroundTruth:انيس سو پچانوے
#
# 8.Transcribed:انس سو پچاوے
# 8.LMCorrected:انس سو پچانوے
#
# 11.GroundTruth:انيس سو نواسی
#
# 11.Transcribed:انس سو پنواسی
# 11.LMCorrected:انس سو نواسی
#
# 12.GroundTruth:چورانوے
#
# 12.Transcribed:چورانوے
# 12.LMCorrected:چورانوے
#
# 14.GroundTruth:انيس سو چھیاسی
#
# 14.Transcribed:نس سو چھیاس
# 14.LMCorrected:نے سو چھیاسی
#
# 15.GroundTruth:ننانوے
#
# 15.Transcribed:دننانوے
# 15.LMCorrected:ننانوے
#
# 2.GroundTruth:پندرہ
#
# 2.Transcribed:پندرہ
# 2.LMCorrected:پندرہ
#
# 3.GroundTruth:انيس سو اٹھانوے
#
# 3.Transcribed:انس سو پٹھانوے
# 3.LMCorrected:انس سو اٹھانوے
#
# 4.GroundTruth:بانوے
#
# 4.Transcribed:بانوے
# 4.LMCorrected:بانوے
#
# 5.GroundTruth:چوبیس
#
# 5.Transcribed:چوبیس
# 5.LMCorrected:چوبیس
#
# 7.GroundTruth:میرا آٹھ سال کا تجربہ ہے
#
# 7.Transcribed:میرا آٹھ سال کا تجربہ ہے
# 7.LMCorrected:میرا آٹھ سال کا تجربہ ہے
#
# 8.GroundTruth:مجھے یہ کام کرتے ہوئے چھ سال کا عرصہ ہو گیا ہے
#
# 8.Transcribed:جھے یہ کام کرتے ہوئے ال کا عرتہ کو گی ہے
# 8.LMCorrected:مجھے یہ کام کرتے ہوئے ال کا عرصہ کو گی ہے
#
# 9.GroundTruth:میں نے ایف ایس سی تک تعلیم حاصل کی ہے
#
# 9.Transcribed:میں نے افتایس سی تک تعلیم حاصل کی ہے
# 9.LMCorrected:میں نے افلاس سی تک تعلیم حاصل کی ہے
#
# 10.GroundTruth:انيس سو اکانوے
#
# 10.Transcribed:انس سو اکاوے
# 10.LMCorrected:انس سو اکانوے
#
# 11.GroundTruth:میرا پیشہ الیکٹریشن ہے
#
# 11.Transcribed:میرا تیشہ لیکٹریس ہے
# 11.LMCorrected:میرا پیشہ لیکٹریس ہے
#
# 14.GroundTruth:اٹھسٹھ
#
# 14.Transcribed:اڑٹڑسٹھ
# 14.LMCorrected:اٹھسٹھ
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:میں نے کوئی تعلیم حاصل نہں کی
# 0.LMCorrected:میں نے کوئی تعلیم حاصل نہیں کی
#
# 2.GroundTruth:میں نے دو ہزار سولہ میں میٹرک مکمل کی ہے
#
# 2.Transcribed:میں نے دو ہزار سولہ میں میٹک کمل کی ہے
# 2.LMCorrected:میں نے دو ہزار سولہ میں میٹرک مکمل کی ہے
#
# 5.GroundTruth:میں اسلام آباد میں رہتا ہوں
#
# 5.Transcribed:میں سلامآبار میں رہتا ہوں
# 5.LMCorrected:میں سلامآبار میں رہتا ہوں
#
# 7.GroundTruth:چالیس
#
# 7.Transcribed:چالیس
# 7.LMCorrected:چالیس
#
# 8.GroundTruth:ایک
#
# 8.Transcribed:ایک
# 8.LMCorrected:ایک
#
# 9.GroundTruth:میرا نام رضی ہے
#
# 9.Transcribed:میرا نام عرکویہ ہے
# 9.LMCorrected:میرا نام رویہ ہے
#
# 10.GroundTruth:حسد کا متضاد
#
# 10.Transcribed:حصکا متظاد
# 10.LMCorrected:کا متضاد
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed:سولہ
# 0.LMCorrected:سولہ
#
# 2.GroundTruth:ستاسی
#
# 2.Transcribed:ستاسی
# 2.LMCorrected:ستاسی
#
# 3.GroundTruth:میں الیکٹریشن کا کام جانتا ہوں
#
# 3.Transcribed:میںں لیکٹریشن ک کام جانتا ہوں
# 3.LMCorrected:میں الیکٹریشن ک کام جانتا ہوں
#
# 4.GroundTruth:چھتیس
#
# 4.Transcribed:چھتیس
# 4.LMCorrected:چھتیس
#
# 5.GroundTruth:دو ہزار سات
#
# 5.Transcribed:دو ہزار سات
# 5.LMCorrected:دو ہزار سات
#
# 6.GroundTruth:انيس سو نوے
#
# 6.Transcribed:انس سو ناوے
# 6.LMCorrected:انس سو نوے
#
# 8.GroundTruth:اٹھاسی
#
# 8.Transcribed:اٹھاسی
# 8.LMCorrected:اٹھاسی
#
# 9.GroundTruth:میں نے  دو ہزار دس میں میٹرک  کیا ہے
#
# 9.Transcribed:میں نے دو ہزار دنں میٹرک کیا ہے
# 9.LMCorrected:میں نے دو ہزار دن میٹرک کیا ہے
#
# 10.GroundTruth:انيس سو اٹھاسی
#
# 10.Transcribed:انس سو اٹھاسی
# 10.LMCorrected:انس سو اٹھاسی
#
# 12.GroundTruth:اکتیس
#
# 12.Transcribed:اکہتیس
# 12.LMCorrected:اکتیس
#
# 13.GroundTruth:جو مسجود ملائک ہوں اسے کسی انسان کے سامنے نہیں جھکنا چاہیے
#
# 13.Transcribed:جو مسدود ماد ہو کاسے کسی انسان کے سامنے نہی جنچایے
# 13.LMCorrected:جو مسجود مان ہو اسے کسی انسان کے سامنے نہیں جنچایے
#
# 14.GroundTruth:میں نے دس سال کام کیا ہے
#
# 14.Transcribed:میں نے دس سال کام کیا ہے
# 14.LMCorrected:میں نے دس سال کام کیا ہے
#
# 1.GroundTruth:میں بارہویں پاس ہوں
#
# 1.Transcribed:میں بارویں پاس ہں
# 1.LMCorrected:میں بارہویں پاس ہوں
#
# 2.GroundTruth:پینسٹھ
#
# 2.Transcribed:پینسٹھ
# 2.LMCorrected:پینسٹھ
#
# 4.GroundTruth:مجھے یہ کام کرتے ہوئے سات سال کا عرصہ ہو گیا ہے
#
# 4.Transcribed:مجیے یہ کام کرتے ہوئت سال کا عرشہ ہو گا ہے
# 4.LMCorrected:مجھے یہ کام کرتے ہوئے سال کا عرصہ ہو گا ہے
#
# 5.GroundTruth:دو ہزار
#
# 5.Transcribed:دو ہزارر
# 5.LMCorrected:دو ہزار
#
# 6.GroundTruth:انيس سو چھیانوے
#
# 6.Transcribed:انس سو چھیانوے
# 6.LMCorrected:انس سو چھیانوے
#
# 7.GroundTruth:دو ہزار تیرہ
#
# 7.Transcribed:دو ہزار تیرہ
# 7.LMCorrected:دو ہزار تیرہ
#
# 8.GroundTruth:اکانوے
#
# 8.Transcribed:اکانے
# 8.LMCorrected:اکانوے
#
# 10.GroundTruth:انيس سو ترانوے
#
# 10.Transcribed:انس سو تیرانوے
# 10.LMCorrected:انس سو ترانوے
#
# 12.GroundTruth:پچاسی
#
# 12.Transcribed:پکچاسی
# 12.LMCorrected:پچاسی
#
# 13.GroundTruth:پچیس
#
# 13.Transcribed:بچیس
# 13.LMCorrected:پچیس
#
# 14.GroundTruth:ظاہری طور پر
#
# 14.Transcribed:زاری طور پرو
# 14.LMCorrected:زاری طور پر
#
# 0.GroundTruth:میں ان پڑھ ہوں
#
# 0.Transcribed:میں ان پڑھہو
# 0.LMCorrected:میں ان پڑھ
#
# 1.GroundTruth:ستر
#
# 1.Transcribed:ستر
# 1.LMCorrected:ستر
#
# 2.GroundTruth:میں نے ایف ایس سی تک پڑھا ہے
#
# 2.Transcribed:میں نے ایف ایف سی تک پڑڑھا ہے
# 2.LMCorrected:میں نے ایف ایف سی تک پڑھا ہے
#
# 5.GroundTruth:دو ہزار چودہ
#
# 5.Transcribed:دو ہزار چودہ
# 5.LMCorrected:دو ہزار چودہ
#
# 6.GroundTruth:بانوے
#
# 6.Transcribed:بانوے
# 6.LMCorrected:بانوے
#
# 7.GroundTruth:انيس سو پچانوے
#
# 7.Transcribed:انس سو پچنوے
# 7.LMCorrected:انس سو پچانوے
#
# 11.GroundTruth:اس بلندی پر نہیں جہاں تک انسانی عقل انسانی احساس پہنچ ہی نہیں سکتا
#
# 11.Transcribed:اس پلندی پر نہیں جہا تک انسانی عقل انسانی ساس پچنیں کتا
# 11.LMCorrected:اس بلندی پر نہیں جہاں تک انسانی عقل انسانی اس پچیس کا
#
# 13.GroundTruth:میری عمر اکیس سال ہے
#
# 13.Transcribed:میری م کیس سال ہے
# 13.LMCorrected:میری م اکیس سال ہے
#
# 15.GroundTruth:میرا دس سال کا تجربہ ہے
#
# 15.Transcribed:میرا د سال کتجرباہ ہے
# 15.LMCorrected:میرا د سال تجربہ ہے
#
# 0.GroundTruth:دو ہزار تین
#
# 0.Transcribed:دو ہزار تین
# 0.LMCorrected:دو ہزار تین
#
# 1.GroundTruth:میں ڈلیوری بوائے کا کام جانتا ہوں
#
# 1.Transcribed:میں ڈدیلیوی بائے ک کام جانتا ہوں
# 1.LMCorrected:میں ڈیلیوری بوائے ک کام جانتا ہوں
#
# 5.GroundTruth:ترانوے
#
# 5.Transcribed:چرانوے
# 5.LMCorrected:ترانوے
#
# 9.GroundTruth:میں پلمبر ہوں
#
# 9.Transcribed:میں پلر ہوں
# 9.LMCorrected:میں پر ہوں
#
# 11.GroundTruth:میں نے دو ہزار انیس میں بارہویں مکمل کی ہے
#
# 11.Transcribed:میں نے دو  ہزار انیں  نیں برہویں ہ کمر کی ہے
# 11.LMCorrected:میں نے دو ہزار انیس میں بارہویں ہ کر کی ہے
#
# 12.GroundTruth:ترانوے
#
# 12.Transcribed:تیانوے
# 12.LMCorrected:ترانوے
#
# 13.GroundTruth:میں الیکٹریشن کا کام جانتا ہوں
#
# 13.Transcribed:میں ایلیکٹرریشن کا کام جانتا ہوں
# 13.LMCorrected:میں الیکٹریشن کا کام جانتا ہوں
#
# 14.GroundTruth:انيس سو اکانوے
#
# 14.Transcribed:انس سو کانوے
# 14.LMCorrected:انس سو اکانوے
#
# 1.GroundTruth:میں ڈرائیور ہوں
#
# 1.Transcribed:میں ڈررائیور ہوں
# 1.LMCorrected:میں ڈرائیور ہوں
#
# 2.GroundTruth:میں نے پانچ سال کام کیا ہے
#
# 2.Transcribed:میں نے پانچ سال کام کیا ہےں
# 2.LMCorrected:میں نے پانچ سال کام کیا ہے
#
# 3.GroundTruth:میں نے دسویں جماعت تک پڑھا ہے
#
# 3.Transcribed:میں نے تسیں یبات تک پڑھا ہے
# 3.LMCorrected:میں نے تھیں بات تک پڑھا ہے
#
# 4.GroundTruth:میرا فون نمبر یہ ہے  03174728808
#
# 4.Transcribed:میرا فون نمبر یہ ا
# 4.LMCorrected:میرا فون نمبر یہ ا
#
# 5.GroundTruth:میں نے ایف ایس سی تک تعلیم حاصل کی ہے
#
# 5.Transcribed:میں نے ادس سی تک تعلیم حاصل کی ہے
# 5.LMCorrected:میں نے ایس سی تک تعلیم حاصل کی ہے
#
# 8.GroundTruth:دو ہزار نو
#
# 8.Transcribed:دو ہزار نو
# 8.LMCorrected:دو ہزار نو
#
# 10.GroundTruth:میں نے میٹرک تک پڑھا ہے
#
# 10.Transcribed:میں نے میٹرک تک پڑھا ہے
# 10.LMCorrected:میں نے میٹرک تک پڑھا ہے
#
# 13.GroundTruth:اڑتالیس
#
# 13.Transcribed:اڑتایس
# 13.LMCorrected:اڑتالیس
#
# 15.GroundTruth:دو ہزار ایک
#
# 15.Transcribed:دو ہزار ای
# 15.LMCorrected:دو ہزار ای
#
# 1.GroundTruth:انیس
#
# 1.Transcribed:انیس
# 1.LMCorrected:انیس
#
# 2.GroundTruth:دو ہزار پانچ
#
# 2.Transcribed:دو ہزار پانچ
# 2.LMCorrected:دو ہزار پانچ
#
# 3.GroundTruth:طالب ہوتا ہے
#
# 3.Transcribed:طالب وتا ہے
# 3.LMCorrected:طالب ہوتا ہے
#
# 4.GroundTruth:سڑسٹھ
#
# 4.Transcribed:سیڑھٹھ
# 4.LMCorrected:سڑسٹھ
#
# 7.GroundTruth:پانچ
#
# 7.Transcribed:پانچ
# 7.LMCorrected:پانچ
#
# 8.GroundTruth:پچانوے
#
# 8.Transcribed:پچنوے
# 8.LMCorrected:پچانوے
#
# 10.GroundTruth:میرا پیشہ پلمبر ہے
#
# 10.Transcribed:میرا تیشہ تلمبر ہے
# 10.LMCorrected:میرا پیشہ پلمبر ہے
#
# 14.GroundTruth:ستاسی
#
# 14.Transcribed:سدتاسی
# 14.LMCorrected:ستاسی
#
# 15.GroundTruth:چوسٹھ
#
# 15.Transcribed:چوسھ
# 15.LMCorrected:چوسٹھ
#
# 0.GroundTruth:دو ہزار چودہ
#
# 0.Transcribed:دو ہزار چ
# 0.LMCorrected:دو ہزار چھ
#
# 2.GroundTruth:اناسی
#
# 2.Transcribed:اناسی
# 2.LMCorrected:اناسی
#
# 3.GroundTruth:انيس سو تراسی
#
# 3.Transcribed:انس سو تراسی
# 3.LMCorrected:انس سو تراسی
#
# 4.GroundTruth:انيس سو چھیانوے
#
# 4.Transcribed:انس سو چھیانوی
# 4.LMCorrected:انس سو چھیانوے
#
# 5.GroundTruth:دو ہزار چھ
#
# 5.Transcribed:دو ہزار چھ
# 5.LMCorrected:دو ہزار چھ
#
# 6.GroundTruth:میں نے سات سال کام کیا ہے
#
# 6.Transcribed:میں راس سات سال کام کیا ہے
# 6.LMCorrected:میں اس سات سال کام کیا ہے
#
# 7.GroundTruth:چورانوے
#
# 7.Transcribed:چورانوے
# 7.LMCorrected:چورانوے
#
# 8.GroundTruth:انيس سو ستاسی
#
# 8.Transcribed:انس سو ستاس
# 8.LMCorrected:انس سو ستاسی
#
# 9.GroundTruth:اکسٹھ
#
# 9.Transcribed:اکسٹھ
# 9.LMCorrected:اکسٹھ
#
# 10.GroundTruth:دو ہزار گیارہ
#
# 10.Transcribed:دو ہزار گیارہ
# 10.LMCorrected:دو ہزار گیارہ
#
# 11.GroundTruth:بائیس
#
# 11.Transcribed:بائیس
# 11.LMCorrected:بائیس
#
# 12.GroundTruth:ہمنے غالب کے حالات زندگی پر بات کرنے کے بعد
#
# 12.Transcribed:ہب ن غالب کے حلا تزندہی پر بات کرنے کے بعاد
# 12.LMCorrected:ہے ن غالب کے حال زندگی پر بات کرنے کے بعد
#
# 14.GroundTruth:یہاں پر
#
# 14.Transcribed:یہہاں پر
# 14.LMCorrected:یہاں پر
#
# 15.GroundTruth:تراسی
#
# 15.Transcribed:تراتی
# 15.LMCorrected:تراسی
#
# 3.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 3.Transcribed:میرا پانچ سالکا تجرپباہ ہے
# 3.LMCorrected:میرا پانچ سال تجربہ ہے
#
# 5.GroundTruth:میں ڈرائیور ہوں
#
# 5.Transcribed:میں ڈرار ہوں
# 5.LMCorrected:میں قرار ہوں
#
# 6.GroundTruth:میں نے ایف ایس سی تک پڑھا ہے
#
# 6.Transcribed:میں نے ایف ایس سی تک پڑھہا ہے
# 6.LMCorrected:میں نے ایف ایس سی تک پڑھا ہے
#
# 8.GroundTruth:میں نے میٹرک تک پڑھا ہے
#
# 8.Transcribed:میں نے میٹرک تک پڑھا ہے
# 8.LMCorrected:میں نے میٹرک تک پڑھا ہے
#
# 9.GroundTruth:انيس سو پچاسی
#
# 9.Transcribed:انس سو پچاسی
# 9.LMCorrected:انس سو پچاسی
#
# 11.GroundTruth:چوراسی
#
# 11.Transcribed:چورسی
# 11.LMCorrected:چوراسی
#
# 12.GroundTruth:تہتر
#
# 12.Transcribed:تہتر
# 12.LMCorrected:تہتر
#
# 14.GroundTruth:انتالیس
#
# 14.Transcribed:نتالیس
# 14.LMCorrected:انتالیس
#
# 15.GroundTruth:میرا تجربہ آٹھ سال ہے
#
# 15.Transcribed:میرا توجربہ آسال ہے
# 15.LMCorrected:میرا تجربہ سال ہے
#
# 0.GroundTruth:سڑسٹھ
#
# 0.Transcribed:سڑسٹھ
# 0.LMCorrected:سڑسٹھ
#
# 2.GroundTruth:اٹھاسی
#
# 2.Transcribed:اٹھاسی
# 2.LMCorrected:اٹھاسی
#
# 5.GroundTruth:میں الیکٹریشن کا کام جانتا ہوں
#
# 5.Transcribed:میں ں لیکٹریشن کا کام جنتا ہوں
# 5.LMCorrected:میں و الیکٹریشن کا کام جانتا ہوں
#
# 6.GroundTruth:دو ہزار سولہ
#
# 6.Transcribed:دو ہزار سولہ
# 6.LMCorrected:دو ہزار سولہ
#
# 8.GroundTruth:غزل
#
# 8.Transcribed:غز
# 8.LMCorrected:غزل
#
# 9.GroundTruth:میں نے میٹرک کیا ہے
#
# 9.Transcribed:میں نے میٹرک کیا ہے
# 9.LMCorrected:میں نے میٹرک کیا ہے
#
# 10.GroundTruth:اٹھارہ
#
# 10.Transcribed:اٹھارہ
# 10.LMCorrected:اٹھارہ
#
# 12.GroundTruth:باسٹھ
#
# 12.Transcribed:باسٹھ
# 12.LMCorrected:باسٹھ
#
# 13.GroundTruth:میں میٹرک پاس ہوں
#
# 13.Transcribed:میں نیٹرک پاس ہوں
# 13.LMCorrected:میں میٹرک پاس ہوں
#
# 1.GroundTruth:انيس سو نوے
#
# 1.Transcribed:انس سو نوے
# 1.LMCorrected:انس سو نوے
#
# 3.GroundTruth:پینتیس
#
# 3.Transcribed:پینتیس
# 3.LMCorrected:پینتیس
#
# 7.GroundTruth:تین
#
# 7.Transcribed:تین
# 7.LMCorrected:تین
#
# 8.GroundTruth:دو ہزار سات
#
# 8.Transcribed:دو ہزار سات
# 8.LMCorrected:دو ہزار سات
#
# 10.GroundTruth:اٹھانوے
#
# 10.Transcribed:اٹانوے
# 10.LMCorrected:اٹھانوے
#
# 11.GroundTruth:دو
#
# 11.Transcribed:دو
# 11.LMCorrected:دو
#
# 15.GroundTruth:انيس سو پچاسی
#
# 15.Transcribed:انس سو پچاسی
# 15.LMCorrected:انس سو پچاسی
#
# 1.GroundTruth:چھیاسی
#
# 1.Transcribed:چھاسی
# 1.LMCorrected:چھیاسی
#
# 2.GroundTruth:انيس سو پچاسی
#
# 2.Transcribed:نس سو پچاسی
# 2.LMCorrected:نے سو پچاسی
#
# 4.GroundTruth:بائیس
#
# 4.Transcribed:بائیس
# 4.LMCorrected:بائیس
#
# 5.GroundTruth:سولہ
#
# 5.Transcribed:سولہ
# 5.LMCorrected:سولہ
#
# 6.GroundTruth:ترسٹھ
#
# 6.Transcribed:تررٹھ
# 6.LMCorrected:ترسٹھ
#
# 7.GroundTruth:میرا تجربہ دو سال ہے
#
# 7.Transcribed:میرا تجربر دو سال ہے
# 7.LMCorrected:میرا تجربہ دو سال ہے
#
# 8.GroundTruth:دہلوی زبانوں میں اردو زبان کو تلاش کرتے
#
# 8.Transcribed:دلوی زبانو میں وردو ز بان کو تلاچ کرتیں
# 8.LMCorrected:دہلوی زبانوں میں اردو ز بان کو تلاش کریں
#
# 10.GroundTruth:دو ہزار پانچ
#
# 10.Transcribed:دو ہزار وانچ
# 10.LMCorrected:دو ہزار پانچ
#
# 12.GroundTruth:اٹھائیس
#
# 12.Transcribed:اٹھائیس
# 12.LMCorrected:اٹھائیس
#
# 13.GroundTruth:ترپن
#
# 13.Transcribed:ترپن
# 13.LMCorrected:ترپن
#
# 15.GroundTruth:دو ہزار سات
#
# 15.Transcribed:دو ہزار ست
# 15.LMCorrected:دو ہزار ست
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed:دولہ
# 0.LMCorrected:سولہ
#
# 1.GroundTruth:میں کارپینٹر ہو
#
# 1.Transcribed:میں کاپینٹر ہوں
# 1.LMCorrected:میں کارپینٹر ہوں
#
# 3.GroundTruth:میں پلمبر ہوں
#
# 3.Transcribed:میں پلممبر ہوں
# 3.LMCorrected:میں پلمبر ہوں
#
# 6.GroundTruth:انسان کی زندگی کیا ہے انسان کی زندگی کس بات سے عبارت ہے
#
# 6.Transcribed:انسان گ زدگی کیا ہے انسان ک زندنی کس بات سے بارد ت
# 6.LMCorrected:انسان گ زندگی کیا ہے انسان ک زندگی کس بات سے بار ت
#
# 8.GroundTruth:سترہ
#
# 8.Transcribed:ستچرہ
# 8.LMCorrected:سترہ
#
# 9.GroundTruth:تہتر
#
# 9.Transcribed:تہتر
# 9.LMCorrected:تہتر
#
# 10.GroundTruth:تین
#
# 10.Transcribed:تین
# 10.LMCorrected:تین
#
# 12.GroundTruth:اٹھانوے
#
# 12.Transcribed:اٹھانوے
# 12.LMCorrected:اٹھانوے
#
# 13.GroundTruth:دو ہزار نو
#
# 13.Transcribed:دو ہزار نو
# 13.LMCorrected:دو ہزار نو
#
# 14.GroundTruth:میں نے آئی سی ایس تک پڑھا ہے
#
# 14.Transcribed:میں نے ائی س ایس تک پڑھا ہے
# 14.LMCorrected:میں نے ائی س ایس تک پڑھا ہے
#
# 1.GroundTruth:انتالیس
#
# 1.Transcribed:انتالیس
# 1.LMCorrected:انتالیس
#
# 2.GroundTruth:سینتیس
#
# 2.Transcribed:سیتیس
# 2.LMCorrected:سینتیس
#
# 4.GroundTruth:ستتر
#
# 4.Transcribed:ستتر
# 4.LMCorrected:ستتر
#
# 5.GroundTruth:میں نے آٹھویں جماعت تک پڑھا ہے
#
# 5.Transcribed:میں نے آٹھ جماعت تک پڑھ ہے
# 5.LMCorrected:میں نے آٹھ جماعت تک پڑھ ہے
#
# 6.GroundTruth:انيس سو اٹھاسی
#
# 6.Transcribed:انس سو اٹھاسی
# 6.LMCorrected:انس سو اٹھاسی
#
# 7.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 7.Transcribed:میرا پانچ س سال کا تجربہ ہے
# 7.LMCorrected:میرا پانچ س سال کا تجربہ ہے
#
# 10.GroundTruth:اڑتیس
#
# 10.Transcribed:اڑتیس
# 10.LMCorrected:اڑتیس
#
# 11.GroundTruth:بارہ
#
# 11.Transcribed:بارہ
# 11.LMCorrected:بارہ
#
# 13.GroundTruth:میرا تجربہ دو سال ہے
#
# 13.Transcribed:میرا تجرباہ دو سا ہے
# 13.LMCorrected:میرا تجربہ دو سا ہے
#
# 14.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 14.Transcribed:میں کارپینٹر کا کام جانتا ہوں
# 14.LMCorrected:میں کارپینٹر کا کام جانتا ہوں
#
# 15.GroundTruth:میرا سات سال کا تجربہ ہے
#
# 15.Transcribed:میرا سات سال ک تجربہ ہے
# 15.LMCorrected:میرا سات سال ک تجربہ ہے
#
# 0.GroundTruth:میرا تعلق لاہور سے ہے
#
# 0.Transcribed:میرا تعلق ہور سے ہے
# 0.LMCorrected:میرا تعلق اور سے ہے
#
# 1.GroundTruth:دو ہزار ایک
#
# 1.Transcribed:دو ہزار یہک
# 1.LMCorrected:دو ہزار یہ
#
# 2.GroundTruth:چورانوے
#
# 2.Transcribed:چورانوے
# 2.LMCorrected:چورانوے
#
# 3.GroundTruth:اکہتر
#
# 3.Transcribed:اکہتر
# 3.LMCorrected:اکہتر
#
# 10.GroundTruth:ستاسی
#
# 10.Transcribed:ستاسی
# 10.LMCorrected:ستاسی
#
# 11.GroundTruth:میں پلمبر کا کام جانتا ہوں
#
# 11.Transcribed:میں پلمبر کا کام جانتا ہوں
# 11.LMCorrected:میں پلمبر کا کام جانتا ہوں
#
# 12.GroundTruth:انيس سو تراسی
#
# 12.Transcribed:انس سو تراسی
# 12.LMCorrected:انس سو تراسی
#
# 14.GroundTruth:انتیس
#
# 14.Transcribed:انہتیس
# 14.LMCorrected:انتیس
#
# 15.GroundTruth:یہ وہ دور تھا جس میں غالب نے
#
# 15.Transcribed:کہ نوہ دور تھا جس منے غالب نے
# 15.LMCorrected:کہ وہ دور تھا جس نے غالب نے
#
# 1.GroundTruth:چھیانوے
#
# 1.Transcribed:چھیانوے
# 1.LMCorrected:چھیانوے
#
# 2.GroundTruth:دو ہزار پانچ
#
# 2.Transcribed:دو ہزار انچ
# 2.LMCorrected:دو ہزار پانچ
#
# 3.GroundTruth:انيس سو اٹھانوے
#
# 3.Transcribed:انس سو اٹھانوے
# 3.LMCorrected:انس سو اٹھانوے
#
# 7.GroundTruth:ترپن
#
# 7.Transcribed:ترپن
# 7.LMCorrected:ترپن
#
# 8.GroundTruth:اردو
#
# 8.Transcribed:اردو
# 8.LMCorrected:اردو
#
# 9.GroundTruth:دو ہزار اٹھارہ
#
# 9.Transcribed:دو زار اٹھارہ
# 9.LMCorrected:دو زار اٹھارہ
#
# 11.GroundTruth:چھپن
#
# 11.Transcribed:چھپن
# 11.LMCorrected:چھپن
#
# 15.GroundTruth:دو ہزار پندرہ
#
# 15.Transcribed:دو ہزار پدرہ
# 15.LMCorrected:دو ہزار پندرہ
#
# 0.GroundTruth:دس
#
# 0.Transcribed:دس
# 0.LMCorrected:دس
#
# 5.GroundTruth:میں نے جامعہ تک پڑھا ہے
#
# 5.Transcribed:میں نے کاہیہ تک پرہ ہے
# 5.LMCorrected:میں نے کہیہ تک پارہ ہے
#
# 6.GroundTruth:انيس سو پچاسی
#
# 6.Transcribed:انس سو اپچاسی
# 6.LMCorrected:انس سو پچاسی
#
# 7.GroundTruth:پچہتر
#
# 7.Transcribed:پچہتر
# 7.LMCorrected:پچہتر
#
# 8.GroundTruth:انتیس
#
# 8.Transcribed:انتیس
# 8.LMCorrected:انتیس
#
# 12.GroundTruth:دو ہزار انیس
#
# 12.Transcribed:دو ہزار انیس
# 12.LMCorrected:دو ہزار انیس
#
# 13.GroundTruth:اکانوے
#
# 13.Transcribed:اکانوے
# 13.LMCorrected:اکانوے
#
# 1.GroundTruth:میرا نام احمد ہے
#
# 1.Transcribed:میرا نام بر ہے
# 1.LMCorrected:میرا نام بر ہے
#
# 2.GroundTruth:دو ہزار سات
#
# 2.Transcribed:دو ہزار سٹھ
# 2.LMCorrected:دو ہزار آٹھ
#
# 3.GroundTruth:اٹھسٹھ
#
# 3.Transcribed:اٹھھسڑٹھ
# 3.LMCorrected:اٹھسٹھ
#
# 4.GroundTruth:چون
#
# 4.Transcribed:چون
# 4.LMCorrected:چون
#
# 6.GroundTruth:تین
#
# 6.Transcribed:تین
# 6.LMCorrected:تین
#
# 9.GroundTruth:اٹھہتر
#
# 9.Transcribed:اٹھہتر
# 9.LMCorrected:اٹھہتر
#
# 10.GroundTruth:اکانوے
#
# 10.Transcribed:اکیانوے
# 10.LMCorrected:اکانوے
#
# 11.GroundTruth:اکہتر
#
# 11.Transcribed:اکہتر
# 11.LMCorrected:اکہتر
#
# 12.GroundTruth:دو ہزار چھ
#
# 12.Transcribed:دو ہزار چھ
# 12.LMCorrected:دو ہزار چھ
#
# 13.GroundTruth:تہتر
#
# 13.Transcribed:تیہتر
# 13.LMCorrected:تہتر
#
# 14.GroundTruth:دو ہزار چھ
#
# 14.Transcribed:دو ہزار چھ
# 14.LMCorrected:دو ہزار چھ
#
# 0.GroundTruth:اکیس
#
# 0.Transcribed:اکیس
# 0.LMCorrected:اکیس
#
# 1.GroundTruth:مجھے یہ کام کرتے ہوئے پانچ سال کا عرصہ ہو گیا ہے
#
# 1.Transcribed:مجھے یہ کام کر ت ہے پنچ سال کا عرصہ ہو گیا ہے
# 1.LMCorrected:مجھے یہ کام کر ت ہے پانچ سال کا عرصہ ہو گیا ہے
#
# 2.GroundTruth:میں ڈرائیور ہوں
#
# 2.Transcribed:مں ڈرائور ہوں
# 2.LMCorrected:میں ڈرائیور ہوں
#
# 6.GroundTruth:ایک خاص انداز میں اپنے ادب کی بنیاد رکھی
#
# 6.Transcribed:اک خاصنداز مں اپندب کی بناد درککھی
# 6.LMCorrected:اک انداز میں ادب کی بنیاد رکھی
#
# 9.GroundTruth:بیس
#
# 9.Transcribed:بیس
# 9.LMCorrected:بیس
#
# 14.GroundTruth:دو ہزار تین
#
# 14.Transcribed:دو ہزار تیر
# 14.LMCorrected:دو ہزار تیر
#
# 15.GroundTruth:اکتالیس
#
# 15.Transcribed:اکککالیس
# 15.LMCorrected:اکتالیس
#
# 2.GroundTruth:انيس سو بانوے
#
# 2.Transcribed:انس سو بیانوے
# 2.LMCorrected:انس سو بانوے
#
# 3.GroundTruth:میں نے آئی سی ایس کیا ہے
#
# 3.Transcribed:میں نے آئیس ی س کیا ہے
# 3.LMCorrected:میں نے آئی ی س کیا ہے
#
# 4.GroundTruth:بتیس
#
# 4.Transcribed:بتیس
# 4.LMCorrected:بتیس
#
# 6.GroundTruth:ساٹھ
#
# 6.Transcribed:ساٹھ
# 6.LMCorrected:ساٹھ
#
# 7.GroundTruth:میں نے پانچ  سال کام کیا ہے
#
# 7.Transcribed:میں لے پانچ سال کام کیا ہے
# 7.LMCorrected:میں لے پانچ سال کام کیا ہے
#
# 8.GroundTruth:چوبیس
#
# 8.Transcribed:چوبیس
# 8.LMCorrected:چوبیس
#
# 9.GroundTruth:دو ہزار بارہ
#
# 9.Transcribed:دو ہزار پارہ
# 9.LMCorrected:دو ہزار پارہ
#
# 10.GroundTruth:چوبیس
#
# 10.Transcribed:چوبیس
# 10.LMCorrected:چوبیس
#
# 11.GroundTruth:دو ہزار نو
#
# 11.Transcribed:دو ہزا ٹھ
# 11.LMCorrected:دو ہزار آٹھ
#
# 13.GroundTruth:انيس سو ستانوے
#
# 13.Transcribed:انس سو ستانوے
# 13.LMCorrected:انس سو ستانوے
#
# 14.GroundTruth:میرا نام احمد ہے
#
# 14.Transcribed:میرا نام نمن ہے
# 14.LMCorrected:میرا نام امن ہے
#
# 15.GroundTruth:میں گیارہویں پاس ہو
#
# 15.Transcribed:میں گیائیویں پاس ہوں
# 15.LMCorrected:میں گیارہویں پاس ہوں
#
# 0.GroundTruth:میں کارپینٹر  ہوں
#
# 0.Transcribed:میں کارپینٹ ہوں
# 0.LMCorrected:میں کارپینٹر ہوں
#
# 3.GroundTruth:اسی
#
# 3.Transcribed:اسی
# 3.LMCorrected:اسی
#
# 4.GroundTruth:میں نے پانچ سال کام کیا ہے
#
# 4.Transcribed:میں نے پانچ سال کام کیا ہے
# 4.LMCorrected:میں نے پانچ سال کام کیا ہے
#
# 6.GroundTruth:میں لاہور میں رہتا ہوں
#
# 6.Transcribed:میں لاہ میں پہتا ہوں
# 6.LMCorrected:میں شاہ میں رہتا ہوں
#
# 8.GroundTruth:چوراسی
#
# 8.Transcribed:چوراسی
# 8.LMCorrected:چوراسی
#
# 9.GroundTruth:میرا تعلق اسلام آباد سے ہے
#
# 9.Transcribed:میرا تعنلق لام آباد ی ہے
# 9.LMCorrected:میرا تعلق کام آباد ی ہے
#
# 10.GroundTruth:میرا تجربہ پانچ   سال ہے
#
# 10.Transcribed:میرا تجربہ پانچ سان ہے
# 10.LMCorrected:میرا تجربہ پانچ سال ہے
#
# 13.GroundTruth:اڑتالیس
#
# 13.Transcribed:اڑتالیس
# 13.LMCorrected:اڑتالیس
#
# 15.GroundTruth:بائیس
#
# 15.Transcribed:بائیس
# 15.LMCorrected:بائیس
#
# 0.GroundTruth:تراسی
#
# 0.Transcribed:تراسی
# 0.LMCorrected:تراسی
#
# 3.GroundTruth:انسٹھ
#
# 3.Transcribed:انسٹھ
# 3.LMCorrected:انسٹھ
#
# 4.GroundTruth:ستانوے
#
# 4.Transcribed:ستانوے
# 4.LMCorrected:ستانوے
#
# 7.GroundTruth:دو ہزار چودہ
#
# 7.Transcribed:دو ہزار چودہ
# 7.LMCorrected:دو ہزار چودہ
#
# 8.GroundTruth:میرا پیشہ ڈرائیور ہے
#
# 8.Transcribed:میر پیشہ ڈرایر ہے
# 8.LMCorrected:میر پیشہ ڈرائیور ہے
#
# 9.GroundTruth:چوراسی
#
# 9.Transcribed:چوراسوی
# 9.LMCorrected:چوراسی
#
# 11.GroundTruth:تیس
#
# 11.Transcribed:تیس
# 11.LMCorrected:تیس
#
# 12.GroundTruth:انيس سو اکانوے
#
# 12.Transcribed:امس سو کانوے
# 12.LMCorrected:اس سو اکانوے
#
# 0.GroundTruth:چھیاسی
#
# 0.Transcribed:چھیاسی
# 0.LMCorrected:چھیاسی
#
# 1.GroundTruth:دو ہزار چھ
#
# 1.Transcribed:دو ہزار چھ
# 1.LMCorrected:دو ہزار چھ
#
# 3.GroundTruth:ستاسی
#
# 3.Transcribed:ستاسی
# 3.LMCorrected:ستاسی
#
# 5.GroundTruth:بارہ
#
# 5.Transcribed:بارہ
# 5.LMCorrected:بارہ
#
# 6.GroundTruth:تیس
#
# 6.Transcribed:تیس
# 6.LMCorrected:تیس
#
# 7.GroundTruth:دو ہزار بیس
#
# 7.Transcribed:دو ہزار بیس
# 7.LMCorrected:دو ہزار بیس
#
# 8.GroundTruth:دس
#
# 8.Transcribed:دس
# 8.LMCorrected:دس
#
# 9.GroundTruth:میں کارپینٹر ہو
#
# 9.Transcribed:میں کارپینٹر ہوں
# 9.LMCorrected:میں کارپینٹر ہوں
#
# 10.GroundTruth:دو ہزار چھ
#
# 10.Transcribed:دو ززار چھ
# 10.LMCorrected:دو ہزار چھ
#
# 11.GroundTruth:میں نے دو ہزار سولہ میں دسویں مکمل کی ہے
#
# 11.Transcribed:میں نے دو ہزارل سولام میں دسویں مکمل کی ہے
# 11.LMCorrected:میں نے دو ہزار سوعام میں دسویں مکمل کی ہے
#
# 12.GroundTruth:تینتالیس
#
# 12.Transcribed:تینتالیس
# 12.LMCorrected:تینتالیس
#
# 14.GroundTruth:دو ہزار سات
#
# 14.Transcribed:دو ہزار سات
# 14.LMCorrected:دو ہزار سات
#
# 1.GroundTruth:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 1.Transcribed:میں نے دو ہزار دس میں میٹریک کیا ہے
# 1.LMCorrected:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 2.GroundTruth:دو ہزار نو
#
# 2.Transcribed:دو ہزار ن
# 2.LMCorrected:دو ہزار ن
#
# 3.GroundTruth:غزل
#
# 3.Transcribed:غظل
# 3.LMCorrected:غزل
#
# 5.GroundTruth:چودہ
#
# 5.Transcribed:چودہ
# 5.LMCorrected:چودہ
#
# 7.GroundTruth:میر تقی میر کی
#
# 7.Transcribed:مھیر تکی میر کی
# 7.LMCorrected:میر تقی میر کی
#
# 8.GroundTruth:باسٹھ
#
# 8.Transcribed:پاسٹھ
# 8.LMCorrected:باسٹھ
#
# 10.GroundTruth:غالب نے اسی دور میں زندگی گزاری
#
# 10.Transcribed:غالب نے اسی دور میں زدگیے گزاری
# 10.LMCorrected:غالب نے اسی دور میں زندگی گزاری
#
# 11.GroundTruth:اکتیس
#
# 11.Transcribed:اکتیس
# 11.LMCorrected:اکتیس
#
# 13.GroundTruth:اٹھسٹھ
#
# 13.Transcribed:اٹسٹھ
# 13.LMCorrected:اٹھسٹھ
#
# 14.GroundTruth:انيس سو ترانوے
#
# 14.Transcribed:انس سو تریاوے
# 14.LMCorrected:انس سو ترانوے
#
# 15.GroundTruth:جس نے ہمیں پہچانا ہی نہیں
#
# 15.Transcribed:جس نے ہمں پہچانا نیں
# 15.LMCorrected:جس نے ہمیں پہچانا میں
#
# 0.GroundTruth:میں نے دسویں تک پڑھا ہے
#
# 0.Transcribed:میں نے دسویں تک پڑھا ہ
# 0.LMCorrected:میں نے دسویں تک پڑھا ہ
#
# 2.GroundTruth:انسٹھ
#
# 2.Transcribed:انسٹھ
# 2.LMCorrected:انسٹھ
#
# 3.GroundTruth:پینتالیس
#
# 3.Transcribed:پنتالیس
# 3.LMCorrected:پینتالیس
#
# 4.GroundTruth:میں دس سال سے یہ کام کر رہا ہوں
#
# 4.Transcribed:میں دس سال سے یہ کام کر را ہوں
# 4.LMCorrected:میں دس سال سے یہ کام کر رہا ہوں
#
# 5.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 5.Transcribed:میرا پانچ  سال کاتجر با ہے
# 5.LMCorrected:میرا پانچ سال کار با ہے
#
# 6.GroundTruth:انيس سو ستانوے
#
# 6.Transcribed:انس سو ستانوے
# 6.LMCorrected:انس سو ستانوے
#
# 8.GroundTruth:دو ہزار آٹھ
#
# 8.Transcribed:دو ہزار آنٹھ
# 8.LMCorrected:دو ہزار آٹھ
#
# 9.GroundTruth:باون
#
# 9.Transcribed:باون
# 9.LMCorrected:باون
#
# 11.GroundTruth:اٹھاون
#
# 11.Transcribed:اٹاون
# 11.LMCorrected:اٹھاون
#
# 12.GroundTruth:چھیالیس
#
# 12.Transcribed:چھیالیس
# 12.LMCorrected:چھیالیس
#
# 13.GroundTruth:چورانوے
#
# 13.Transcribed:چورانوے
# 13.LMCorrected:چورانوے
#
# 15.GroundTruth:چالیس
#
# 15.Transcribed:چالیس
# 15.LMCorrected:چالیس
#
# 1.GroundTruth:میں الیکٹریشن ہوں
#
# 1.Transcribed:میں لیکٹریشن ہوں
# 1.LMCorrected:میں الیکٹریشن ہوں
#
# 2.GroundTruth:میں ڈرائیور ہوں
#
# 2.Transcribed:میں ڈئیور ہوی
# 2.LMCorrected:میں ڈرائیور ہوی
#
# 3.GroundTruth:ایک
#
# 3.Transcribed:ایک
# 3.LMCorrected:ایک
#
# 4.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 4.Transcribed:میں کاپیکٹر ک تا جانتا ہوں
# 4.LMCorrected:میں کارپینٹر ک تا جانتا ہوں
#
# 5.GroundTruth:انيس سو تراسی
#
# 5.Transcribed:انس سو تراسی
# 5.LMCorrected:انس سو تراسی
#
# 6.GroundTruth:میں ان پڑھ ہوں
#
# 6.Transcribed:میں انم پاھ ہوں
# 6.LMCorrected:میں ان پڑھ ہوں
#
# 9.GroundTruth:انيس سو اکانوے
#
# 9.Transcribed:انس سو کانوے
# 9.LMCorrected:انس سو اکانوے
#
# 10.GroundTruth:تینتالیس
#
# 10.Transcribed:تینتالیس
# 10.LMCorrected:تینتالیس
#
# 11.GroundTruth:میں نے دو ہزار سولہ میں میٹرک مکمل کیا ہے
#
# 11.Transcribed:بیں نے دو ہزار زولا آمیں میٹر  کم کیا ہے
# 11.LMCorrected:میں نے دو ہزار زوال میں میر کم کیا ہے
#
# 13.GroundTruth:بعدازاں اس نے سندھ پر قبضہ کیا اور ملتان تک آیا
#
# 13.Transcribed:اودزا اس نے سن طر قبظاہ کیا اور  متطان تا قکاا
# 13.LMCorrected:انداز اس نے سن پر قبضہ کیا اور ملتان تا کا
#
# 14.GroundTruth:اکتالیس
#
# 14.Transcribed:اکتالیس
# 14.LMCorrected:اکتالیس
#
# 15.GroundTruth:ستاسی
#
# 15.Transcribed:ستاسی
# 15.LMCorrected:ستاسی
#
# 1.GroundTruth:میں نے بارہویں جماعت تک پڑھا ہے
#
# 1.Transcribed:میں نے بارویں ڈماہ تک پڑھا ہے
# 1.LMCorrected:میں نے بارہویں ماہ تک پڑھا ہے
#
# 2.GroundTruth:پانچ
#
# 2.Transcribed:پانچ
# 2.LMCorrected:پانچ
#
# 4.GroundTruth:چھہتر
#
# 4.Transcribed:چھہتر
# 4.LMCorrected:چھہتر
#
# 5.GroundTruth:انيس سو نوے
#
# 5.Transcribed:انس سو نوے
# 5.LMCorrected:انس سو نوے
#
# 6.GroundTruth:اسی
#
# 6.Transcribed:اسی
# 6.LMCorrected:اسی
#
# 13.GroundTruth:میں میٹرک پاس ہوں
#
# 13.Transcribed:میں میٹرک کپاس ہوں
# 13.LMCorrected:میں میٹرک پاس ہوں
#
# 14.GroundTruth:دو ہزار چار
#
# 14.Transcribed:دو ہزار چار
# 14.LMCorrected:دو ہزار چار
#
# 1.GroundTruth:تیس
#
# 1.Transcribed:تیس
# 1.LMCorrected:تیس
#
# 4.GroundTruth:بیاسی
#
# 4.Transcribed:بیراسی
# 4.LMCorrected:بیاسی
#
# 7.GroundTruth:دو ہزار بیس
#
# 7.Transcribed:دو ہزار تبیس
# 7.LMCorrected:دو ہزار بیس
#
# 8.GroundTruth:میرا پیشہ الیکٹریشن ہے
#
# 8.Transcribed:میرا پیشہ الیکٹریشن ہے
# 8.LMCorrected:میرا پیشہ الیکٹریشن ہے
#
# 11.GroundTruth:میرا پیشہ ڈیلیوری بوائے ہے
#
# 11.Transcribed:میرا پیشہ ڈیلیوری بوائے ہے
# 11.LMCorrected:میرا پیشہ ڈیلیوری بوائے ہے
#
# 14.GroundTruth:چون
#
# 14.Transcribed:چوون
# 14.LMCorrected:چون
#
# 15.GroundTruth:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 15.Transcribed:میں نے دو سزال دس میں نیٹرر کا ہے
# 15.LMCorrected:میں نے دو سال دس میں میٹرک کا ہے
#
# 0.GroundTruth:دو
#
# 0.Transcribed:دو
# 0.LMCorrected:دو
#
# 2.GroundTruth:اکسٹھ
#
# 2.Transcribed:تکسٹھ
# 2.LMCorrected:اکسٹھ
#
# 3.GroundTruth:پینتیس
#
# 3.Transcribed:پینتیس
# 3.LMCorrected:پینتیس
#
# 5.GroundTruth:چار
#
# 5.Transcribed:چھار
# 5.LMCorrected:چار
#
# 8.GroundTruth:میں پانچ سال سے یہ کام کر رہا ہوں
#
# 8.Transcribed:میں پانچ سال سے کام کر رہا ہوں
# 8.LMCorrected:میں پانچ سال سے کام کر رہا ہوں
#
# 10.GroundTruth:ترانوے
#
# 10.Transcribed:ترانوے
# 10.LMCorrected:ترانوے
#
# 11.GroundTruth:چوبیس
#
# 11.Transcribed:چوبیس
# 11.LMCorrected:چوبیس
#
# 12.GroundTruth:انيس سو چھیاسی
#
# 12.Transcribed:انس سو چھیاس
# 12.LMCorrected:انس سو چھیاسی
#
# 13.GroundTruth:دو ہزار پانچ
#
# 13.Transcribed:دو ہزار پانچ
# 13.LMCorrected:دو ہزار پانچ
#
# 14.GroundTruth:ذوق یاروں نے بہت زور غزل میں مارا
#
# 14.Transcribed:و اروں نے بغت زورقزل نیں مارا
# 14.LMCorrected:و یاروں نے بہت زورقزل میں مارا
#
# 0.GroundTruth:دو ہزار سولہ
#
# 0.Transcribed:دو ہزار سولہ
# 0.LMCorrected:دو ہزار سولہ
#
# 1.GroundTruth:دو ہزار گیارہ
#
# 1.Transcribed:دو ہزار گیارہ
# 1.LMCorrected:دو ہزار گیارہ
#
# 2.GroundTruth:انتیس
#
# 2.Transcribed:انتیس
# 2.LMCorrected:انتیس
#
# 4.GroundTruth:پچیس
#
# 4.Transcribed:پچیس
# 4.LMCorrected:پچیس
#
# 5.GroundTruth:ستر
#
# 5.Transcribed:ستر
# 5.LMCorrected:ستر
#
# 6.GroundTruth:تو کسی نے غالب کی توجہ ذوق کی طرف مبذول کی
#
# 6.Transcribed:تو کسیے نے غالب کی تووجو وکی طرفزو کی
# 6.LMCorrected:تو کسی نے غالب کی توجہ کی طرف کی
#
# 8.GroundTruth:سینتالیس
#
# 8.Transcribed:سینتالیس
# 8.LMCorrected:سینتالیس
#
# 9.GroundTruth:میں نویں پاس ہوں
#
# 9.Transcribed:میں نوائیہ پاس ہوں
# 9.LMCorrected:میں نواسی پاس ہوں
#
# 10.GroundTruth:ستاون
#
# 10.Transcribed:ستاون
# 10.LMCorrected:ستاون
#
# 13.GroundTruth:پچانوے
#
# 13.Transcribed:پنچانوے
# 13.LMCorrected:پچانوے
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:میں نے بوئییہ تعلیم  حال نہی کی ہے
# 0.LMCorrected:میں نے بوئییہ تعلیم حال نہیں کی ہے
#
# 3.GroundTruth:دو ہزار دس
#
# 3.Transcribed:دو ہزار تاس
# 3.LMCorrected:دو ہزار اس
#
# 6.GroundTruth:میری عمر بائیس سال ہے
#
# 6.Transcribed:میریں مر بائیس  سال ہے
# 6.LMCorrected:میری عمر بائیس سال ہے
#
# 7.GroundTruth:ترانوے
#
# 7.Transcribed:ترنوے
# 7.LMCorrected:ترانوے
#
# 8.GroundTruth:بانوے
#
# 8.Transcribed:بانوے
# 8.LMCorrected:بانوے
#
# 9.GroundTruth:سو
#
# 9.Transcribed:سو
# 9.LMCorrected:سو
#
# 10.GroundTruth:انيس سو تراسی
#
# 10.Transcribed:انس سو تراس
# 10.LMCorrected:انس سو تراسی
#
# 11.GroundTruth:تین
#
# 11.Transcribed:تین
# 11.LMCorrected:تین
#
# 13.GroundTruth:اب زوال کا شکار ہونے لگے
#
# 13.Transcribed:اب وال کا شکا ہونلکں
# 13.LMCorrected:اب زوال کا شکار ہونٹوں
#
# 14.GroundTruth:میری عمر بیس سال ہے
#
# 14.Transcribed:میری عمر بیس سال ہے
# 14.LMCorrected:میری عمر بیس سال ہے
#
# 0.GroundTruth:سترہ
#
# 0.Transcribed:سترہ
# 0.LMCorrected:سترہ
#
# 1.GroundTruth:ستتر
#
# 1.Transcribed:صتتر
# 1.LMCorrected:ستتر
#
# 3.GroundTruth:ترسٹھ
#
# 3.Transcribed:تسٹھ
# 3.LMCorrected:ترسٹھ
#
# 4.GroundTruth:انيس سو چھیانوے
#
# 4.Transcribed:انس سو چھانوے
# 4.LMCorrected:انس سو چھیانوے
#
# 5.GroundTruth:آٹھ
#
# 5.Transcribed:آٹھ
# 5.LMCorrected:آٹھ
#
# 6.GroundTruth:ترانوے
#
# 6.Transcribed:ترانوے
# 6.LMCorrected:ترانوے
#
# 7.GroundTruth:اٹھہتر
#
# 7.Transcribed:اٹھہتر
# 7.LMCorrected:اٹھہتر
#
# 8.GroundTruth:باون
#
# 8.Transcribed:باون
# 8.LMCorrected:باون
#
# 9.GroundTruth:ساٹھ
#
# 9.Transcribed:سھاھٹھ
# 9.LMCorrected:ساٹھ
#
# 12.GroundTruth:اکیس
#
# 12.Transcribed:اکیس
# 12.LMCorrected:اکیس
#
# 13.GroundTruth:تینتالیس
#
# 13.Transcribed:تینتالیس
# 13.LMCorrected:تینتالیس
#
# 0.GroundTruth:چھپن
#
# 0.Transcribed:چھپن
# 0.LMCorrected:چھپن
#
# 2.GroundTruth:میں نے دو ہزار اٹھارہ میں ایف ایس سی کی ہے
#
# 2.Transcribed:میں نے دو ہزار اا میںیف یس س کی ہے
# 2.LMCorrected:میں نے دو ہزار اس میں یس س کی ہے
#
# 4.GroundTruth:دو ہزار آٹھ
#
# 4.Transcribed:دو ہزار آٹھ
# 4.LMCorrected:دو ہزار آٹھ
#
# 6.GroundTruth:دو ہزار چھ
#
# 6.Transcribed:دو ہزار چھ
# 6.LMCorrected:دو ہزار چھ
#
# 9.GroundTruth:دو ہزار سات
#
# 9.Transcribed:دو ہزار سات
# 9.LMCorrected:دو ہزار سات
#
# 11.GroundTruth:دو ہزار چار
#
# 11.Transcribed:دو ہزار چار
# 11.LMCorrected:دو ہزار چار
#
# 13.GroundTruth:میرا تجربہ دس سال ہے
#
# 13.Transcribed:میراں تجیبہ دسال ہے
# 13.LMCorrected:میرا تجربہ سال ہے
#
# 14.GroundTruth:ستاسی
#
# 14.Transcribed:ستاسی
# 14.LMCorrected:ستاسی
#
# 15.GroundTruth:دو ہزار گیارہ
#
# 15.Transcribed:دو ہزاے گیرہ
# 15.LMCorrected:دو ہزار گیارہ
#
# 0.GroundTruth:میں نے مڈل  تک پڑھا ہے
#
# 0.Transcribed:میں نے بیڈے تک پڑھا ہے
# 0.LMCorrected:میں نے بیٹے تک پڑھا ہے
#
# 2.GroundTruth:انيس سو ترانوے
#
# 2.Transcribed:اانس سو ترانوے
# 2.LMCorrected:انس سو ترانوے
#
# 4.GroundTruth:میرا فون نمبر یہ ہے 03001357924
#
# 4.Transcribed:میرا فون نمبر یہ ہے
# 4.LMCorrected:میرا فون نمبر یہ ہے
#
# 5.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 5.Transcribed:میں نے کوئی تعلیم حصل نہی کی ہے
# 5.LMCorrected:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 9.GroundTruth:پندرہ
#
# 9.Transcribed:پندرہ
# 9.LMCorrected:پندرہ
#
# 10.GroundTruth:میرا تجربہ پندرہ سال ہے
#
# 10.Transcribed:میرا تجرباہ پندہ سال کا ہے
# 10.LMCorrected:میرا تجربہ پندرہ سال کا ہے
#
# 11.GroundTruth:میرا پیشہ ڈلیوری بوائے ہے
#
# 11.Transcribed:میرا پیکشہ لیوری بوائے ہے
# 11.LMCorrected:میرا پیشہ ڈلیوری بوائے ہے
#
# 12.GroundTruth:چوہتر
#
# 12.Transcribed:چوہتر
# 12.LMCorrected:چوہتر
#
# 13.GroundTruth:اٹھاون
#
# 13.Transcribed:اٹھاون
# 13.LMCorrected:اٹھاون
#
# 3.GroundTruth:بیالیس
#
# 3.Transcribed:بیالیس
# 3.LMCorrected:بیالیس
#
# 5.GroundTruth:میں پلمبر کا کام جانتا ہوں
#
# 5.Transcribed:ممیں پلمبر کا کاسانتا ہوں
# 5.LMCorrected:میں پلمبر کا کاسانتا ہوں
#
# 8.GroundTruth:پچپن
#
# 8.Transcribed:پچپن
# 8.LMCorrected:پچپن
#
# 12.GroundTruth:میرا نام احمد ہے
#
# 12.Transcribed:میرا نام پنمر ہے
# 12.LMCorrected:میرا نام پر ہے
#
# 14.GroundTruth:میرا نام بلال ہے
#
# 14.Transcribed:میراے نام پرار ہے
# 14.LMCorrected:میرا نام قرار ہے
#
# 15.GroundTruth:چھیاسی
#
# 15.Transcribed:چھیاسی
# 15.LMCorrected:چھیاسی
#
# 2.GroundTruth:میر کہتے ہیں
#
# 2.Transcribed:مر کہتے ہی
# 2.LMCorrected:میر کہتے ہی
#
# 4.GroundTruth:آپ جانتے ہیں کہ فرشتوں کے حوالے سے روایت ہم پروں کی بات کرتے ہیں
#
# 4.Transcribed:آپ جادے یے کہ فریشتو کے حوالے سے پریوائتن ہم پرو کی بات کرتے ہں
# 4.LMCorrected:آپ جائے یے کہ فرشتوں کے حوالے سے پریوائتن ہم پروں کی بات کرتے ہیں
#
# 5.GroundTruth:چوبیس
#
# 5.Transcribed:چونیس
# 5.LMCorrected:چوبیس
#
# 6.GroundTruth:اڑتالیس
#
# 6.Transcribed:پڑتالیس
# 6.LMCorrected:اڑتالیس
#
# 7.GroundTruth:اس کے بعد ہم بات کریں گے اگلے دو اشعار پر
#
# 7.Transcribed:اس کے باعد م بات کرے جیہ الے دو شار پر
# 7.LMCorrected:اس کے بعد م بات کرے یہ اگلے دو چار پر
#
# 9.GroundTruth:اٹھسٹھ
#
# 9.Transcribed:اڑھسٹھ
# 9.LMCorrected:اٹھسٹھ
#
# 10.GroundTruth:اور یہی متاثرہ شاعری
#
# 10.Transcribed:اور ہیم متاسرا شاری
# 10.LMCorrected:اور ہم متاثرہ شاعری
#
# 12.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 12.Transcribed:میرا پانچچ  سال کا تجربہ ہے
# 12.LMCorrected:میرا پانچ سال کا تجربہ ہے
#
# 1.GroundTruth:دو ہزار
#
# 1.Transcribed:دو ہزار
# 1.LMCorrected:دو ہزار
#
# 2.GroundTruth:انيس سو اٹھاسی
#
# 2.Transcribed:انس سو اٹھاسی
# 2.LMCorrected:انس سو اٹھاسی
#
# 3.GroundTruth:دو ہزار بیس
#
# 3.Transcribed:دو ہزار بیس
# 3.LMCorrected:دو ہزار بیس
#
# 4.GroundTruth:میری عمر چالیس سال ہے
#
# 4.Transcribed:میریں عمر چایس ساے ہے
# 4.LMCorrected:میری عمر چالیس سال ہے
#
# 7.GroundTruth:چالیس
#
# 7.Transcribed:چالیس
# 7.LMCorrected:چالیس
#
# 8.GroundTruth:اڑتیس
#
# 8.Transcribed:اڑتیس
# 8.LMCorrected:اڑتیس
#
# 9.GroundTruth:چھیاسی
#
# 9.Transcribed:چھیاسی
# 9.LMCorrected:چھیاسی
#
# 10.GroundTruth:اکانوے
#
# 10.Transcribed:اکانوے
# 10.LMCorrected:اکانوے
#
# 13.GroundTruth:میں نے دو ہزار اٹھارہ میں بارہویں مکمل کی ہے
#
# 13.Transcribed:میں نے دو ہزار اٹھارم میں بارویم کمل کیہ ہے
# 13.LMCorrected:میں نے دو ہزار اٹھارہ میں بارہویں مکمل کی ہے
#
# 14.GroundTruth:اٹھہتر
#
# 14.Transcribed:پاٹھہتہ
# 14.LMCorrected:اٹھہتر
#
# 15.GroundTruth:میں تین سال سے یہ کام کر رہی ہو
#
# 15.Transcribed:میں ت سال ے یہ کام کاروی ہو
# 15.LMCorrected:میں ت سال سے یہ کام کاری ہو
#
# 0.GroundTruth:اسی
#
# 0.Transcribed:اسی
# 0.LMCorrected:اسی
#
# 1.GroundTruth:دو ہزار چودہ
#
# 1.Transcribed:دو ہزار چودہ
# 1.LMCorrected:دو ہزار چودہ
#
# 2.GroundTruth:تیس
#
# 2.Transcribed:تیس
# 2.LMCorrected:تیس
#
# 3.GroundTruth:میرا پیشہ پلمبر ہے
#
# 3.Transcribed:میرا پیشہ پلمبر ہے
# 3.LMCorrected:میرا پیشہ پلمبر ہے
#
# 5.GroundTruth:ہم نے گزشتہ لیکچر میں میر تقی میر کی شامل نصاب دو غزلیات کا مطالعہ کیا
#
# 5.Transcribed:ہم نے پشکلکچر میں میر طکینیر کی شالے نساب دو غزیا کا مطالہ کیا
# 5.LMCorrected:ہم نے پشکلکچر میں میر طکینیر کی والے نصاب دو غزلیات کا مطالعہ کیا
#
# 9.GroundTruth:اکہتر
#
# 9.Transcribed:اکہتر
# 9.LMCorrected:اکہتر
#
# 11.GroundTruth:میں نے دو ہزار سولہ میں ایف ایس سی مکمل کی ہے
#
# 11.Transcribed:میں نے دو ہزار سولا میں ایف اسی مکمل کی ہے
# 11.LMCorrected:میں نے دو ہزار سولہ میں ایف اسی مکمل کی ہے
#
# 13.GroundTruth:تین
#
# 13.Transcribed:تین
# 13.LMCorrected:تین
#
# 1.GroundTruth:انيس سو اکانوے
#
# 1.Transcribed:انس سو اکنکانوے
# 1.LMCorrected:انس سو اکانوے
#
# 2.GroundTruth:پینتیس
#
# 2.Transcribed:پینبیس
# 2.LMCorrected:پینتیس
#
# 3.GroundTruth:ستاون
#
# 3.Transcribed:ستاون
# 3.LMCorrected:ستاون
#
# 4.GroundTruth:چار
#
# 4.Transcribed:چیار
# 4.LMCorrected:چار
#
# 6.GroundTruth:انتالیس
#
# 6.Transcribed:انتالیس
# 6.LMCorrected:انتالیس
#
# 8.GroundTruth:انيس سو ستاسی
#
# 8.Transcribed:اانس سو ستاسی
# 8.LMCorrected:انس سو ستاسی
#
# 10.GroundTruth:میں نے ایف ایس سی تک تعلیم حاصل کی ہے
#
# 10.Transcribed:میں نے اف سسی تک تعلیم حاص کیہ
# 10.LMCorrected:میں نے اف سی تک تعلیم حاصل کی
#
# 11.GroundTruth:میں ڈرائیور ہوں
#
# 11.Transcribed:میں داار ہوں
# 11.LMCorrected:میں دار ہوں
#
# 14.GroundTruth:دو ہزار آٹھ
#
# 14.Transcribed:دو ہزار آٹھ
# 14.LMCorrected:دو ہزار آٹھ
#
# 15.GroundTruth:ترسٹھ
#
# 15.Transcribed:ترسٹھ
# 15.LMCorrected:ترسٹھ
#
# 0.GroundTruth:میں نے دو ہزار بارہ  میں بارہویں مکمل کی ہے
#
# 0.Transcribed:میں نے دو ہزار بار میں بارویں مکرم  کی ہے
# 0.LMCorrected:میں نے دو ہزار بار میں بارہویں محرم کی ہے
#
# 1.GroundTruth:ستاون
#
# 1.Transcribed:ستاون
# 1.LMCorrected:ستاون
#
# 2.GroundTruth:تیس
#
# 2.Transcribed:تیس
# 2.LMCorrected:تیس
#
# 5.GroundTruth:اکانوے
#
# 5.Transcribed:اکیانوے
# 5.LMCorrected:اکانوے
#
# 6.GroundTruth:اٹھاسی
#
# 6.Transcribed:اٹھاسی
# 6.LMCorrected:اٹھاسی
#
# 7.GroundTruth:میں نے دو ہزار آٹھ میں نویں مکمل کی ہے
#
# 7.Transcribed:میں نے دو ہزار آرھمیں نہویہ محمل کی ہے
# 7.LMCorrected:میں نے دو ہزار آٹھویں نویں مکمل کی ہے
#
# 9.GroundTruth:تیرہ
#
# 9.Transcribed:تیرہ
# 9.LMCorrected:تیرہ
#
# 11.GroundTruth:میرا پیشہ ڈرائیور ہے
#
# 11.Transcribed:میرا پیشہ ڈرایور ہے
# 11.LMCorrected:میرا پیشہ ڈرائیور ہے
#
# 12.GroundTruth:دو ہزار انیس
#
# 12.Transcribed:دو ہزار انیس
# 12.LMCorrected:دو ہزار انیس
#
# 13.GroundTruth:ترسٹھ
#
# 13.Transcribed:ترسٹھ
# 13.LMCorrected:ترسٹھ
#
# 15.GroundTruth:میں نے میٹرک  تک تعلیم حاصل کی ہے
#
# 15.Transcribed:میں نے منیٹرک تک تعلیمحاصل کی ہے
# 15.LMCorrected:میں نے میٹرک تک تعلیمحاصل کی ہے
#
# 2.GroundTruth:انیس
#
# 2.Transcribed:انیس
# 2.LMCorrected:انیس
#
# 4.GroundTruth:نوے
#
# 4.Transcribed:نوے
# 4.LMCorrected:نوے
#
# 5.GroundTruth:ساٹھ
#
# 5.Transcribed:ساٹھ
# 5.LMCorrected:ساٹھ
#
# 7.GroundTruth:میں کارپینٹر ہو
#
# 7.Transcribed:میں کارپینٹر ہوں
# 7.LMCorrected:میں کارپینٹر ہوں
#
# 8.GroundTruth:میں ڈرائیور ہوں
#
# 8.Transcribed:میں ڈگور ہوں
# 8.LMCorrected:میں اور ہوں
#
# 11.GroundTruth:اکیاسی
#
# 11.Transcribed:اککاسی
# 11.LMCorrected:اکیاسی
#
# 14.GroundTruth:اکتالیس
#
# 14.Transcribed:اکتالیس
# 14.LMCorrected:اکتالیس
#
# 1.GroundTruth:پینتالیس
#
# 1.Transcribed:پینٹتالیس
# 1.LMCorrected:پینتالیس
#
# 2.GroundTruth:اٹھاسی
#
# 2.Transcribed:اٹھاسی
# 2.LMCorrected:اٹھاسی
#
# 3.GroundTruth:پندرہ
#
# 3.Transcribed:پندرہ
# 3.LMCorrected:پندرہ
#
# 4.GroundTruth:اکیاون
#
# 4.Transcribed:اکیان
# 4.LMCorrected:اکیاون
#
# 8.GroundTruth:دو ہزار دو
#
# 8.Transcribed:دو ہزار د
# 8.LMCorrected:دو ہزار د
#
# 9.GroundTruth:انتالیس
#
# 9.Transcribed:انتالیس
# 9.LMCorrected:انتالیس
#
# 10.GroundTruth:اور اس
#
# 10.Transcribed:اور اس
# 10.LMCorrected:اور اس
#
# 11.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 11.Transcribed:میف وئییے کوئی سعلیم حاصو ک ہے
# 11.LMCorrected:میں ویسے کوئی تعلیم حاصل ک ہے
#
# 13.GroundTruth:دو ہزار پندرہ
#
# 13.Transcribed:دو ہزار پندرہہ
# 13.LMCorrected:دو ہزار پندرہ
#
# 14.GroundTruth:دو ہزار تین
#
# 14.Transcribed:دو ہزار تی
# 14.LMCorrected:دو ہزار تین
#
# 15.GroundTruth:ترانوے
#
# 15.Transcribed:ترانوے
# 15.LMCorrected:ترانوے
#
# 0.GroundTruth:باسٹھ
#
# 0.Transcribed:پاسٹھ
# 0.LMCorrected:باسٹھ
#
# 1.GroundTruth:اٹھاون
#
# 1.Transcribed:اٹھاون
# 1.LMCorrected:اٹھاون
#
# 2.GroundTruth:پندرہ
#
# 2.Transcribed:پندرہ
# 2.LMCorrected:پندرہ
#
# 7.GroundTruth:انيس سو نواسی
#
# 7.Transcribed:انس سو نواسی
# 7.LMCorrected:انس سو نواسی
#
# 9.GroundTruth:میں نے دسویں جماعت تک پڑھا ہے
#
# 9.Transcribed:میں نے دسویں جموہت تک پڑڑھ ہے
# 9.LMCorrected:میں نے دسویں جماعت تک پڑھ ہے
#
# 10.GroundTruth:یعنی مقتے میں غالب کہتے ہیں
#
# 10.Transcribed:ینی مققتے میں غالب کہتے ہ
# 10.LMCorrected:یعنی مقتے میں غالب کہتے ہ
#
# 11.GroundTruth:میں نے دو ہزار تیرہ میں میٹرک کیا ہے
#
# 11.Transcribed:میں نے دو ہزار تویں میشک کیا ہے
# 11.LMCorrected:میں نے دو ہزار تھیں میں کیا ہے
#
# 12.GroundTruth:احساس کیا کہ شاید
#
# 12.Transcribed:احساز کیا کہ شائد
# 12.LMCorrected:احساس کیا کہ شاید
#
# 14.GroundTruth:میں نے دو ہزار سولہ میں میٹرک کیا ہے
#
# 14.Transcribed:میں نے دو ہزار سولہ میں میٹریک کیا ہے
# 14.LMCorrected:میں نے دو ہزار سولہ میں میٹرک کیا ہے
#
# 15.GroundTruth:میرا چھ سال کا تجربہ ہے
#
# 15.Transcribed:میرا چھ سال کا تجربہ ہے
# 15.LMCorrected:میرا چھ سال کا تجربہ ہے
#
# 1.GroundTruth:دو ہزار انیس
#
# 1.Transcribed:دو ہزار انیس
# 1.LMCorrected:دو ہزار انیس
#
# 2.GroundTruth:دو ہزار پانچ
#
# 2.Transcribed:دو ہزار پنچ
# 2.LMCorrected:دو ہزار پانچ
#
# 4.GroundTruth:چھیاسٹھ
#
# 4.Transcribed:چھیراسٹھ
# 4.LMCorrected:چھیاسٹھ
#
# 5.GroundTruth:میں کارپینٹری کا کام جانتی ہوں
#
# 5.Transcribed:میں کار پینٹری کا کام جانکی ہوں
# 5.LMCorrected:میں کار پینٹر کا کام جانتی ہوں
#
# 10.GroundTruth:میرا پیشہ پلمبر ہے
#
# 10.Transcribed:میرا پیشہ پلبر ہے
# 10.LMCorrected:میرا پیشہ پلمبر ہے
#
# 11.GroundTruth:دو ہزار اٹھارہ
#
# 11.Transcribed:دو ہزار اٹھار
# 11.LMCorrected:دو ہزار اٹھارہ
#
# 15.GroundTruth:تیرہ
#
# 15.Transcribed:تیرہ
# 15.LMCorrected:تیرہ
#
# 0.GroundTruth:گیارہ
#
# 0.Transcribed:گیرہ
# 0.LMCorrected:گیارہ
#
# 1.GroundTruth:میں پلمبر کا کام جانتا ہوں
#
# 1.Transcribed:میں پلمبر کا کام جنتا ہوں
# 1.LMCorrected:میں پلمبر کا کام جانتا ہوں
#
# 3.GroundTruth:میرا پیشہ ڈرائیور ہے
#
# 3.Transcribed:میرا پیشہ ڈدئیور ہے
# 3.LMCorrected:میرا پیشہ ڈرائیور ہے
#
# 4.GroundTruth:تراسی
#
# 4.Transcribed:تیراسی
# 4.LMCorrected:تراسی
#
# 5.GroundTruth:میں ڈیلیوری بوائے ہوں
#
# 5.Transcribed:میں ڈلیوری بوائے ہوں
# 5.LMCorrected:میں ڈلیوری بوائے ہوں
#
# 6.GroundTruth:دو ہزار ایک
#
# 6.Transcribed:دو ہزار ایبگ
# 6.LMCorrected:دو ہزار ایبک
#
# 7.GroundTruth:میں نے سات سال کام کیا ہے
#
# 7.Transcribed:میں نے سا سال کام کیا ہے
# 7.LMCorrected:میں نے سا سال کام کیا ہے
#
# 8.GroundTruth:میں دس سال سے یہ کام کر رہا ہوں
#
# 8.Transcribed:میں دس سال سے یہ کام ہکر ر ہوں
# 8.LMCorrected:میں دس سال سے یہ کام کر ر ہوں
#
# 10.GroundTruth:انيس سو چوراسی
#
# 10.Transcribed:انس سو چھوراسی
# 10.LMCorrected:انس سو چوراسی
#
# 11.GroundTruth:دو ہزار دس
#
# 11.Transcribed:دو ہزار دس
# 11.LMCorrected:دو ہزار دس
#
# 14.GroundTruth:چالیس
#
# 14.Transcribed:چالیس
# 14.LMCorrected:چالیس
#
# 2.GroundTruth:اس کے بعد
#
# 2.Transcribed:اس کے باد
# 2.LMCorrected:اس کے بعد
#
# 7.GroundTruth:میں نے چارسال کام کیا ہے
#
# 7.Transcribed:مینے چرسال کام کیا ہوے
# 7.LMCorrected:مینے چارسال کام کیا ہے
#
# 10.GroundTruth:میرا تجربہ سات سال ہے
#
# 10.Transcribed:میرا تجرربہ ساہ سال ہ
# 10.LMCorrected:میرا تجربہ سات سال ہ
#
# 11.GroundTruth:انيس سو ستانوے
#
# 11.Transcribed:انس سو ستانو
# 11.LMCorrected:انس سو ستانوے
#
# 12.GroundTruth:پچپن
#
# 12.Transcribed:پچپن
# 12.LMCorrected:پچپن
#
# 13.GroundTruth:ترانوے
#
# 13.Transcribed:ترانوے
# 13.LMCorrected:ترانوے
#
# 15.GroundTruth:اٹھائیس
#
# 15.Transcribed:اٹھائیس
# 15.LMCorrected:اٹھائیس
#
# 0.GroundTruth:میں پلمبر ہوں
#
# 0.Transcribed:میں پلمبر ہوں
# 0.LMCorrected:میں پلمبر ہوں
#
# 1.GroundTruth:پچپن
#
# 1.Transcribed:پچپن
# 1.LMCorrected:پچپن
#
# 4.GroundTruth:بیاسی
#
# 4.Transcribed:مبیاسی
# 4.LMCorrected:بیاسی
#
# 8.GroundTruth:انيس سو چھیاسی
#
# 8.Transcribed:انس سو چھیاسی
# 8.LMCorrected:انس سو چھیاسی
#
# 9.GroundTruth:بیس
#
# 9.Transcribed:بیس
# 9.LMCorrected:بیس
#
# 14.GroundTruth:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 14.Transcribed:میں نے دو ہزار دس میں نٹرک کیا ہے
# 14.LMCorrected:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 0.GroundTruth:اکہتر
#
# 0.Transcribed:اکہتر
# 0.LMCorrected:اکہتر
#
# 2.GroundTruth:سولہ
#
# 2.Transcribed:سولہ
# 2.LMCorrected:سولہ
#
# 3.GroundTruth:تہتر
#
# 3.Transcribed:تیہتر
# 3.LMCorrected:تہتر
#
# 4.GroundTruth:اکتالیس
#
# 4.Transcribed:اکتالیس
# 4.LMCorrected:اکتالیس
#
# 5.GroundTruth:میں ڈرائیور ہوں
#
# 5.Transcribed:میں ڈرائیور ہوں
# 5.LMCorrected:میں ڈرائیور ہوں
#
# 7.GroundTruth:اکتیس
#
# 7.Transcribed:اکہتیس
# 7.LMCorrected:اکتیس
#
# 10.GroundTruth:سو
#
# 10.Transcribed:سو
# 10.LMCorrected:سو
#
# 11.GroundTruth:میں نے دو ہزار بیس میں بی اے مکمل کی ہے
#
# 11.Transcribed:میں نے دو ہزار بیس یں بی وکل ی ہے
# 11.LMCorrected:میں نے دو ہزار بیس یں بی کل ی ہے
#
# 13.GroundTruth:بائیس
#
# 13.Transcribed:بائس
# 13.LMCorrected:بائیس
#
# 14.GroundTruth:اٹھاون
#
# 14.Transcribed:اٹھاون
# 14.LMCorrected:اٹھاون
#
# 0.GroundTruth:نو
#
# 0.Transcribed:نو
# 0.LMCorrected:نو
#
# 1.GroundTruth:دو ہزار چار
#
# 1.Transcribed:دو ہزار سچار
# 1.LMCorrected:دو ہزار چار
#
# 2.GroundTruth:دو ہزار سولہ
#
# 2.Transcribed:دو ہزار سولہ
# 2.LMCorrected:دو ہزار سولہ
#
# 3.GroundTruth:انہتر
#
# 3.Transcribed:انہتر
# 3.LMCorrected:انہتر
#
# 4.GroundTruth:تراسی
#
# 4.Transcribed:تراسی
# 4.LMCorrected:تراسی
#
# 7.GroundTruth:چار
#
# 7.Transcribed:چار
# 7.LMCorrected:چار
#
# 8.GroundTruth:چوراسی
#
# 8.Transcribed:چوراسی
# 8.LMCorrected:چوراسی
#
# 9.GroundTruth:انيس سو چورانوے
#
# 9.Transcribed:انس سو چورانوے
# 9.LMCorrected:انس سو چورانوے
#
# 11.GroundTruth:دو ہزار چودہ
#
# 11.Transcribed:دو ہزار چولہ
# 11.LMCorrected:دو ہزار چودہ
#
# 12.GroundTruth:مجھے یہ کام کرتے ہوئے دس سال کا عرصہ ہو گیا ہے
#
# 12.Transcribed:مجے یہ کام کرتے ہوئے بر سسال کا عصا ہو کا ہے
# 12.LMCorrected:مجھے یہ کام کرتے ہوئے بر سال کا عطا ہو کا ہے
#
# 13.GroundTruth:دو ہزار پانچ
#
# 13.Transcribed:دو ہزار پا
# 13.LMCorrected:دو ہزار پا
#
# 14.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 14.Transcribed:میرا اس کام میں کوئی تررک ہے
# 14.LMCorrected:میرا اس کام میں کوئی ترک ہے
#
# 15.GroundTruth:دو ہزار نو
#
# 15.Transcribed:دو ہزار دو
# 15.LMCorrected:دو ہزار دو
#
# 0.GroundTruth:دو ہزار پندرہ
#
# 0.Transcribed:دو ہزار پندرہ
# 0.LMCorrected:دو ہزار پندرہ
#
# 1.GroundTruth:میرا دو سال کا تجربہ ہے
#
# 1.Transcribed:میرا دو سال کاتجربہ ہے
# 1.LMCorrected:میرا دو سال تجربہ ہے
#
# 2.GroundTruth:تیس
#
# 2.Transcribed:تیس
# 2.LMCorrected:تیس
#
# 7.GroundTruth:انيس سو چوراسی
#
# 7.Transcribed:انس سو چوراس
# 7.LMCorrected:انس سو چوراسی
#
# 8.GroundTruth:میں نے دسویں  جماعت تک پڑھا ہے
#
# 8.Transcribed:مں نے دزں جما تک پڑھا ہے
# 8.LMCorrected:میں نے دوں جا تک پڑھا ہے
#
# 9.GroundTruth:انيس سو بانوے
#
# 9.Transcribed:انس سو بانوے
# 9.LMCorrected:انس سو بانوے
#
# 10.GroundTruth:دس
#
# 10.Transcribed:دس
# 10.LMCorrected:دس
#
# 11.GroundTruth:شاعری کا آغاز کیا
#
# 11.Transcribed:شای کا آغاز کیا
# 11.LMCorrected:شاہ کا آغاز کیا
#
# 14.GroundTruth:میں نے دو سال کام کیا ہے
#
# 14.Transcribed:میں نے دو سال کام کیا ہے
# 14.LMCorrected:میں نے دو سال کام کیا ہے
#
# 15.GroundTruth:اکیاون
#
# 15.Transcribed:اکاون
# 15.LMCorrected:اکیاون
#
# 0.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 0.Transcribed:میرا اس کام میں کوئی تجرب ہ
# 0.LMCorrected:میرا اس کام میں کوئی تجربہ ہ
#
# 2.GroundTruth:میں نے  دو ہزار پندرہ میں ڈپلومہ کیا ہے
#
# 2.Transcribed:میں نے دو  ہزار پندرہ میں ڈل ماہ کیا ہے
# 2.LMCorrected:میں نے دو ہزار پندرہ میں دل ماہ کیا ہے
#
# ...
#
# 2.Transcribed:میرا فو نمبر یہ ہے
# 2.LMCorrected:میرا فون نمبر یہ ہے
#
# 4.GroundTruth:چھیالیس
#
# 4.Transcribed:چھیالیس
# 4.LMCorrected:چھیالیس
#
# 5.GroundTruth:میرا نام گلزار ہے
#
# 5.Transcribed:میرا نام کوزار ہے
# 5.LMCorrected:میرا نام گلزار ہے
#
# 7.GroundTruth:میں کراچی میں رہتا ہوں
#
# 7.Transcribed:میں کراچی میں نرہتا ہوں
# 7.LMCorrected:میں کراچی میں رہتا ہوں
#
# 8.GroundTruth:چھپن
#
# 8.Transcribed:چھپن
# 8.LMCorrected:چھپن
#
# 13.GroundTruth:پچپن
#
# 13.Transcribed:پچپن
# 13.LMCorrected:پچپن
#
# 14.GroundTruth:میرا نام علی ہے
#
# 14.Transcribed:میرا نام عہلی ہے
# 14.LMCorrected:میرا نام علی ہے
#
# 15.GroundTruth:اٹھارہ
#
# 15.Transcribed:اٹارہ
# 15.LMCorrected:اٹھارہ
#
# 0.GroundTruth:انيس سو نوے
#
# 0.Transcribed:انس سو نوے
# 0.LMCorrected:انس سو نوے
#
# 1.GroundTruth:انہتر
#
# 1.Transcribed:انہتر
# 1.LMCorrected:انہتر
#
# 10.GroundTruth:دو ہزار نو
#
# 10.Transcribed:دو ہزار نو
# 10.LMCorrected:دو ہزار نو
#
# 14.GroundTruth:دو ہزار بارہ
#
# 14.Transcribed:دو ہزار بارہ
# 14.LMCorrected:دو ہزار بارہ
#
# 15.GroundTruth:میں نے دسویں جماعت تک پڑھا ہے
#
# 15.Transcribed:میں نے دسویں جماعت تک پڑھا ہے
# 15.LMCorrected:میں نے دسویں جماعت تک پڑھا ہے
#
# 0.GroundTruth:دو ہزار
#
# 0.Transcribed:دو ہزار
# 0.LMCorrected:دو ہزار
#
# 1.GroundTruth:اسی
#
# 1.Transcribed:اسی
# 1.LMCorrected:اسی
#
# 2.GroundTruth:دو ہزار پندرہ
#
# 2.Transcribed:دو ہزار اندرہ
# 2.LMCorrected:دو ہزار پندرہ
#
# 3.GroundTruth:دو ہزار تیرہ
#
# 3.Transcribed:دو ہزار تیرہ
# 3.LMCorrected:دو ہزار تیرہ
#
# 5.GroundTruth:ساٹھ
#
# 5.Transcribed:ساٹھ
# 5.LMCorrected:ساٹھ
#
# 6.GroundTruth:میں نے نویں جماعت تک پڑھا ہے
#
# 6.Transcribed:میں نے ن جماہ تک پڑھا ہے
# 6.LMCorrected:میں نے ن جمال تک پڑھا ہے
#
# 9.GroundTruth:انيس سو ننانوے
#
# 9.Transcribed:انس سو نننوے
# 9.LMCorrected:انس سو ننانوے
#
# 10.GroundTruth:دو ہزار پندرہ
#
# 10.Transcribed:دو ہزار پندرہ
# 10.LMCorrected:دو ہزار پندرہ
#
# 11.GroundTruth:دو ہزار بارہ
#
# 11.Transcribed:دو ہزار بارہ
# 11.LMCorrected:دو ہزار بارہ
#
# 12.GroundTruth:میں الیکٹریشن کا کام جانتا ہوں
#
# 12.Transcribed:میں ایلیکٹریشن کا کام جانتا ہوں
# 12.LMCorrected:میں الیکٹریشن کا کام جانتا ہوں
#
# 13.GroundTruth:اٹھہتر
#
# 13.Transcribed:اٹھہتر
# 13.LMCorrected:اٹھہتر
#
# 14.GroundTruth:انيس سو ننانوے
#
# 14.Transcribed:انس سو ننانوے
# 14.LMCorrected:انس سو ننانوے
#
# 0.GroundTruth:دو ہزار پانچ
#
# 0.Transcribed:دو ہزار پاچ
# 0.LMCorrected:دو ہزار پانچ
#
# 2.GroundTruth:دو ہزار سترہ
#
# 2.Transcribed:دو ہزار سترہ
# 2.LMCorrected:دو ہزار سترہ
#
# 3.GroundTruth:میں نے دو ہزار چودہ میں دسویں مکمل کی ہے
#
# 3.Transcribed:میں نے دو ہزار چودہ میں دسویں عمل کی ہے
# 3.LMCorrected:میں نے دو ہزار چودہ میں دسویں عمل کی ہے
#
# 4.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 4.Transcribed:میں کارپینٹر ا کام جانتا
# 4.LMCorrected:میں کارپینٹر ا کام جانتا
#
# 6.GroundTruth:چھیالیس
#
# 6.Transcribed:چھیالیس
# 6.LMCorrected:چھیالیس
#
# 9.GroundTruth:چوالیس
#
# 9.Transcribed:چوالیس
# 9.LMCorrected:چوالیس
#
# 11.GroundTruth:چھیالیس
#
# 11.Transcribed:چھیالیس
# 11.LMCorrected:چھیالیس
#
# 12.GroundTruth:دو
#
# 12.Transcribed:دو
# 12.LMCorrected:دو
#
# 13.GroundTruth:میرا پیشہ الیکٹریشن ہے
#
# 13.Transcribed:میرا پیشہ الیکٹریش ہے
# 13.LMCorrected:میرا پیشہ الیکٹریشن ہے
#
# 14.GroundTruth:میں اسلام آباد میں رہتا ہوں
#
# 14.Transcribed:میں ڈلاآبادر میں رہتا ہوں
# 14.LMCorrected:میں ڈلاآبادر میں رہتا ہوں
#
# 15.GroundTruth:اسی سال یہ کام کرنا شروع کیا ہے
#
# 15.Transcribed:اسی سال یہ کام کرنہ شرول کیا ہے
# 15.LMCorrected:اسی سال یہ کام کرنا شروع کیا ہے
#
# 0.GroundTruth:ایک
#
# 0.Transcribed:گیک
# 0.LMCorrected:ایک
#
# 1.GroundTruth:ستاون
#
# 1.Transcribed:ستان
# 1.LMCorrected:ستاون
#
# 3.GroundTruth:اٹھارہ
#
# 3.Transcribed:اٹھارہ
# 3.LMCorrected:اٹھارہ
#
# 4.GroundTruth:میں نے دو ہزار اٹھارہ میں ایف ایس سی مکمل کیا ہیں
#
# 4.Transcribed:میں نے دو ہزار اٹھارہ میں ایفصو کمل کی ہں
# 4.LMCorrected:میں نے دو ہزار اٹھارہ میں ایف مکمل کی ہے
#
# 5.GroundTruth:اکانوے
#
# 5.Transcribed:اکاوے
# 5.LMCorrected:اکانوے
#
# 6.GroundTruth:پچیس
#
# 6.Transcribed:پچیس
# 6.LMCorrected:پچیس
#
# 7.GroundTruth:پچیس
#
# 7.Transcribed:پنچیس
# 7.LMCorrected:پچیس
#
# 8.GroundTruth:پچیس
#
# 8.Transcribed:پچیس
# 8.LMCorrected:پچیس
#
# 9.GroundTruth:پچاسی
#
# 9.Transcribed:پچاستی
# 9.LMCorrected:پچاسی
#
# 10.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 10.Transcribed:میرا پان سانل کرام تجنپ ہے
# 10.LMCorrected:میرا پانچ سال کرام تڑپ ہے
#
# 11.GroundTruth:پچاس
#
# 11.Transcribed:پچاس
# 11.LMCorrected:پچاس
#
# 12.GroundTruth:میں نے بارہویں جماعت تک پڑھا ہے
#
# 12.Transcribed:میں نے بورہویں جمت تکپڑھا ہے
# 12.LMCorrected:میں نے بارہویں جمع پڑھا ہے
#
# 13.GroundTruth:تیرہ
#
# 13.Transcribed:تیرہ
# 13.LMCorrected:تیرہ
#
# 14.GroundTruth:چھتیس
#
# 14.Transcribed:چھتیس
# 14.LMCorrected:چھتیس
#
# 3.GroundTruth:دو ہزار آٹھ
#
# 3.Transcribed:دوہزار پٹھ
# 3.LMCorrected:ہزار آٹھ
#
# 6.GroundTruth:میں کارپینٹر  ہوں
#
# 6.Transcribed:میں کارپینٹر ہے
# 6.LMCorrected:میں کارپینٹر ہے
#
# 7.GroundTruth:انيس سو چھیاسی
#
# 7.Transcribed:انس سو چھیاسی
# 7.LMCorrected:انس سو چھیاسی
#
# 8.GroundTruth:اٹھارہ
#
# 8.Transcribed:اٹھارہ
# 8.LMCorrected:اٹھارہ
#
# 12.GroundTruth:دو ہزار تین
#
# 12.Transcribed:دو ہزار تی
# 12.LMCorrected:دو ہزار تین
#
# 15.GroundTruth:انيس سو ننانوے
#
# 15.Transcribed:انس سو ننانو
# 15.LMCorrected:انس سو ننانوے
#
# 0.GroundTruth:انيس سو نواسی
#
# 0.Transcribed:انس سو ناواسی
# 0.LMCorrected:انس سو نواسی
#
# 1.GroundTruth:انيس سو نواسی
#
# 1.Transcribed:ونس سو ناسی
# 1.LMCorrected:ونس سو نواسی
#
# 2.GroundTruth:انيس سو چورانوے
#
# 2.Transcribed:انس سو چورانوے
# 2.LMCorrected:انس سو چورانوے
#
# 5.GroundTruth:سترہ
#
# 5.Transcribed:سترہ
# 5.LMCorrected:سترہ
#
# 8.GroundTruth:چار
#
# 8.Transcribed:چار
# 8.LMCorrected:چار
#
# 9.GroundTruth:تئیس
#
# 9.Transcribed:تئیس
# 9.LMCorrected:تئیس
#
# 10.GroundTruth:سینتالیس
#
# 10.Transcribed:سینتالیس
# 10.LMCorrected:سینتالیس
#
# 11.GroundTruth:بیس
#
# 11.Transcribed:بیس
# 11.LMCorrected:بیس
#
# 12.GroundTruth:پچاس
#
# 12.Transcribed:پچاس
# 12.LMCorrected:پچاس
#
# 13.GroundTruth:انيس سو نواسی
#
# 13.Transcribed:انس سو نواسی
# 13.LMCorrected:انس سو نواسی
#
# 14.GroundTruth:میرا پیشہ الیکٹریشن ہے
#
# 14.Transcribed:میرا پیشہ الیکٹریشن ہے
# 14.LMCorrected:میرا پیشہ الیکٹریشن ہے
#
# 15.GroundTruth:اڑتیس
#
# 15.Transcribed:اڑتیس
# 15.LMCorrected:اڑتیس
#
# 0.GroundTruth:دو ہزار آٹھ
#
# 0.Transcribed:دو ہزار آٹھ
# 0.LMCorrected:دو ہزار آٹھ
#
# 1.GroundTruth:دو ہزار ایک
#
# 1.Transcribed:دو ہزار اتیس
# 1.LMCorrected:دو ہزار انیس
#
# 2.GroundTruth:دو ہزار بارہ
#
# 2.Transcribed:دو ہزار بارہ
# 2.LMCorrected:دو ہزار بارہ
#
# 3.GroundTruth:اسی سال یہ کام کرنا شروع کیا ہے
#
# 3.Transcribed:اکی سال کیہ کام کلہ شرع کیا ہے
# 3.LMCorrected:اکیس سال یہ کام کہ شروع کیا ہے
#
# 4.GroundTruth:میرا چھ سال کا تجربہ ہے
#
# 4.Transcribed:میرا چھ سال کا تجبہ ہے
# 4.LMCorrected:میرا چھ سال کا تجربہ ہے
#
# 6.GroundTruth:کہ تو کیا ہے
#
# 6.Transcribed:کہ پو کیا ے
# 6.LMCorrected:کہ تو کیا ہے
#
# 9.GroundTruth:انيس سو ستاسی
#
# 9.Transcribed:انس سو ستاس
# 9.LMCorrected:انس سو ستاسی
#
# 11.GroundTruth:تیرہ
#
# 11.Transcribed:تیرہ
# 11.LMCorrected:تیرہ
#
# 13.GroundTruth:میرا تعلق کراچی سے ہے
#
# 13.Transcribed:میرا تعلق کراچیسے ہے
# 13.LMCorrected:میرا تعلق کراچی ہے
#
# 14.GroundTruth:انيس سو پچانوے
#
# 14.Transcribed:انس سو پچانو
# 14.LMCorrected:انس سو پچانوے
#
# 0.GroundTruth:انيس سو اکانوے
#
# 0.Transcribed:نس سو اکانوے
# 0.LMCorrected:نے سو اکانوے
#
# 2.GroundTruth:پچاسی
#
# 2.Transcribed:پچیاسی
# 2.LMCorrected:پچاسی
#
# 5.GroundTruth:انيس سو اٹھاسی
#
# 5.Transcribed:انس سو اٹھاسی
# 5.LMCorrected:انس سو اٹھاسی
#
# 6.GroundTruth:اس کے بعد
#
# 6.Transcribed:س کے بعد
# 6.LMCorrected:س کے بعد
#
# 7.GroundTruth:انيس سو ترانوے
#
# 7.Transcribed:انس سو ترانے
# 7.LMCorrected:انس سو ترانوے
#
# 8.GroundTruth:تینتالیس
#
# 8.Transcribed:تینتالیس
# 8.LMCorrected:تینتالیس
#
# 10.GroundTruth:اکسٹھ
#
# 10.Transcribed:اکسٹھ
# 10.LMCorrected:اکسٹھ
#
# 11.GroundTruth:چودہ
#
# 11.Transcribed:چودہ
# 11.LMCorrected:چودہ
#
# 0.GroundTruth:یعنی شاعر بتاتا ہے کہ آج جو کچھ ہے ضروری نہیں کہ وہ کل رہے
#
# 0.Transcribed:یعنی شار براتا ہے کہ آدجو کچھ ہے روری نہیں کے مک ر
# 0.LMCorrected:یعنی شاعر بتاتا ہے کہ جو کچھ ہے ضروری نہیں کے تک ر
#
# 2.GroundTruth:چھ
#
# 2.Transcribed:چھ
# 2.LMCorrected:چھ
#
# 5.GroundTruth:انہتر
#
# 5.Transcribed:انہتر
# 5.LMCorrected:انہتر
#
# 7.GroundTruth:انيس سو ستانوے
#
# 7.Transcribed:انس سو ستانوے
# 7.LMCorrected:انس سو ستانوے
#
# 8.GroundTruth:اکیاسی
#
# 8.Transcribed:اککیاسی
# 8.LMCorrected:اکیاسی
#
# 10.GroundTruth:سڑسٹھ
#
# 10.Transcribed:سڑسٹھ
# 10.LMCorrected:سڑسٹھ
#
# 15.GroundTruth:باون
#
# 15.Transcribed:باون
# 15.LMCorrected:باون
#
# 0.GroundTruth:دو ہزار بارہ
#
# 0.Transcribed:دو ہزار بارہ
# 0.LMCorrected:دو ہزار بارہ
#
# 4.GroundTruth:میں نے چار سال کام کیا ہے
#
# 4.Transcribed:میں نے چا سال کام کی ہے
# 4.LMCorrected:میں نے چھ سال کام کی ہے
#
# 8.GroundTruth:اٹھارہ
#
# 8.Transcribed:اٹارہ
# 8.LMCorrected:اٹھارہ
#
# 9.GroundTruth:پچاسی
#
# 9.Transcribed:پچاسی
# 9.LMCorrected:پچاسی
#
# 12.GroundTruth:چھیالیس
#
# 12.Transcribed:چھیالیس
# 12.LMCorrected:چھیالیس
#
# 14.GroundTruth:میں الیکٹریشن کا کام جانتا ہوں
#
# 14.Transcribed:میں ڈلیکٹریشن کا کم جانتا ہوں
# 14.LMCorrected:میں الیکٹریشن کا کم جانتا ہوں
#
# 15.GroundTruth:اٹھائیس
#
# 15.Transcribed:اٹھائیس
# 15.LMCorrected:اٹھائیس
#
# 0.GroundTruth:غزل میں جب کوئی شاعر
#
# 0.Transcribed:زل میں جب کوئی شار
# 0.LMCorrected:غزل میں جب کوئی شاعر
#
# 4.GroundTruth:اکیاون
#
# 4.Transcribed:اکیاون
# 4.LMCorrected:اکیاون
#
# 13.GroundTruth:میں نے میٹرک  تک تعلیم حاصل کی ہے
#
# 13.Transcribed:میں نے میٹرک تک تعلیم حعصل کی ہے
# 13.LMCorrected:میں نے میٹرک تک تعلیم حاصل کی ہے
#
# 14.GroundTruth:میں میٹرک پاس ہو
#
# 14.Transcribed:میں میٹرک پاس ہو
# 14.LMCorrected:میں میٹرک پاس ہو
#
# 15.GroundTruth:میں نے میٹرک تک تعلیم حاصل کی ہے
#
# 15.Transcribed:میں نے میٹرک تک تعلیحاصل کی
# 15.LMCorrected:میں نے میٹرک تک تعلیحاصل کی
#
# 0.GroundTruth:ننانوے
#
# 0.Transcribed:ننانوے
# 0.LMCorrected:ننانوے
#
# 2.GroundTruth:ستاون
#
# 2.Transcribed:ستاو
# 2.LMCorrected:ستاون
#
# 5.GroundTruth:میرا پیشہ کارپینٹر ہے
#
# 5.Transcribed:میرا پیشہ کاپنٹر ہے
# 5.LMCorrected:میرا پیشہ کارپینٹر ہے
#
# 6.GroundTruth:اکیس
#
# 6.Transcribed:ایہکیس
# 6.LMCorrected:اکیس
#
# 9.GroundTruth:انيس سو ستاسی
#
# 9.Transcribed:نس سو ستاسی
# 9.LMCorrected:نے سو ستاسی
#
# 11.GroundTruth:میں اسلام آباد میں رہتا ہوں
#
# 11.Transcribed:میں سلام آپاد می ہرتا ہوں
# 11.LMCorrected:میں اسلام آباد می رہتا ہوں
#
# 12.GroundTruth:پچانوے
#
# 12.Transcribed:پچانوے
# 12.LMCorrected:پچانوے
#
# 13.GroundTruth:دو ہزار پندرہ
#
# 13.Transcribed:دو ہزار پندہ
# 13.LMCorrected:دو ہزار پندرہ
#
# 1.GroundTruth:میں الیکٹریشن ہوں
#
# 1.Transcribed:میں ایلیکوریشن ہوں
# 1.LMCorrected:میں الیکٹریشن ہوں
#
# 3.GroundTruth:انيس سو اٹھانوے
#
# 3.Transcribed:انس سو اٹھانوے
# 3.LMCorrected:انس سو اٹھانوے
#
# 6.GroundTruth:انيس سو ستاسی
#
# 6.Transcribed:انس سو ستاس
# 6.LMCorrected:انس سو ستاسی
#
# 7.GroundTruth:دو
#
# 7.Transcribed:دو
# 7.LMCorrected:دو
#
# 10.GroundTruth:عزیز طلباء
#
# 10.Transcribed:عزیز طلبا
# 10.LMCorrected:عزیز طلباء
#
# 13.GroundTruth:چھیاسٹھ
#
# 13.Transcribed:چھیاسٹھ
# 13.LMCorrected:چھیاسٹھ
#
# 15.GroundTruth:میرا نام بلال ہے
#
# 15.Transcribed:میرا نام پاہ ہے
# 15.LMCorrected:میرا نام ماہ ہے
#
# 0.GroundTruth:میں لاہور میں رہتا ہوں
#
# 0.Transcribed:میں لاہر میں رہتا ہوں
# 0.LMCorrected:میں لاہور میں رہتا ہوں
#
# 1.GroundTruth:ساٹھ
#
# 1.Transcribed:ساٹھ
# 1.LMCorrected:ساٹھ
#
# 2.GroundTruth:دو ہزار انیس
#
# 2.Transcribed:دو ہزا انیس
# 2.LMCorrected:دو ہزار انیس
#
# 5.GroundTruth:ترانوے
#
# 5.Transcribed:ترانوے
# 5.LMCorrected:ترانوے
#
# 6.GroundTruth:اٹھائیس
#
# 6.Transcribed:اٹائیس
# 6.LMCorrected:اٹھائیس
#
# 8.GroundTruth:میں پلمبر ہوں
#
# 8.Transcribed:میں پلامبر ہوں
# 8.LMCorrected:میں پلمبر ہوں
#
# 9.GroundTruth:دو ہزار بیس
#
# 9.Transcribed:دو ہزا بیس
# 9.LMCorrected:دو ہزار بیس
#
# 11.GroundTruth:پچاسی
#
# 11.Transcribed:پچاسی
# 11.LMCorrected:پچاسی
#
# 12.GroundTruth:میں نے میٹرک تک پڑھا ہے
#
# 12.Transcribed:میں لے میٹرک تک پہا ہے
# 12.LMCorrected:میں لے میٹرک تک رہا ہے
#
# 13.GroundTruth:چھیاسٹھ
#
# 13.Transcribed:چھیاسٹھ
# 13.LMCorrected:چھیاسٹھ
#
# 1.GroundTruth:دو ہزار دس
#
# 1.Transcribed:دو ہزار دس
# 1.LMCorrected:دو ہزار دس
#
# 7.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 7.Transcribed:میں نے کوئی علیم حاصلہو کی ہں
# 7.LMCorrected:میں نے کوئی تعلیم حاصل کی ہے
#
# 9.GroundTruth:سترہ
#
# 9.Transcribed:سترہ
# 9.LMCorrected:سترہ
#
# 11.GroundTruth:میں چھ سال سے یہ کام کر رہا ہوں
#
# 11.Transcribed:میں چھ سال ے یہ کام ترہا ہوں
# 11.LMCorrected:میں چھ سال سے یہ کام رہا ہوں
#
# 14.GroundTruth:میں نے ایف ایس سی تک تعلیم حاصل کی ہے
#
# 14.Transcribed:میں نے ایف ایسف  ک تایم حاصل کی ہے
# 14.LMCorrected:میں نے ایف ایس ک تاہم حاصل کی ہے
#
# 15.GroundTruth:دس
#
# 15.Transcribed:دس
# 15.LMCorrected:دس
#
# 1.GroundTruth:سینتالیس
#
# 1.Transcribed:سینتالیس
# 1.LMCorrected:سینتالیس
#
# 2.GroundTruth:میرا پیشہ ڈرائیور ہے
#
# 2.Transcribed:میرا پیشہ ڈرائیر ہے
# 2.LMCorrected:میرا پیشہ ڈرائیور ہے
#
# 3.GroundTruth:بیاسی
#
# 3.Transcribed:بیراسی
# 3.LMCorrected:بیاسی
#
# 4.GroundTruth:چوالیس
#
# 4.Transcribed:چوالیس
# 4.LMCorrected:چوالیس
#
# 5.GroundTruth:دو ہزار پانچ
#
# 5.Transcribed:دو ہزار پانچ
# 5.LMCorrected:دو ہزار پانچ
#
# 6.GroundTruth:دو ہزار تین
#
# 6.Transcribed:دو ہزا تین
# 6.LMCorrected:دو ہزار تین
#
# 10.GroundTruth:چھیانوے
#
# 10.Transcribed:چھیانوے
# 10.LMCorrected:چھیانوے
#
# 12.GroundTruth:چوراسی
#
# 12.Transcribed:چوراسی
# 12.LMCorrected:چوراسی
#
# 13.GroundTruth:دو ہزار ایک
#
# 13.Transcribed:دو ہزار ای
# 13.LMCorrected:دو ہزار ای
#
# 14.GroundTruth:یا واقعی غالب کی شعوری کاوش
#
# 14.Transcribed:یا وا کی غالب کی شعوری کایش
# 14.LMCorrected:یا وا کی غالب کی شعوری کاوش
#
# 15.GroundTruth:سات
#
# 15.Transcribed:سات
# 15.LMCorrected:سات
# SHUFFLING as reached end of data
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:اٹھاون
# 0.LMCorrected:اٹھاون
#
# 1.GroundTruth:انيس سو چورانوے
#
# 1.Transcribed:انس سو چورانوے
# 1.LMCorrected:انس سو چورانوے
#
# 2.GroundTruth:میرا پیشہ الیکٹریشن ہے
#
# 2.Transcribed:میرا پیشل لکٹریشن ہے
# 2.LMCorrected:میرا پیشہ الیکٹریشن ہے
#
# 3.GroundTruth:انہتر
#
# 3.Transcribed:انہتر
# 3.LMCorrected:انہتر
#
# 4.GroundTruth:ستائیس
#
# 4.Transcribed:ستایس
# 4.LMCorrected:ستائیس
#
# 6.GroundTruth:بانوے
#
# 6.Transcribed:بانوے
# 6.LMCorrected:بانوے
#
# 7.GroundTruth:انيس سو اکانوے
#
# 7.Transcribed:نس سو اکانوے
# 7.LMCorrected:نے سو اکانوے
#
# 8.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 8.Transcribed:میں ڈایریکٹے کر کام جانتا ہوں
# 8.LMCorrected:میں ڈایلیکٹس کر کام جانتا ہوں
#
# 9.GroundTruth:انتیس
#
# 9.Transcribed:انتیس
# 9.LMCorrected:انتیس
#
# 11.GroundTruth:دو ہزار سات
#
# 11.Transcribed:دو ہزار سات
# 11.LMCorrected:دو ہزار سات
#
# 13.GroundTruth:اکسٹھ
#
# 13.Transcribed:اکسٹھ
# 13.LMCorrected:اکسٹھ
#
# 15.GroundTruth:دو ہزار تیرہ
#
# 15.Transcribed:دو ہزار تیرہ
# 15.LMCorrected:دو ہزار تیرہ
#
# 0.GroundTruth:پانچ
#
# 0.Transcribed:پانچ
# 0.LMCorrected:پانچ
#
# 2.GroundTruth:میں ڈرائیور ہوں
#
# 2.Transcribed:میں ڈرر ہوں
# 2.LMCorrected:میں ڈر ہوں
#
# 3.GroundTruth:میں نے دو ہزار سولہ میں میٹرک مکمل کیا ہے
#
# 3.Transcribed:میں نے دو ہزار سول میں میٹر کم کیا ہے
# 3.LMCorrected:میں نے دو ہزار سولہ میں میٹرک کم کیا ہے
#
# 5.GroundTruth:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 5.Transcribed:میں نے دو زارل دس میں نٹک کا ہے
# 5.LMCorrected:میں نے دو زار دس میں ناٹک کا ہے
#
# 6.GroundTruth:احساس کیا کہ شاید
#
# 6.Transcribed:احساز کیا کہ شادب
# 6.LMCorrected:احساس کیا کہ ادب
#
# 7.GroundTruth:اٹھاون
#
# 7.Transcribed:اٹھاون
# 7.LMCorrected:اٹھاون
#
# 8.GroundTruth:میں ڈرائیور ہوں
#
# 8.Transcribed:میں ڈئیور ہوی
# 8.LMCorrected:میں ڈرائیور ہوی
#
# 9.GroundTruth:میں ڈرائیونگ کا کام جانتا ہوں
#
# 9.Transcribed:میں ڈرائیوینہ کا کام جانتا ہو
# 9.LMCorrected:میں ڈرائیونگ کا کام جانتا ہو
#
# 10.GroundTruth:انتیس
#
# 10.Transcribed:انتیس
# 10.LMCorrected:انتیس
#
# 11.GroundTruth:دو ہزار انیس
#
# 11.Transcribed:دو ہزار انیس
# 11.LMCorrected:دو ہزار انیس
#
# 13.GroundTruth:دو ہزار ایک
#
# 13.Transcribed:دو ہزار ای
# 13.LMCorrected:دو ہزار ای
#
# 14.GroundTruth:اکانوے
#
# 14.Transcribed:اکانوے
# 14.LMCorrected:اکانوے
#
# 15.GroundTruth:انيس سو چھیاسی
#
# 15.Transcribed:انس سو چھیاس
# 15.LMCorrected:انس سو چھیاسی
# ########################################################
# Completed Validation Test: WER & LER results
# Test WER average is   : 0.3969658448625444
# Test LER average is   : 6.119469026548672
# Test normalised LER is: 0.29116686981249
# ########################################################
# better ler/wer at: /content/drive/My Drive/SpeakCV/CombinedDataModels/epochs/LER-WER-best-DS2_2020-12-22_13-07-0.4
# Saving model at: /content/drive/My Drive/SpeakCV/CombinedDataModels/epochs/LER-WER-best-DS2_2020-12-22_13-07-0.4/model.json /content/drive/My Drive/SpeakCV/CombinedDataModels/epochs/LER-WER-best-DS2_2020-12-22_13-07-0.4/model.h5
# Mean WER   : [1.0, 1.0504928670304872, 0.8900000871568893, 0.7506827698232801, 0.6246362477619135, 0.6324295932082319, 0.4831208359686974, 0.48353096879567514, 0.457231999110046, 0.3969658448625444]
# Mean LER   : [20.76216814159292, 13.2804203539823, 11.665929203539823, 9.75608407079646, 9.017699115044248, 9.627212389380531, 7.196902654867257, 7.23174778761062, 6.972898230088496, 6.119469026548672]
# NormMeanLER: [0.9991497926441415, 0.676658263838769, 0.5892726771109315, 0.4665297538378083, 0.417617884187014, 0.43072494904622516, 0.3322461382181384, 0.3325102611454165, 0.32047635147549536, 0.29116686981249]

# %% [markdown]
# >#  **Testing of validation files**

# %%
import argparse
import datetime
import socket

#####################################################


import keras

from keras import backend as K
from keras.callbacks import ModelCheckpoint, TensorBoard

#######################################################

def main_test(test_files,name,batchsize,model_arch,loadcheckpointpath,opt,train_steps,valid_steps):
# def main(args):
    '''

    only args.name args.test_files and args.loadcheckpointpath can be passed as args


    '''

    print("Getting data from arguments")
    test_dataprops, df_test = combine_all_wavs_and_trans_from_csvs(test_files, sortagrad=False,start=0,end=100)


    # check any special data model requirments e.g. a spectrogram
    if(model_arch == 1):
        model_input_type = "mfcc"
    elif(model_arch == 2 or model_arch == 5):
        print("Spectrogram required")
        # spectrogram = True
        model_input_type = "spectrogram"
    else:
        model_input_type = "mfcc"



    ## 2. init data generators
    print("Creating data batch generators")
    testdata = BatchGenerator(dataframe=df_test, dataproperties=test_dataprops,
                               training=False, batch_size=1, model_input_type=model_input_type)



    ## 3. Load existing or error
    if loadcheckpointpath:
        # load existing
        print("Loading model")

        cp = loadcheckpointpath
        assert(os.path.isdir(cp))
        trimmed = False

        if trimmed:
            model_path = os.path.join(cp, "TRIMMED_ds_model")
        else:
            model_path = os.path.join(cp, "model")
        # assert(os.path.isfile(model_path))

        model = load_model_checkpoint(model_path)
        opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True, clipnorm=5)

        print("Model loaded")

    else:
        # new model
        raise("You need to load an existing trained model")


    model.compile(optimizer=opt, loss=ctc)

    ## 4. test

    train_steps = len(df_test.index) // 200

    try:
        y_pred = model.get_layer('ctc').input[0]
    except Exception as e:
        print("error", e)
        print("couldn't find ctc layer, possibly a trimmed layer, trying other name")
        y_pred = model.get_layer('out').output

    input_data = model.get_layer('the_input').input

    K.set_learning_phase(0)
    report = K.function([input_data, K.learning_phase()], [y_pred])
    report_cb = ReportCallback(report, testdata, model, name, save=False)
    report_cb.force_output = True
    print('starting....................................')
    report_cb.on_epoch_end(0, logs=None)

    K.clear_session()

# %% [markdown]
# **Change loadcheckpointpath to the last best model**

# %%
runtime = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')
name="DS"+str(2)+"_"+runtime
#     print(args)

main_test(test_files="/content/drive/MyDrive/SpeakCV/CombinedDataFiles/validate_data.csv",model_arch=2,name=name,batchsize=8,train_steps=0,valid_steps=0,loadcheckpointpath="/content/drive/MyDrive/SpeakCV/CombinedDataModels/epochs/LER-WER-best-DS2_2020-12-22_13-07-0.4",opt='sgd')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 0.Transcribed:سان ا
# 0.LMCorrected:ان ا
#
# 0.GroundTruth:میں نے میٹرک  تک تعلیم حاصل کی ہے
#
# 0.Transcribed:یں پانے و اھہ اس کیر ے
# 0.LMCorrected:یں پانے و الہ اس کی ہے
#
# 0.GroundTruth:چھیاسٹھ
#
# 0.Transcribed:اسو
# 0.LMCorrected:اس
#
# 0.GroundTruth:میں نے چھ سال کام کیا ہے
#
# 0.Transcribed:نچاسا کاکی
# 0.LMCorrected:پچاس کافی
#
# 0.GroundTruth:سڑسٹھ
#
# 0.Transcribed:ای  ا
# 0.LMCorrected:ای ا
#
# 0.GroundTruth:انيس سو پچاسی
#
# 0.Transcribed:انسوچاسی
# 0.LMCorrected:انسوچاسی
#
# 0.GroundTruth:میرا تجربہ سات سال ہے
#
# 0.Transcribed:ی جبا ساسا
# 0.LMCorrected:ی جب سارا
#
# 0.GroundTruth:ایسا شخص نئے نئے تجربات کرتا ہے
#
# 0.Transcribed:جروا کتا ہے
# 0.LMCorrected:روا کیا ہے
#
# 0.GroundTruth:پھر زندگی کی بے ثباتی کا تذکرہ
#
# 0.Transcribed:ی سی  سا سر
# 0.LMCorrected:ی سی سا سر
#
# 0.GroundTruth:میر تقی میر کی
#
# 0.Transcribed:سے و
# 0.LMCorrected:سے و
#
# 0.GroundTruth:ہوا ہے شہ کا مصاحب
#
# 0.Transcribed:ک سای
# 0.LMCorrected:ک اسی
#
# 0.GroundTruth:اپنی آنکھوں پر عیاں ہو جا
#
# 0.Transcribed:اایکج
# 0.LMCorrected:ایک
#
# 0.GroundTruth:میں پلمبر ہوں
#
# 0.Transcribed:یا  ہوں
# 0.LMCorrected:یا ہوں
#
# 0.GroundTruth:انيس سو اکانوے
#
# 0.Transcribed:سا کاہ
# 0.LMCorrected:سا کا
#
# 0.GroundTruth:اس مقام سے آگے ایک قدم بھی نہیں بڑھ سکا
#
# 0.Transcribed:اساے  کری ٹس
# 0.LMCorrected:اسے کی اس
#
# 0.GroundTruth:میری عمر بائیس سال ہے
#
# 0.Transcribed:سمی سسا سے
# 0.LMCorrected:سی سا سے
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے پندرہ سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed:یکاوی ا  ساادو ا
# 0.LMCorrected:کافی ا اردو ا
#
# 0.GroundTruth:میں نے میٹرک تک پڑھا ہے
#
# 0.Transcribed:یتن دساس پ
# 0.LMCorrected:تین حساس پ
#
# 0.GroundTruth:عور یعنی برہنہ یا ننگا
#
# 0.Transcribed: ااجیو
# 0.LMCorrected:اایف
#
# 0.GroundTruth:یہ وہ دور تھا جس میں غالب نے
#
# 0.Transcribed:ت سغا ے
# 0.LMCorrected:ت سزا ہے
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے سات سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed: ہ کا کت و سھ سل کا ہو گیا
# 0.LMCorrected:ہ کا کی و چھ سال کا ہو گیا
#
# 0.GroundTruth:چھ
#
# 0.Transcribed:دا
# 0.LMCorrected:دا
#
# 0.GroundTruth:عزیز طلبہ کسی بھی شاعر کے امتیازی خصائص پر بات دو انداز میں کی جاتی ہے
#
# 0.Transcribed:س رشاوں تا زساسواو آظر کی ت
# 0.LMCorrected:س فرشتوں تا زساسواو نظر کی ت
#
# 0.GroundTruth:میرا فون نمبر یہ ہے03001234567
#
# 0.Transcribed:اسوبوی س یسی ییہاسا
# 0.LMCorrected:اسوبوی س کسی ییہاسا
#
# 0.GroundTruth:میں نے سات سال کام کیا ہے
#
# 0.Transcribed:نے ساس
# 0.LMCorrected:نے اس
#
# 0.GroundTruth:چھیالیس
#
# 0.Transcribed:چس
# 0.LMCorrected:اس
#
# 0.GroundTruth:چوبیس
#
# 0.Transcribed:ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:جنہیں کل درس و تدریس کے مرحلے سے بذات خود گزرنا ہے
#
# 0.Transcribed:یہکسی س مالس را ک لاہے
# 0.LMCorrected:کسی س مفلس کا ک لانے
#
# 0.GroundTruth:چوبیس
#
# 0.Transcribed:ااابیس
# 0.LMCorrected:ااابیس
#
# 0.GroundTruth:مرزا رفیع سودا کی تشبیب گریز اور مدح میں کچھ ایسے نئے مضامین کا اضافہ کیا جو ان سے پہلے نہیں تھا
#
# 0.Transcribed:وسساسمی ورزمں سمیااکیا  ن ستی کھا
# 0.LMCorrected:وسساسمی ورزش سمیااکیا ن ستی کھا
#
# 0.GroundTruth:میرا نام طلحہ ہے
#
# 0.Transcribed:می ننانا
# 0.LMCorrected:می بنانا
#
# 0.GroundTruth:پچاس
#
# 0.Transcribed:پکا
# 0.LMCorrected:کا
#
# 0.GroundTruth:انتالیس
#
# 0.Transcribed:چ ہ
# 0.LMCorrected:و ہ
#
# 0.GroundTruth:نو
#
# 0.Transcribed:ارا ہ
# 0.LMCorrected:انا ہ
#
# 0.GroundTruth:دو ہزار انیس
#
# 0.Transcribed:سو ایس
# 0.LMCorrected:سو ایس
#
# 0.GroundTruth:اس کے بعد بھی بہت سے مثنوی کو پیدا ہوئے لیکن
#
# 0.Transcribed: رز  ر سا اسا پیویسارتا ہ
# 0.LMCorrected:رب ر سا اس پیویسارتا ہ
#
# 0.GroundTruth:میرا تعلق لاہور سے ہے
#
# 0.Transcribed:ان  جوھار س ا
# 0.LMCorrected:ان وقار س ا
#
# 0.GroundTruth:سڑسٹھ
#
# 0.Transcribed:چسن
# 0.LMCorrected:حسن
#
# 0.GroundTruth:بالکل اسی طرح  کہ جیسے چاند خواہ کتنے ہی لوگ تکیں
#
# 0.Transcribed:سسااسا و نرو
# 0.LMCorrected:سسااسا و نحو
#
# 0.GroundTruth:تعلیم بھی مکمل نہ ہو پائی تھی کہ 1857 کے ہنگامے میں گھریلو حالات نے ایسی صورت اختیار کی کہ اسکول چھوڑنا پڑا
#
# 0.Transcribed: کہو ی کسستکمی میق  رستکی ک سکورڑھ
# 0.LMCorrected:کہو ی کسستکمی میں رہتی ک سکورڑھ
#
# 0.GroundTruth:پینسٹھ
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:بیالیس
#
# 0.Transcribed: اکی ک
# 0.LMCorrected:کی ک
#
# 0.GroundTruth:میرا فون نمبر یہ ہے 03009877004
#
# 0.Transcribed:ونو ی ے ستس سڑ ہتسکساککسٹ
# 0.LMCorrected:نو ی و ستم سے ہتسکساککسٹ
#
# 0.GroundTruth:میں نے جامعہ تک پڑھا ہے
#
# 0.Transcribed:دویسری ائیا
# 0.LMCorrected:دوسری ائی
#
# 0.GroundTruth:تئیس
#
# 0.Transcribed:اددار
# 0.LMCorrected:ادوار
#
# 0.GroundTruth:دو ہزار
#
# 0.Transcribed:دو ٹا
# 0.LMCorrected:دو کا
#
# 0.GroundTruth:میں نے ایف ایس سی کیا ہے
#
# 0.Transcribed:مں واں سسکاے
# 0.LMCorrected:میں واں سکتے
#
# 0.GroundTruth:وسطی دور تک
#
# 0.Transcribed:سیے ت
# 0.LMCorrected:سے ت
#
# 0.GroundTruth:بائیس
#
# 0.Transcribed:سب
# 0.LMCorrected:سب
#
# 0.GroundTruth:انيس سو ترانوے
#
# 0.Transcribed:انس سو
# 0.LMCorrected:انس سو
#
# 0.GroundTruth:میری عمر دس سال ہے
#
# 0.Transcribed:میسو ڑھا
# 0.LMCorrected:میسر تھا
#
# 0.GroundTruth:اڑتیس
#
# 0.Transcribed:یں اکت
# 0.LMCorrected:یں اک
#
# 0.GroundTruth:اناسی
#
# 0.Transcribed:انسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:میں ڈرائیور ہوں
#
# 0.Transcribed:شوی
# 0.LMCorrected:شوق
#
# 0.GroundTruth:نوے
#
# 0.Transcribed:نا
# 0.LMCorrected:نا
#
# 0.GroundTruth:آٹھ
#
# 0.Transcribed:ارنس
# 0.LMCorrected:انس
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:اور پھر
#
# 0.Transcribed:رج
# 0.LMCorrected:آج
#
# 0.GroundTruth:آٹھ
#
# 0.Transcribed:  ر ر وس
# 0.LMCorrected:ر ر اس
#
# 0.GroundTruth:ستاسی
#
# 0.Transcribed:انس
# 0.LMCorrected:انس
#
# 0.GroundTruth:انيس سو بياسي
#
# 0.Transcribed:پانسا
# 0.LMCorrected:پارسا
#
# 0.GroundTruth:چار
#
# 0.Transcribed:سچل
# 0.LMCorrected:سال
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے دس سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed: کا کلر س کاسہو راہے
# 0.LMCorrected:کا کر س کاسہ رہے
#
# 0.GroundTruth:چوالیس
#
# 0.Transcribed:ا ہو ر
# 0.LMCorrected:ا ہو ر
#
# 0.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 0.Transcribed:انیس سامیں ریری ا ی
# 0.LMCorrected:انیس امیں میری ا ی
#
# 0.GroundTruth:تیرہ
#
# 0.Transcribed:سا
# 0.LMCorrected:سا
#
# 0.GroundTruth:دو ہزار پانچ
#
# 0.Transcribed:دی و چ
# 0.LMCorrected:دی و و
#
# 0.GroundTruth:پچانوے
#
# 0.Transcribed:اوینس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:دس
#
# 0.Transcribed:وی
# 0.LMCorrected:کی
#
# 0.GroundTruth:میں نے دو ہزار چودہ میں دسویں مکمل کی ہے
#
# 0.Transcribed: ا زان ہاکی
# 0.LMCorrected:ا ان ہائی
#
# 0.GroundTruth:اٹھہتر
#
# 0.Transcribed:یس
# 0.LMCorrected:یس
#
# 0.GroundTruth:کہ اردو ادب میں ان اصناف میں کس نوعیت کے اضافے ہوئے
#
# 0.Transcribed:  سرامیں سا اسیو
# 0.LMCorrected:گرامی سا اسی
#
# 0.GroundTruth:اڑتیس
#
# 0.Transcribed:اس
# 0.LMCorrected:اس
#
# 0.GroundTruth:میں دس  سال سے یہ کام کر رہا ہوں
#
# 0.Transcribed:میں سایہ کام کر
# 0.LMCorrected:میں سایہ کام کر
#
# 0.GroundTruth:بازار میں موجود تھے
#
# 0.Transcribed:ساوو
# 0.LMCorrected:اور
#
# 0.GroundTruth:اکیاون
#
# 0.Transcribed:  ےدی انس ی
# 0.LMCorrected:دی انس ی
#
# 0.GroundTruth:اس کے سامنے دنیا کا یہ تمام کا تمام تماشا ہو رہا تھا
#
# 0.Transcribed:سانک یس تما کا گرا
# 0.LMCorrected:ایک یس تھا کا گرا
#
# 0.GroundTruth:انيس سو اٹھاسی
#
# 0.Transcribed:کنس
# 0.LMCorrected:کس
#
# 0.GroundTruth:چھیانوے
#
# 0.Transcribed:چاے
# 0.LMCorrected:اے
#
# 0.GroundTruth:انيس سو تراسی
#
# 0.Transcribed:انس سارراسی
# 0.LMCorrected:انس سارراسی
#
# 0.GroundTruth:پینسٹھ
#
# 0.Transcribed:ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:باسٹھ
#
# 0.Transcribed:ب
# 0.LMCorrected:ب
#
# 0.GroundTruth:اور پھر شاید غالب جیسے شاعر اسی وجہ سے کہتی ہے کہ سب کہاں کچھ لالہ و گل میں نمایاں ہو گئیں خاک میں کیا صورتیں ہوں گی کہ پنہاں ہو گئیں
#
# 0.Transcribed:اترچسشاسشاسستچسکا غرم ہوگری کر جسہو تدہگی
# 0.LMCorrected:اترچسشاسشاسستچسکا غم ہوگی کر جسکو دہلی
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:نے والم حار
# 0.LMCorrected:نے والا چار
#
# 0.GroundTruth:باسٹھ
#
# 0.Transcribed: ی
# 0.LMCorrected:ی
#
# 0.GroundTruth:انسٹھ
#
# 0.Transcribed:اسٹ
# 0.LMCorrected:اس
#
# 0.GroundTruth:بائیس
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:میں ڈیلیوری بوائے کا کام جانتا ہوں
#
# 0.Transcribed:مراک  ا کا
# 0.LMCorrected:مراد ا کا
#
# 0.GroundTruth:انيس سو چھیاسی
#
# 0.Transcribed:وچراسی
# 0.LMCorrected:چوراسی
#
# 0.GroundTruth:تراسی
#
# 0.Transcribed:تھق تی ارہ
# 0.LMCorrected:تھا کی راہ
#
# 0.GroundTruth:اڑتالیس
#
# 0.Transcribed:االیس
# 0.LMCorrected:چالیس
#
# 0.GroundTruth:اسی طرح کہتے ہیں کہ رقیبوں نے رپٹ لکھوائی ہے جا جا کے تھانے میں کہ اکبر نام لیتا ہے خدا کا اس زمانے میں
#
# 0.Transcribed:سوڑایازرا ارساک ا سوی
# 0.LMCorrected:سوڑایازرا احساس ا سو
#
# 0.GroundTruth:سو
#
# 0.Transcribed:سد
# 0.LMCorrected:سے
#
# 0.GroundTruth:میں نے ایف ایس سی تک پڑھا ہے
#
# 0.Transcribed:م س سسی  پا
# 0.LMCorrected:م س کسی پا
#
# 0.GroundTruth:دو ہزار پانچ
#
# 0.Transcribed: ہزایچ
# 0.LMCorrected:ہزار
#
# 0.GroundTruth:میں نے آئی سی ایس کیا ہے
#
# 0.Transcribed:بنے اسی س اہ
# 0.LMCorrected:بنے اسی س اس
#
# 0.GroundTruth:صفر
#
# 0.Transcribed: ل س
# 0.LMCorrected:ل س
#
# 0.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 0.Transcribed:میراسکا یں کوئی بے
# 0.LMCorrected:میراسکا یں کوئی بے
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:افچا رس
# 0.LMCorrected:اپنا سر
#
# 0.GroundTruth:ستاسی
#
# 0.Transcribed:دا سمں
# 0.LMCorrected:دا سم
#
# 0.GroundTruth:میں  لاہور میں رہتا ہوں
#
# 0.Transcribed:ساس سسرات تساک
# 0.LMCorrected:اس سسرال تھا
#
# 0.GroundTruth:پچیس
#
# 0.Transcribed:سب س س
# 0.LMCorrected:سب س س
#
# 0.GroundTruth:دو ہزار ایک
#
# 0.Transcribed:دزراک
# 0.LMCorrected:گزرا
#
# 0.GroundTruth:میرا پیشہ ڈلیوری بوائے ہے
#
# 0.Transcribed:اسچ ی با
# 0.LMCorrected:اس ی با
#
# 0.GroundTruth:میں نے ڈپلومہ کیا ہے
#
# 0.Transcribed:ن سرو
# 0.LMCorrected:ن سو
#
# 0.GroundTruth:انچاس
#
# 0.Transcribed:پایس
# 0.LMCorrected:پاس
#
# 0.GroundTruth:زخمی پڑا ہے شیر مرا کس کچار میں
#
# 0.Transcribed: پ ویرا سا
# 0.LMCorrected:پ میرا سا
#
# 0.GroundTruth:اور جذبات کی بات کی جائے تو کچھ ایسا بیان کیا کہ واقعی مجالس عزا
#
# 0.Transcribed:اییے چسا ککری لسا
# 0.LMCorrected:ایسے سا فکری لیا
#
# 0.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 0.Transcribed:نیاااا
# 0.LMCorrected:نیاااا
#
# 0.GroundTruth:میرا تعلق لاہور سے ہے
#
# 0.Transcribed:نیو ا
# 0.LMCorrected:یو ا
#
# 0.GroundTruth:انيس سو بياسي
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:انتیس
#
# 0.Transcribed:پاس
# 0.LMCorrected:پاس
#
# 0.GroundTruth:میرا پیشہ الیکٹریشن ہے
#
# 0.Transcribed:میرایشلکسنے
# 0.LMCorrected:میرایشلکسنے
#
# 0.GroundTruth:انيس سو پچانوے
#
# 0.Transcribed:اننسہچاں
# 0.LMCorrected:اننسہچاں
#
# 0.GroundTruth:دو ہزار تیرہ
#
# 0.Transcribed:ی ار
# 0.LMCorrected:ی ار
#
# 0.GroundTruth:چھیالیس
#
# 0.Transcribed:چانیسا
# 0.LMCorrected:ایسا
#
# 0.GroundTruth:اسی
#
# 0.Transcribed:د
# 0.LMCorrected:د
#
# 0.GroundTruth:چھیاسی
#
# 0.Transcribed:کا
# 0.LMCorrected:کا
#
# 0.GroundTruth:انيس سو ستاسی
#
# 0.Transcribed:پنساسنہ
# 0.LMCorrected:پنساسنہ
#
# 0.GroundTruth:دو ہزار گیارہ
#
# 0.Transcribed:ااہ را
# 0.LMCorrected:شاہ کا
#
# 0.GroundTruth:اور جدید اردو شاعری کا نقشہ اول بھی اس کے بغیر تلاشنا میں ممکن نہیں
#
# 0.Transcribed:دیدرکے لا وکے ی
# 0.LMCorrected:میرکے لا کے ی
#
# 0.GroundTruth:میں نے سات سال کام کیا ہے
#
# 0.Transcribed: سسسال کام کی
# 0.LMCorrected:سسرال کام کی
#
# 0.GroundTruth:اور بعض ناقدین یہ بھی کہتے ہیں کہ یہی اختصار و اعجاز اس کی سب سے بڑی خامی  بھی ہے
#
# 0.Transcribed:اکارل ک ی کی سں رنبت سلا اسو ت
# 0.LMCorrected:اکبر ک ی کی سے رنگت سوا سو ت
#
# 0.GroundTruth:میں ڈرائیور ہوں
#
# 0.Transcribed:وراہ
# 0.LMCorrected:راہ
#
# 0.GroundTruth:میں او لیولز پاس ہوں
#
# 0.Transcribed:می فاو ساس ہوں
# 0.LMCorrected:می راو پاس ہوں
#
# 0.GroundTruth:دو ہزار چودہ
#
# 0.Transcribed:چھر   اا ر
# 0.LMCorrected:پھر اس ر
#
# 0.GroundTruth:اردو شاعری کی
#
# 0.Transcribed:ساک
# 0.LMCorrected:سال
#
# 0.GroundTruth:گیارہ
#
# 0.Transcribed:دد ا
# 0.LMCorrected:دل ا
#
# 0.GroundTruth:سینتالیس
#
# 0.Transcribed:سنکر
# 0.LMCorrected:شنکر
#
# 0.GroundTruth:میرا پیشہ ڈیلیوری بوائے ہے
#
# 0.Transcribed:مییسیو  بہ
# 0.LMCorrected:میتھیو بہ
#
# 0.GroundTruth:دو ہزار دس
#
# 0.Transcribed:ا اس
# 0.LMCorrected:ا اس
#
# 0.GroundTruth:چورانوے
#
# 0.Transcribed:چاج
# 0.LMCorrected:چار
#
# 0.GroundTruth:ننانوے
#
# 0.Transcribed:و
# 0.LMCorrected:و
#
# 0.GroundTruth:بارہ
#
# 0.Transcribed:ساس
# 0.LMCorrected:اس
#
# 0.GroundTruth:پچانوے
#
# 0.Transcribed:سان
# 0.LMCorrected:ان
#
# 0.GroundTruth:انيس سو تراسی
#
# 0.Transcribed:پانتس
# 0.LMCorrected:پاس
#
# 0.GroundTruth:چھببیس
#
# 0.Transcribed:منبن ر ای
# 0.LMCorrected:منبع ر ای
#
# 0.GroundTruth:بائیس
#
# 0.Transcribed:بائیس
# 0.LMCorrected:بائیس
#
# 0.GroundTruth:ستر
#
# 0.Transcribed:سون
# 0.LMCorrected:سو
#
# 0.GroundTruth:بہتر
#
# 0.Transcribed:ا ے
# 0.LMCorrected:ا ب
#
# 0.GroundTruth:دو ہزار ایک
#
# 0.Transcribed:بویس
# 0.LMCorrected:بیس
#
# 0.GroundTruth:میرا پیشہ ڈرائیونگ ہے
#
# 0.Transcribed:یاان
# 0.LMCorrected:یا
#
# 0.GroundTruth:میں کارپینٹر  ہوں
#
# 0.Transcribed:یسا پررہو
# 0.LMCorrected:یا پردہ
#
# 0.GroundTruth:انیس
#
# 0.Transcribed:دوناک
# 0.LMCorrected:ہونا
#
# 0.GroundTruth:کہ ایک شخص کہ جس سے پانچ سال میں
#
# 0.Transcribed:ساسامیں
# 0.LMCorrected:ساسامیں
#
# 0.GroundTruth:دو ہزار چھ
#
# 0.Transcribed:دہزار
# 0.LMCorrected:ہزار
#
# 0.GroundTruth:پچاسی
#
# 0.Transcribed:پون
# 0.LMCorrected:کون
#
# 0.GroundTruth:میں نے دو ہزار بارہ  میں بارہویں مکمل کی ہے
#
# 0.Transcribed:م اں ساف ریکیہ
# 0.LMCorrected:م اب اف ریزہ
#
# 0.GroundTruth:میں نے نویں جماعت تک پڑھا ہے
#
# 0.Transcribed: اہوی جماک پڑھا
# 0.LMCorrected:ہوی جمال پڑھا
#
# 0.GroundTruth:چھیاسٹھ
#
# 0.Transcribed:چیا
# 0.LMCorrected:یا
#
# 0.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 0.Transcribed:سال ا  ہویس ا کی
# 0.LMCorrected:سال ا آویس ا کی
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:ی
# 0.LMCorrected:ی
#
# 0.GroundTruth:زیادہ تر
#
# 0.Transcribed:زاے
# 0.LMCorrected:اے
#
# 0.GroundTruth:حضور نبی کریم صلی اللہ علیہ وسلم سے دعا فرمائی
#
# 0.Transcribed:بی  سس س وس
# 0.LMCorrected:بی سی س اس
#
# 0.GroundTruth:دو ہزار ایک
#
# 0.Transcribed:سیس
# 0.LMCorrected:سی
#
# 0.GroundTruth:انيس سو اٹھانوے
#
# 0.Transcribed:س سوھاو
# 0.LMCorrected:س سودا
#
# 0.GroundTruth:سینتیس
#
# 0.Transcribed: اساننیس
# 0.LMCorrected:اساننیس
#
# 0.GroundTruth:اناسی
#
# 0.Transcribed:اای
# 0.LMCorrected:اسی
#
# 0.GroundTruth:دو ہزار سات
#
# 0.Transcribed:بیاہای
# 0.LMCorrected:باہمی
#
# 0.GroundTruth:اکیاون
#
# 0.Transcribed:ین
# 0.LMCorrected:یا
#
# 0.GroundTruth:بہتر
#
# 0.Transcribed:ن
# 0.LMCorrected:ن
#
# 0.GroundTruth:بائیس
#
# 0.Transcribed:ا بای
# 0.LMCorrected:ا بھی
#
# 0.GroundTruth:آٹھ
#
# 0.Transcribed:دسا
# 0.LMCorrected:دیا
#
# 0.GroundTruth:ورچوئل یونیورسٹی آف پاکستان کا سلسلہ تدریس بی ایڈ انرز کا کورس مطالعہ اردو ادب
#
# 0.Transcribed:ھرسسا سا سریسمی اسککو سادوا
# 0.LMCorrected:رستا سا رسمی اسکو سادگی
#
# 0.GroundTruth:صرف میر کے لیے نہیں تھے
#
# 0.Transcribed:ک
# 0.LMCorrected:ک
#
# 0.GroundTruth:میں گیارہویں پاس ہوں
#
# 0.Transcribed:ینسییسباس
# 0.LMCorrected:ینسییسباس
#
# 0.GroundTruth:میں نے ایف ایس سی کیا ہے
#
# 0.Transcribed:میں می  ساسیکی
# 0.LMCorrected:میں می کلاسیکی
#
# 0.GroundTruth:ساٹھ
#
# 0.Transcribed:پسات
# 0.LMCorrected:سات
#
# 0.GroundTruth:چوسٹھ
#
# 0.Transcribed:واس
# 0.LMCorrected:اس
#
# 0.GroundTruth:پر شکوہ سادگی سلاست نادر خیالی
#
# 0.Transcribed:اواے تاپنا
# 0.LMCorrected:اوے اپنا
#
# 0.GroundTruth:یہ دل بھی تو آخر جسم کا حصہ ہی ہے
#
# 0.Transcribed:اوغ سیے
# 0.LMCorrected:اور سے
#
# 0.GroundTruth:تین
#
# 0.Transcribed:ش  تتک
# 0.LMCorrected:و تک
#
# 0.GroundTruth:دو ہزار تیرہ
#
# 0.Transcribed:سااایرا  ت
# 0.LMCorrected:سااایرا ت
#
# 0.GroundTruth:انچاس
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:دو ہزار انیس
#
# 0.Transcribed:دوہزا نس
# 0.LMCorrected:دوہرا اس
#
# 0.GroundTruth:چھیاسٹھ
#
# 0.Transcribed:ارسکہ
# 0.LMCorrected:راستہ
#
# 0.GroundTruth:چودہ
#
# 0.Transcribed:استا
# 0.LMCorrected:استاد
#
# 0.GroundTruth:چھیاسٹھ
#
# 0.Transcribed:و
# 0.LMCorrected:و
#
# 0.GroundTruth:انیس
#
# 0.Transcribed:ادا
# 0.LMCorrected:ادا
#
# 0.GroundTruth:میں میٹرک پاس ہوں
#
# 0.Transcribed:می   ا
# 0.LMCorrected:می ا
#
# 0.GroundTruth:میں ڈرائیور ہوں
#
# 0.Transcribed:می افسا ک
# 0.LMCorrected:می ایسا ک
#
# 0.GroundTruth:چورانوے
#
# 0.Transcribed:ل
# 0.LMCorrected:ل
#
# 0.GroundTruth:انيس سو پچانوے
#
# 0.Transcribed:وبیس سار
# 0.LMCorrected:چوبیس سال
#
# 0.GroundTruth:انچاس
#
# 0.Transcribed:اس
# 0.LMCorrected:اس
#
# 0.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 0.Transcribed:ما ا ر  ہ
# 0.LMCorrected:یا ا ر ہ
#
# 0.GroundTruth:انيس سو اٹھانوے
#
# 0.Transcribed:پان س
# 0.LMCorrected:ان س
#
# 0.GroundTruth:تہتر
#
# 0.Transcribed:اا
# 0.LMCorrected:کا
#
# 0.GroundTruth:میں چھ  سال سے یہ کام کر رہا ہوں
#
# 0.Transcribed:می سالسیہ کام کر ہاہو
# 0.LMCorrected:می سلسلہ کام کر ہو
#
# 0.GroundTruth:ساٹھ
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:کاغذی ہے پیراہن ہر پیکر تصویر کا
#
# 0.Transcribed:کاف وسسی کا
# 0.LMCorrected:کا وسطی کا
#
# 0.GroundTruth:میں نے دو ہزار آٹھ میں نویں مکمل کی ہے
#
# 0.Transcribed:نے و ہزر آمی کاوی مے
# 0.LMCorrected:نے و ہزار آئی کافی ہے
#
# 0.GroundTruth:پینتیس
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:تہتر
#
# 0.Transcribed:س را
# 0.LMCorrected:س کا
#
# 0.GroundTruth:چونتیس
#
# 0.Transcribed: تر ان
# 0.LMCorrected:تر ان
#
# 0.GroundTruth:چھیاسی
#
# 0.Transcribed:پاس
# 0.LMCorrected:پاس
#
# 0.GroundTruth:انيس سو ستانوے
#
# 0.Transcribed:پانسر
# 0.LMCorrected:پاس
#
# 0.GroundTruth:انسٹھ
#
# 0.Transcribed:وپیا
# 0.LMCorrected:یا
#
# 0.GroundTruth:انيس سو اٹھاسی
#
# 0.Transcribed:نس سواھاس
# 0.LMCorrected:نے سوالات
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:مے ک حال ہی کی
# 0.LMCorrected:کے ک حال ہی کی
#
# 0.GroundTruth:چھیاسی
#
# 0.Transcribed:نل  ای
# 0.LMCorrected:نے ای
#
# 0.GroundTruth:بیالیس
#
# 0.Transcribed:داسل
# 0.LMCorrected:اسل
#
# 0.GroundTruth:انيس سو ستاسی
#
# 0.Transcribed:ونسزاسی
# 0.LMCorrected:ونسزاسی
#
# 0.GroundTruth:اکانوے
#
# 0.Transcribed:ی
# 0.LMCorrected:ی
#
# 0.GroundTruth:ایک
#
# 0.Transcribed:اکر
# 0.LMCorrected:اور
#
# 0.GroundTruth:دو ہزار
#
# 0.Transcribed:ا سر
# 0.LMCorrected:ا سر
#
# 0.GroundTruth:دو ہزار چھ
#
# 0.Transcribed:د
# 0.LMCorrected:د
#
# 0.GroundTruth:اناسی
#
# 0.Transcribed:چی ا س
# 0.LMCorrected:کی ا س
#
# 0.GroundTruth:انيس سو اکاسي
#
# 0.Transcribed:انسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:کیونکہ زندگی ہے تو اس میں مشکلات ہوں گی
#
# 0.Transcribed:دسے سو چا ی
# 0.LMCorrected:سے سو کا ی
#
# 0.GroundTruth:ہم نے ان کی شاعری کے مختلف ادوار کا جائزہ لیا
#
# 0.Transcribed:ی مسواکجسل
# 0.LMCorrected:ی مسواکجسل
#
# 0.GroundTruth:الگ پہچان رکھتے ہیں امتیاز رکھتے ہیں کہ امتیاز ہیں جاویدانی ہے
#
# 0.Transcribed:گسدستے تے وتا  س ے
# 0.LMCorrected:گسدستے بے وفا س کے
#
# 0.GroundTruth:تینتالیس
#
# 0.Transcribed:نالیس
# 0.LMCorrected:چالیس
#
# 0.GroundTruth:انيس سو چوراسی
#
# 0.Transcribed:ونی س اسی
# 0.LMCorrected:وہی س اسی
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed:مر س
# 0.LMCorrected:پر س
#
# 0.GroundTruth:میرا نام علی ہے
#
# 0.Transcribed:میراای
# 0.LMCorrected:میری
#
# 0.GroundTruth:تراسی
#
# 0.Transcribed:تس
# 0.LMCorrected:اس
#
# 0.GroundTruth:وہ یہ کہتے ہیں کہ ہم کسی بھی صورت میں دوسرے کے سامنے جھکنے کے یا دوسرے پر اپنی کسما پرسی  ثابت کرنے کے قائل نہیں
#
# 0.Transcribed:ساوز سوتن ے  طر ارکسپس ساس کجہا
# 0.LMCorrected:سوز سوتا لے کر ارکسپس اس کہا
#
# 0.GroundTruth:اٹھائیس
#
# 0.Transcribed:پٹھس
# 0.LMCorrected:پھر
#
# 0.GroundTruth:انيس سو نواسی
#
# 0.Transcribed:س سوای
# 0.LMCorrected:س سوال
#
# 0.GroundTruth:میری عمر اکیس سال ہے
#
# 0.Transcribed:می  انایسا ر
# 0.LMCorrected:می ایسا ر
#
# 0.GroundTruth:اکیاون
#
# 0.Transcribed:ایس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:انيس سو ستاسی
#
# 0.Transcribed:انس سو سا
# 0.LMCorrected:انس سو سا
#
# 0.GroundTruth:وہ پیار وہ خلوص و لطافت وہ احترام
#
# 0.Transcribed:بیارہ سلتترا
# 0.LMCorrected:بارہ ستتر
#
# 0.GroundTruth:انہتر
#
# 0.Transcribed:ااا
# 0.LMCorrected:انا
#
# 0.GroundTruth:دو ہزار بیس
#
# 0.Transcribed:ا ہاس
# 0.LMCorrected:ا اس
#
# 0.GroundTruth:انيس سو ننانوے
#
# 0.Transcribed:دنس سیس
# 0.LMCorrected:دن سی
#
# 0.GroundTruth:انتیس
#
# 0.Transcribed:ان تس
# 0.LMCorrected:ان اس
#
# 0.GroundTruth:میں اس سے کچھ مختلف اخذ کرو لیکن ہم دونوں کا آغاز کردہ نتیجہ درست بھی ہو منطقی بھی دلچسپ بھی موثر بھی اور بلیغ بھی
#
# 0.Transcribed:سساسدیرا اسب و س پیس
# 0.LMCorrected:سساسدیرا اس و س پاس
#
# 0.GroundTruth:اپنا راستہ تبدیل کر گئے یا اپنا انداز تخاطب بدل گئے بلکہ دراصل ہر سال ہر شخص ایک خاص فکری اور ذہنی ارتقائی عمل سے گزرتا ہے
#
# 0.Transcribed:ارست گ اگسساساسیترک ونی تغای مگزرڑتہے
# 0.LMCorrected:درست گ اگسساساسیترک بنی تھی مگزرڑتہے
#
# 0.GroundTruth:میں کارپینٹر ہو
#
# 0.Transcribed:بی اہ ے
# 0.LMCorrected:بی اے کے
#
# 0.GroundTruth:اناسی
#
# 0.Transcribed:پنے
# 0.LMCorrected:نے
#
# 0.GroundTruth:بہتر
#
# 0.Transcribed:باا
# 0.LMCorrected:بات
#
# 0.GroundTruth:دو ہزار انیس
#
# 0.Transcribed:وونیس
# 0.LMCorrected:انیس
#
# 0.GroundTruth:دو ہزار
#
# 0.Transcribed:ی ی ا
# 0.LMCorrected:ی ی ا
#
# 0.GroundTruth:میں نے ایف ایس سی تک تعلیم حاصل کی ہے
#
# 0.Transcribed:ی می اسی ال
# 0.LMCorrected:ی می اسی ال
#
# 0.GroundTruth:بعدازاں اس نے سندھ پر قبضہ کیا اور ملتان تک آیا
#
# 0.Transcribed:زاسسسس کیا زانکر
# 0.LMCorrected:زاسسسس کیا اندر
#
# 0.GroundTruth:الہامی روشنی
#
# 0.Transcribed:میر
# 0.LMCorrected:میر
#
# 0.GroundTruth:لیکن بصد افسوس ہر انسان کو اس کا ادراک نہیں ہوپاتا ہر انسان اس حقیقت کو پہچان نہیں پاتا
#
# 0.Transcribed:سوسسسکا ارری وپتا رنسنی  ش ا
# 0.LMCorrected:سوسسسکا اثری پتا انسانی ط ا
#
# 0.GroundTruth:انيس سو چورانوے
#
# 0.Transcribed:ن ساوی
# 0.LMCorrected:ن حاوی
#
# 0.GroundTruth:انيس سو بياسي
#
# 0.Transcribed:میس سااتاسی
# 0.LMCorrected:میں ستاسی
#
# 0.GroundTruth:کس نوعیت کے مسائل کا سامنا کرنا پڑا اور پھر بعد میں ہم نے گفتگو کی ان کے اوساف شعری کے حوالے سے
#
# 0.Transcribed:ساسسانڑا ب ہرے سدوی کساسری ہ ل سے
# 0.LMCorrected:ساسسانڑا ب ہے دوی ساری ہ ل سے
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:پچ
# 0.LMCorrected:پر
#
# 0.GroundTruth:اس کی ایک خاص شان نزول ہے
#
# 0.Transcribed:سکیانوے
# 0.LMCorrected:اکانوے
#
# 0.GroundTruth:انيس سو ستانوے
#
# 0.Transcribed:ان س سارا
# 0.LMCorrected:ان س سارا
#
# 0.GroundTruth:اور یہ ترقی اردو شاعری کو محض سوا سو سالوں میں حاصل ہوگی
#
# 0.Transcribed:ی ا کوازساسوسامیلک
# 0.LMCorrected:ی ا کوازساسوسامیلک
#
# 0.GroundTruth:بیس
#
# 0.Transcribed:اہی
# 0.LMCorrected:ہی
#
# 0.GroundTruth:ہمارا جسم بھی زار زار زخموں سے چور ہے
#
# 0.Transcribed:اسبز  سو
# 0.LMCorrected:سبز سو
#
# 0.GroundTruth:اکیس
#
# 0.Transcribed: ی
# 0.LMCorrected:ی
#
# 0.GroundTruth:چہرے کے تاثرات یا جسمانی حرکات وسکنات کے ذریعے
#
# 0.Transcribed:چسا سان کاناتے
# 0.LMCorrected:سا ان کائنات
#
# 0.GroundTruth:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 0.Transcribed:ن  سرر کیا
# 0.LMCorrected:ن سر کیا
#
# 0.GroundTruth:ایک
#
# 0.Transcribed:را
# 0.LMCorrected:کا
#
# 0.GroundTruth:میں ڈرائیونگ کا کام جانتا ہوں
#
# 0.Transcribed:سا  و ا
# 0.LMCorrected:سا و ا
#
# 0.GroundTruth:غزل کی تشریح کی طرف
#
# 0.Transcribed:زکی کی تر
# 0.LMCorrected:کی کی تر
#
# 0.GroundTruth:سب سے پہلے
#
# 0.Transcribed:ساس
# 0.LMCorrected:اس
#
# 0.GroundTruth:سو
#
# 0.Transcribed:مرارس
# 0.LMCorrected:مدارس
#
# 0.GroundTruth:اب  اگر اس بیان پر نظر کی جائے تو یہ کوئی لسانی تحقیق یا لسانیاتی نوعیت کا کوئی بیان نہیں
#
# 0.Transcribed:تانکل دساتیکسایرای ریکریا
# 0.LMCorrected:انکل دساتیکسایرای ریکریا
#
# 0.GroundTruth:میرا سات سال کا تجربہ ہے
#
# 0.Transcribed:میسسالکیجباا ے
# 0.LMCorrected:میسسالکیجباا کے
#
# 0.GroundTruth:میرا تجربہ آٹھ سال ہے
#
# 0.Transcribed:میج رفسا
# 0.LMCorrected:میں رہتا
#
# 0.GroundTruth:انيس سو اکانوے
#
# 0.Transcribed:نسری ایور
# 0.LMCorrected:نثری اور
#
# 0.GroundTruth:اٹھہتر
#
# 0.Transcribed:ای ٹ
# 0.LMCorrected:ای و
#
# 0.GroundTruth:اکیاون
#
# 0.Transcribed:چی ا
# 0.LMCorrected:کی ا
#
# 0.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 0.Transcribed:س سایں کئی زا
# 0.LMCorrected:س سکیں کئی کا
#
# 0.GroundTruth:دو ہزار نو
#
# 0.Transcribed:تد ست
# 0.LMCorrected:تو ست
#
# 0.GroundTruth:باون
#
# 0.Transcribed:یب
# 0.LMCorrected:یا
#
# 0.GroundTruth:تین
#
# 0.Transcribed:ا ےا
# 0.LMCorrected:ا یا
#
# 0.GroundTruth:چھ
#
# 0.Transcribed:چھیا
# 0.LMCorrected:چھین
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی
#
# 0.Transcribed:بو اسری
# 0.LMCorrected:و ساری
#
# 0.GroundTruth:ترسٹھ
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:کل پاؤں ایک کاسہ سر پر جو آگیا
#
# 0.Transcribed:یہکسسرر دو
# 0.LMCorrected:یہکسسرر دو
#
# 0.GroundTruth:اکیاون
#
# 0.Transcribed:یائی
# 0.LMCorrected:پائی
#
# 0.GroundTruth:اڑتیس
#
# 0.Transcribed:پس
# 0.LMCorrected:پس
#
# 0.GroundTruth:میرا پیشہ کارپینٹر ہے
#
# 0.Transcribed:دویس ہ  کا
# 0.LMCorrected:دوی ہ کا
#
# 0.GroundTruth:دو ہزار دس
#
# 0.Transcribed:  ز
# 0.LMCorrected:ز
#
# 0.GroundTruth:اٹھسٹھ
#
# 0.Transcribed:آیس
# 0.LMCorrected:آیا
#
# 0.GroundTruth:چوالیس
#
# 0.Transcribed:سا ن یس
# 0.LMCorrected:سا ن یس
#
# 0.GroundTruth:چوسٹھ
#
# 0.Transcribed: شنااا
# 0.LMCorrected:بنایا
#
# 0.GroundTruth:اگر ہم مغربی علوم کی بات کریں عزیز طلباء تو میتھیو آرنلڈ کی تنقیدات اور ٹی ایس ایلیٹ کی تنقیدات
#
# 0.Transcribed: ر کاسزیسبامیس ہو ارا ڑتییکی ا
# 0.LMCorrected:ر کاسزیسبامیس ہو انا ڑتییکی ا
#
# 0.GroundTruth:چھیالیس
#
# 0.Transcribed:س ی سا
# 0.LMCorrected:س ی سا
#
# 0.GroundTruth:اب دیکھے ہوتا کچھ یوں ہے کہ جب
#
# 0.Transcribed:ا ت   س
# 0.LMCorrected:ا ت س
#
# 0.GroundTruth:میں ڈرائیور ہوں
#
# 0.Transcribed:سس
# 0.LMCorrected:سے
#
# 0.GroundTruth:دس
#
# 0.Transcribed: یس
# 0.LMCorrected:یس
#
# 0.GroundTruth:میرا تجربہ پانچ  سال کا ہے
#
# 0.Transcribed:یس سر سانے
# 0.LMCorrected:یس سر جانے
#
# 0.GroundTruth:میں نے ایف ایس سی تک تعلیم حاصل کی ہے
#
# 0.Transcribed:مینےسی ا تال اے
# 0.LMCorrected:مینے ا حال اے
#
# 0.GroundTruth:میں اسلام آباد میں رہتا ہوں
#
# 0.Transcribed: ے تساا ہ ے
# 0.LMCorrected:کے تمام ہ کے
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:چھیاسٹھ
#
# 0.Transcribed: سی ہ
# 0.LMCorrected:سی ہ
#
# 0.GroundTruth:انيس سو اٹھانوے
#
# 0.Transcribed:انساڑ
# 0.LMCorrected:انسان
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:میں نے آٹھویں تک تعلیم حاصل کی ہے
#
# 0.Transcribed:  ہے او  حا
# 0.LMCorrected:ہے او کا
#
# 0.GroundTruth:پینتالیس
#
# 0.Transcribed:پس
# 0.LMCorrected:پس
#
# 0.GroundTruth:جسکے کے ذریعے اپنی بات دوسروں تک پہنچانا ہیں
#
# 0.Transcribed:سانیاافس ر
# 0.LMCorrected:سانیاافس ر
#
# 0.GroundTruth:بہتر
#
# 0.Transcribed:چ اریے
# 0.LMCorrected:و ایک
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed: ون  سہ
# 0.LMCorrected:ون سہ
#
# 0.GroundTruth:چوراسی
#
# 0.Transcribed:رای
# 0.LMCorrected:رہی
#
# 0.GroundTruth:دو ہزار آٹھ
#
# 0.Transcribed:ا ہزا
# 0.LMCorrected:ا ہوا
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:سے
# 0.LMCorrected:سے
#
# 0.GroundTruth:اکبر الہ آبادی کے بغیر مکمل نہیں ہوتی
#
# 0.Transcribed:وا وسرکات
# 0.LMCorrected:وا واردات
#
# 0.GroundTruth:میں نے  دو ہزار بارہ میں ایف ایس سی کی ہے
#
# 0.Transcribed: دو دواروی س
# 0.LMCorrected:دو داروں س
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed:چان
# 0.LMCorrected:ان
#
# 0.GroundTruth:میں نے دو ہزار سولہ میں ایف ایس سی مکمل کی ہے
#
# 0.Transcribed:ے دو اارسلامیں سسی ی
# 0.LMCorrected:نے دو اارسلامیں کسی ی
#
# 0.GroundTruth:تراسی
#
# 0.Transcribed:تراس
# 0.LMCorrected:ترس
#
# 0.GroundTruth:چوبیس
#
# 0.Transcribed:ابیس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:سے
# 0.LMCorrected:سے
#
# 0.GroundTruth:چنانچہ حالی نے
#
# 0.Transcribed:چناس
# 0.LMCorrected:اس
#
# 0.GroundTruth:دو ہزار اٹھارہ
#
# 0.Transcribed:سک اٹھ
# 0.LMCorrected:سے اٹھا
#
# 0.GroundTruth:میں نے میٹرک کیا ہے
#
# 0.Transcribed:امیچ کی ا  ے
# 0.LMCorrected:امید کی ا ب
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے چالیس سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed:س ی کن کروسکرسبوئیے
# 0.LMCorrected:س ی کن کروسکرسبوئیے
#
# 0.GroundTruth:دو ہزار تین
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:میرا پیشہ کارپینٹر ہے
#
# 0.Transcribed:و یری سایے ے
# 0.LMCorrected:و میری سارے کے
#
# 0.GroundTruth:انيس سو ترانوے
#
# 0.Transcribed:انر سوس
# 0.LMCorrected:اور سو
#
# 0.GroundTruth:اٹھارہ
#
# 0.Transcribed:اٹا
# 0.LMCorrected:انا
#
# 0.GroundTruth:میرا نام حمزہ ہے
#
# 0.Transcribed:س استی کا
# 0.LMCorrected:س اسی کا
#
# 0.GroundTruth:انيس سو ننانوے
#
# 0.Transcribed:اس
# 0.LMCorrected:اس
#
# 0.GroundTruth:دو
#
# 0.Transcribed:چو
# 0.LMCorrected:کو
#
# 0.GroundTruth:میں نے ایف ایس سی کیا ہے
#
# 0.Transcribed:اس س کی ے
# 0.LMCorrected:اس س کی ہے
#
# 0.GroundTruth:چودہ
#
# 0.Transcribed: چس
# 0.LMCorrected:اس
#
# 0.GroundTruth:اکتیس
#
# 0.Transcribed:دایس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:یعنی شاعر بتاتا ہے کہ آج جو کچھ ہے ضروری نہیں کہ وہ کل رہے
#
# 0.Transcribed:نسااے ریر کو ے
# 0.LMCorrected:سارے میر کو کے
#
# 0.GroundTruth:سات
#
# 0.Transcribed:چد
# 0.LMCorrected:چند
#
# 0.GroundTruth:چوہتر
#
# 0.Transcribed:سچاس
# 0.LMCorrected:پچاس
#
# 0.GroundTruth:دو ہزار انیس
#
# 0.Transcribed:و
# 0.LMCorrected:و
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے دس سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed:د یہ اوکہواے
# 0.LMCorrected:د یہ اوکہواے
#
# 0.GroundTruth:میں ڈلیوری بوائے ہوں
#
# 0.Transcribed:ماایسی باہو
# 0.LMCorrected:ایسی باہر
#
# 0.GroundTruth:بیس
#
# 0.Transcribed:وبیس
# 0.LMCorrected:بیس
#
# 0.GroundTruth:یعنی حماوس کا وہ نظریہ کہ جس کے تحت یہ خیال کیا جاتا ہے کہ ہر طرف رب کائنات کی ذات جلوہ گر ہے
#
# 0.Transcribed:ی وازری اپیے استاے تا کی سابسہ
# 0.LMCorrected:ی شاعری اپنے استاد تا کی سابقہ
#
# 0.GroundTruth:میرا فون نمبر یہ ہے 03120000567
#
# 0.Transcribed:نیسیہیا س  اسرڑااس
# 0.LMCorrected:نیسیہیا س اسرڑااس
#
# 0.GroundTruth:میری عمر اکیس سال ہے
#
# 0.Transcribed:ی التی  ی س اسا
# 0.LMCorrected:ی ملتی ی س اس
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:بسککوایایہ کی
# 0.LMCorrected:بسککوایایہ کی
#
# 0.GroundTruth:میرا تجربہ آٹھ  سال ہے
#
# 0.Transcribed:اباھ
# 0.LMCorrected:بات
#
# 0.GroundTruth: عزیز طلباء
#
# 0.Transcribed:اس
# 0.LMCorrected:اس
#
# 0.GroundTruth:دراصل ابتدا میں نےمیں نے عرض کی تھی قصیدے کے اوّلین جزو تشبیب کی
#
# 0.Transcribed: ااسس  ار سم کی
# 0.LMCorrected:اساس ار سم کی
#
# 0.GroundTruth:میں نے گیارہویں تک پڑھا ہے
#
# 0.Transcribed:وی تیویی ا کا پر
# 0.LMCorrected:کی تصویر ا کا پر
#
# 0.GroundTruth:عزیز طلبہ ہم نے گزشتہ لیکچر میں بات کی زبان اور اردو زبان کی تاریخ کے حوالے سے
#
# 0.Transcribed: سمیںکیک  ڑا کی تریالسے
# 0.LMCorrected:سمیںکیک کا کی تریالسے
#
# 0.GroundTruth:شباب عمر نے کھویا طمع نے دین لیا ٹھگوں نے ہم سے بڑی نعمتوں کو چھین لیا
#
# 0.Transcribed:س ک باھ اسراگوا ے ڑسزییا
# 0.LMCorrected:س ک بات اسراگوا کے ڑسزییا
#
# 0.GroundTruth:میں نے پانچ سال کام کیا ہے
#
# 0.Transcribed:می  ا  پانس کا  کیہ
# 0.LMCorrected:می ا پاس کا یہ
#
# 0.GroundTruth:دو ہزار چودہ
#
# 0.Transcribed:ن اچ  ا
# 0.LMCorrected:ن اس ا
#
# 0.GroundTruth:تیس
#
# 0.Transcribed: بایسر
# 0.LMCorrected:ایسا
#
# 0.GroundTruth:میرا چھ سال کا تجربہ ہے
#
# 0.Transcribed:میرا سال کاتجربہ ہ
# 0.LMCorrected:میرا سال تجربہ ہ
#
# 0.GroundTruth:انيس سو چورانوے
#
# 0.Transcribed:اگی سسا رن
# 0.LMCorrected:اگر سا ان
#
# 0.GroundTruth:میری عمر بارہ سال ہے
#
# 0.Transcribed:میر سبا  س ا
# 0.LMCorrected:میر سب س ا
#
# 0.GroundTruth:میرا پیشہ پلمبر ہے
#
# 0.Transcribed:ا را یہا
# 0.LMCorrected:ا کا یہ
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:بی
# 0.LMCorrected:بی
#
# 0.GroundTruth:روح کو راحت
#
# 0.Transcribed: کر
# 0.LMCorrected:کر
#
# 0.GroundTruth:اٹھہتر
#
# 0.Transcribed:تس پس
# 0.LMCorrected:تو پس
#
# 0.GroundTruth: شاید اس کی وجہ یہ ہے کہ اس میں موضوع کی کوئی قید نہیں یا
#
# 0.Transcribed:سوسیےس کا
# 0.LMCorrected:سوبیس کا
#
# 0.GroundTruth:اصناف شعر
#
# 0.Transcribed:زایس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:باسٹھ
#
# 0.Transcribed: ریل ڑلاے
# 0.LMCorrected:میل ملاپ
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:میر تقی میر نے 18 ویں صدی میں اردو شاعری کو وہ احساس تخاطب بخشا کہ ادبیات عالم میں اردو شاعری اور اردو شاعری کی روایت میں میر عمر ہوگے
#
# 0.Transcribed:را تھارسدووکو پواا شا ب تےا ی اوسا چکاری وہ
# 0.LMCorrected:کا تھارسدووکو پورا ا ب تھا ی ایسا کاری وہ
#
# 0.GroundTruth:دس
#
# 0.Transcribed:نا
# 0.LMCorrected:نا
#
# 0.GroundTruth:وہ اٹھارویں صدی کے جس میں اورنگزیب عالمگیر کی وفات کے بعد مغلیہ سلطنت بہت تیزی سے زوال کا شکار ہونے لگی تھی
#
# 0.Transcribed:ٹٹھرے سری  س ڑی سا با ہجسستسکشکاہنلی
# 0.LMCorrected:پھرے سر س کی سا با ہجسستسکشکاہنلی
#
# 0.GroundTruth:تیرہ
#
# 0.Transcribed:چ
# 0.LMCorrected:و
#
# 0.GroundTruth:کیوں کہ غالب کے لیے شاید محبوب سے زیادہ محبت عزیز تر تھی
#
# 0.Transcribed:جاتچاوسس ا کیس
# 0.LMCorrected:جاتچاوسس ا کی
#
# 0.GroundTruth:اکبر کے محاسن شعری کی بات کریں
#
# 0.Transcribed:کے سرس ی با
# 0.LMCorrected:کے سر ی با
#
# 0.GroundTruth:پچاسی
#
# 0.Transcribed:رپچ
# 0.LMCorrected:رپٹ
#
# 0.GroundTruth:اٹھانوے
#
# 0.Transcribed:ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:انيس سو چوراسی
#
# 0.Transcribed:انسو چراسی
# 0.LMCorrected:آنسو تراسی
#
# 0.GroundTruth:بانوے
#
# 0.Transcribed:و
# 0.LMCorrected:و
#
# 0.GroundTruth:ان کے والد گرامی بھی ان کی پیدائش سے پہلے ہی وفات پا گئے
#
# 0.Transcribed:اااویوی ا سوفاتازری
# 0.LMCorrected:اااویوی ا سوفاتازری
#
# 0.GroundTruth:ان کی ماضی پرستی بھی کہی جا سکتی ہے
#
# 0.Transcribed: اسمی است
# 0.LMCorrected:اسی اس
#
# 0.GroundTruth:میں چھ سال سے یہ کام کر رہا ہوں
#
# 0.Transcribed: سا ر کاا رہہں
# 0.LMCorrected:سا ر کا رہیں
#
# 0.GroundTruth:پینسٹھ
#
# 0.Transcribed: ت
# 0.LMCorrected:ت
#
# 0.GroundTruth:میں نے پانچ  سال کام کیا ہے
#
# 0.Transcribed:مییست پسساکاانی
# 0.LMCorrected:میسر پسساکاانی
#
# 0.GroundTruth:میں سمجھتا ہوں کہ اس میں کوئی شک نہیں کہ میر نے اس شعر میں شاعرانہ تعلی کی ہوگی
#
# 0.Transcribed:سسن سرردا تا یوگ
# 0.LMCorrected:حسن سودا تا یوں
#
# 0.GroundTruth:کے افتتاحی لیکچر کے ساتھ میں ہوں فیصل کمال حیدری
#
# 0.Transcribed:ساکسو سکادری
# 0.LMCorrected:اسکو سادگی
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:می کیتاحاصک
# 0.LMCorrected:می کیتاحاصک
#
# 0.GroundTruth:ستاسی
#
# 0.Transcribed:کسا
# 0.LMCorrected:کسا
#
# 0.GroundTruth:چھیاسٹھ
#
# 0.Transcribed:چااسٹ
# 0.LMCorrected:ایسٹ
#
# 0.GroundTruth:اکتیس
#
# 0.Transcribed:دا
# 0.LMCorrected:دا
#
# 0.GroundTruth:میں نے دسویں جماعت تک پڑھا ہے
#
# 0.Transcribed:ن تینہیما پڑھا
# 0.LMCorrected:ن تینہیما پڑھا
#
# 0.GroundTruth:دو ہزار سولہ
#
# 0.Transcribed:دزاا
# 0.LMCorrected:دیا
#
# 0.GroundTruth:میں نے دسویں  جماعت تک پڑھا ہے
#
# 0.Transcribed:میلریسی ماہا
# 0.LMCorrected:میلریسی ماہ
#
# 0.GroundTruth:میں نے چارسال کام کیا ہے
#
# 0.Transcribed:یسسا کام کی
# 0.LMCorrected:یا کام کی
#
# 0.GroundTruth:پچاسی
#
# 0.Transcribed:ساریو
# 0.LMCorrected:ساری
#
# 0.GroundTruth:باون
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:کہا اگر کسی نے کہ کچھ کھائیے
#
# 0.Transcribed:ااس پکر
# 0.LMCorrected:اس پر
#
# 0.GroundTruth:سینتالیس
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth: تو اردو زبان کے متعلق پہلا نظریہ
#
# 0.Transcribed: ہا یاہ
# 0.LMCorrected:ہا یا
#
# 0.GroundTruth:میں میٹرک پاس ہوں
#
# 0.Transcribed:یفں ری اک
# 0.LMCorrected:یوں ری اک
#
# 0.GroundTruth:نصیرالدین ہاشمی کا یہ خیال تھا
#
# 0.Transcribed:سد میکسل
# 0.LMCorrected:سے مکمل
#
# 0.GroundTruth:انيس سو اکاسي
#
# 0.Transcribed:امیس سستکی
# 0.LMCorrected:ایس سکتی
#
# 0.GroundTruth:دو ہزار بیس
#
# 0.Transcribed:ندریس
# 0.LMCorrected:تدریس
#
# 0.GroundTruth:انيس سو تراسی
#
# 0.Transcribed: سای
# 0.LMCorrected:اسی
#
# 0.GroundTruth:بدآموزی عدو یعنی دشمن کی ناراضگی
#
# 0.Transcribed:ی و لیڑکرارا
# 0.LMCorrected:ی و لیڑکرارا
#
# 0.GroundTruth:انيس سو ستانوے
#
# 0.Transcribed:ونا
# 0.LMCorrected:ہونا
#
# 0.GroundTruth:اکیس
#
# 0.Transcribed:اکیس
# 0.LMCorrected:اکیس
#
# 0.GroundTruth:انيس سو ترانوے
#
# 0.Transcribed:انیس ساس
# 0.LMCorrected:انیس سال
#
# 0.GroundTruth:انيس سو ستانوے
#
# 0.Transcribed:انس سا و
# 0.LMCorrected:انس سا و
#
# 0.GroundTruth:میں نے دو ہزار اٹھارہ میں بارہویں مکمل کی ہے
#
# 0.Transcribed:نٹٹھمی ر ک کیے
# 0.LMCorrected:نٹٹھمی ر ک کیے
#
# 0.GroundTruth:عزیز طلباء گزشتہ لیکچرمیں میں نے بتایا تھا کہ میر تقی میر
#
# 0.Transcribed:سساس ا کہی کی ی
# 0.LMCorrected:حساس ا کہی کی ی
#
# 0.GroundTruth:تینتیس
#
# 0.Transcribed:انیس
# 0.LMCorrected:انیس
#
# 0.GroundTruth:انيس سو چھیانوے
#
# 0.Transcribed:سچان
# 0.LMCorrected:سچا
#
# 0.GroundTruth:اڑتیس
#
# 0.Transcribed:انس
# 0.LMCorrected:انس
#
# 0.GroundTruth:میر کہتے ہیں
#
# 0.Transcribed:ا کتے
# 0.LMCorrected:ا کے
#
# 0.GroundTruth:سینتالیس
#
# 0.Transcribed:دسس
# 0.LMCorrected:دس
#
# 0.GroundTruth:چالیس
#
# 0.Transcribed:ر تچل
# 0.LMCorrected:ر چل
#
# 0.GroundTruth:یہ غالب کی زندگی کا
#
# 0.Transcribed:پ اک ی کا
# 0.LMCorrected:پ اک ی کا
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed:سوا
# 0.LMCorrected:سوا
#
# 0.GroundTruth:بیالیس
#
# 0.Transcribed:میاس
# 0.LMCorrected:قیاس
#
# 0.GroundTruth:میں ڈیلیوری بوائے کا کام جانتی ہوں
#
# 0.Transcribed:یری بای کاجا
# 0.LMCorrected:مری بات کانا
#
# 0.GroundTruth:بیاسی
#
# 0.Transcribed:اس
# 0.LMCorrected:اس
#
# 0.GroundTruth:تیس
#
# 0.Transcribed:پار
# 0.LMCorrected:پر
#
# 0.GroundTruth:نو
#
# 0.Transcribed:ی سایس
# 0.LMCorrected:ی ایس
#
# 0.GroundTruth:کیسے  کہ غرور میں ہم خود کو تو بالاتر تصور کرتے ہیں لیکن
#
# 0.Transcribed:چس میں کاو گتےی
# 0.LMCorrected:اس میں کو تھی
#
# 0.GroundTruth:اکتالیس
#
# 0.Transcribed:ایس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:ان تینوں موجوں نے اردو ادب میں غزل کو سمندر کی سی وسعت دیدی
#
# 0.Transcribed:  ماے وایں ہکوسسستگی
# 0.LMCorrected:اے واں ہکوسسستگی
#
# 0.GroundTruth:اٹھاسی
#
# 0.Transcribed:باس
# 0.LMCorrected:اس
#
# 0.GroundTruth:انيس سو اسي
#
# 0.Transcribed:انیس س
# 0.LMCorrected:انیس س
#
# 0.GroundTruth:اٹھسٹھ
#
# 0.Transcribed:ی ا پ
# 0.LMCorrected:ی ا پ
#
# 0.GroundTruth:اور غرور کی بنیاد دوسروں کی تحقیر پر
#
# 0.Transcribed:و یاسپل
# 0.LMCorrected:و اسل
#
# 0.GroundTruth:دو ہزار چار
#
# 0.Transcribed:وستر
# 0.LMCorrected:ستر
#
# 0.GroundTruth:پینسٹھ
#
# 0.Transcribed:انس
# 0.LMCorrected:انس
#
# 0.GroundTruth:ترپن
#
# 0.Transcribed: اسگای
# 0.LMCorrected:اسی
#
# 0.GroundTruth:دو ہزار بیس
#
# 0.Transcribed:دوریس
# 0.LMCorrected:دوری
#
# 0.GroundTruth:پچہتر
#
# 0.Transcribed:سنل
# 0.LMCorrected:سال
#
# 0.GroundTruth:اور دوسرا مسئلہ یہ تھا کہ بیدل بذات خود ایک انتہائی مشکل پسند شاعر تھا
#
# 0.Transcribed:اسساویتو سسوستا
# 0.LMCorrected:اسساویتو سوتا
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:ایاس
# 0.LMCorrected:ایسا
#
# 0.GroundTruth:میرا تعلق کراچی سے ہے
#
# 0.Transcribed: کاچس ہ
# 0.LMCorrected:کا ہ
#
# 0.GroundTruth:ستتر
#
# 0.Transcribed:م  سا
# 0.LMCorrected:م سا
#
# 0.GroundTruth:ستاون
#
# 0.Transcribed:سن
# 0.LMCorrected:سن
#
# 0.GroundTruth:میرا تجربہ آٹھ سال ہے
#
# 0.Transcribed:میاس اڑ سس ے
# 0.LMCorrected:قیاس اس سے ہے
#
# 0.GroundTruth: عزیز طلباء تاریخ زبان اردو کے متعلق تو ہم بعد میں بات کریں گے سب سے پہلے ہم بات کرتے ہیں زبان کی
#
# 0.Transcribed:سون دال با یے سسے ہاتت
# 0.LMCorrected:سو دال با یے سے ہاتھ
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:انيس سو اکاسي
#
# 0.Transcribed:ن سوی
# 0.LMCorrected:ن سو
#
# 0.GroundTruth:اڑتیس
#
# 0.Transcribed:ان
# 0.LMCorrected:ان
#
# 0.GroundTruth:دو ہزار چار
#
# 0.Transcribed: سساا
# 0.LMCorrected:سال
#
# 0.GroundTruth:اسی سال یہ کام کرنا شروع کیا ہے
#
# 0.Transcribed:سسا کا کناشبوکیے
# 0.LMCorrected:سا کا کناشبوکیے
#
# 0.GroundTruth:میں نے چار سال کام کیا ہے
#
# 0.Transcribed: ن ے افال کا
# 0.LMCorrected:ن کے اطفال کا
#
# 0.GroundTruth:انيس سو ستانوے
#
# 0.Transcribed:انسسو ساو
# 0.LMCorrected:انیس سو
#
# 0.GroundTruth:اٹھائیس
#
# 0.Transcribed:اٹھاس
# 0.LMCorrected:اٹھا
#
# 0.GroundTruth:میری عمر چالیس سال ہے
#
# 0.Transcribed:م وننیتسارں
# 0.LMCorrected:م وننیتسارں
#
# 0.GroundTruth:تیس
#
# 0.Transcribed:یس
# 0.LMCorrected:یس
#
# 0.GroundTruth:ولی دکنی ہو میر درد میر تقی میر یا سودا یا کوئی بھی دوسرا شاعر ہوں ان کے ہاں واردات قلبی کا بیان تو ملتا ہی تھا
#
# 0.Transcribed:کنی و مییکینمیاوی  ہاک دتسد س
# 0.LMCorrected:کی و مییکینمیاوی پاک درست س
#
# 0.GroundTruth:دو ہزار تیرہ
#
# 0.Transcribed:دبوز سی
# 0.LMCorrected:دو سی
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:چونے
# 0.LMCorrected:ہونے
#
# 0.GroundTruth:پانچ
#
# 0.Transcribed:سر
# 0.LMCorrected:سر
#
# 0.GroundTruth:بانوے
#
# 0.Transcribed:م
# 0.LMCorrected:م
#
# 0.GroundTruth:میں نے آٹھویں جماعت تک پڑھا ہے
#
# 0.Transcribed:می  سوییں ا
# 0.LMCorrected:می سوچیں ا
#
# 0.GroundTruth:چار
#
# 0.Transcribed:یو
# 0.LMCorrected:یو
#
# 0.GroundTruth:اسی
#
# 0.Transcribed:اسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:میرا پیشہ کارپینٹر ہے
#
# 0.Transcribed:اری  دغارا ی
# 0.LMCorrected:اسی ہمارا ی
#
# 0.GroundTruth:سینتیس
#
# 0.Transcribed:سایس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:انيس سو پچانوے
#
# 0.Transcribed:ان س
# 0.LMCorrected:ان س
#
# 0.GroundTruth:انيس سو اسي
#
# 0.Transcribed:سساسی
# 0.LMCorrected:سیاسی
#
# 0.GroundTruth:پچیس
#
# 0.Transcribed:ٹہیس
# 0.LMCorrected:ہیس
#
# 0.GroundTruth:انيس سو تراسی
#
# 0.Transcribed:انسسوسی
# 0.LMCorrected:انسسوسی
#
# 0.GroundTruth:انيس سو اٹھانوے
#
# 0.Transcribed:ااوی
# 0.LMCorrected:حاوی
#
# 0.GroundTruth:اٹھہتر
#
# 0.Transcribed:ریسسا ر
# 0.LMCorrected:ایسا ر
#
# 0.GroundTruth:سینتیس
#
# 0.Transcribed:سا
# 0.LMCorrected:سا
#
# 0.GroundTruth:میرا فون نمبر یہ ہے03069459455
#
# 0.Transcribed:ونہ ےسیسسی وات زاچا
# 0.LMCorrected:وہ سیاسی بات جاتا
#
# 0.GroundTruth:پینتیس
#
# 0.Transcribed:ل اکنا
# 0.LMCorrected:ل اپنا
#
# 0.GroundTruth:اکہتر
#
# 0.Transcribed:کی
# 0.LMCorrected:کی
#
# 0.GroundTruth:بیاسی
#
# 0.Transcribed:اسارس
# 0.LMCorrected:اساس
#
# 0.GroundTruth:سڑسٹھ
#
# 0.Transcribed:سس ای
# 0.LMCorrected:سے ای
#
# 0.GroundTruth:اڑتالیس
#
# 0.Transcribed:اس ز
# 0.LMCorrected:اس ز
#
# 0.GroundTruth:نواسی
#
# 0.Transcribed:نا
# 0.LMCorrected:نا
#
# 0.GroundTruth:انيس سو چھیانوے
#
# 0.Transcribed:ایویس
# 0.LMCorrected:ایسی
#
# 0.GroundTruth:اٹھارہ
#
# 0.Transcribed:پرا
# 0.LMCorrected:پر
#
# 0.GroundTruth:میرا تجربہ سات سال ہے
#
# 0.Transcribed:متبار سس
# 0.LMCorrected:اعتبار سے
#
# 0.GroundTruth:یعنی مقتے میں غالب کہتے ہیں
#
# 0.Transcribed:اے غای
# 0.LMCorrected:اے ای
#
# 0.GroundTruth:تراسی
#
# 0.Transcribed:ا لولن ت
# 0.LMCorrected:ا لیکن ت
#
# 0.GroundTruth:انيس سو بياسي
#
# 0.Transcribed:انس س دراسی
# 0.LMCorrected:انس س تراسی
#
# 0.GroundTruth:دو
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:چالیس
#
# 0.Transcribed:چاے
# 0.LMCorrected:اے
#
# 0.GroundTruth:یعنی اگر انسان اپنی ذات کو جان لیں خود کو پہچان لے تو اس پر رب تعالیٰ کی ذات از خود کھل جاتی ہے
#
# 0.Transcribed:سا انساکوے  ک ساے تو سستی ہے
# 0.LMCorrected:سا انسانوں ک سے تو سکتی ہے
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے پانچ سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed: یہ کاکتحو تاڑس ل کاہو گے
# 0.LMCorrected:یہ کاکتحو اس ل کہو گے
#
# 0.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 0.Transcribed:میاا سسسو کاا
# 0.LMCorrected:میرا سروس کا
#
# 0.GroundTruth:بیس
#
# 0.Transcribed: ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:سہل ممتنع احساس محرومی گریہ زاری عشق
#
# 0.Transcribed:ا ساول زاری
# 0.LMCorrected:ا سال زاری
#
# 0.GroundTruth:کہ نبی آخر الزماں حضرت محمد مصطفی صلی اللہ علیہ وسلم
#
# 0.Transcribed:ویاس ماز  ساوال
# 0.LMCorrected:قیاس مان سوال
#
# 0.GroundTruth:سولہ
#
# 0.Transcribed:نسااہ
# 0.LMCorrected:سادہ
#
# 0.GroundTruth:عزیز طلبہ
#
# 0.Transcribed:سا
# 0.LMCorrected:سا
#
# 0.GroundTruth:بہتر
#
# 0.Transcribed:بار
# 0.LMCorrected:بار
#
# 0.GroundTruth:سو
#
# 0.Transcribed:ساال
# 0.LMCorrected:سال
#
# 0.GroundTruth:اٹھہتر
#
# 0.Transcribed:دجنس
# 0.LMCorrected:جس
#
# 0.GroundTruth:بیاسی
#
# 0.Transcribed:بیای
# 0.LMCorrected:بیان
#
# 0.GroundTruth:کوئی نئی زبان کس زبان سے پیدا ہوگی کوئی نئی زبان کن زبانوں کا ملغوبہ ہے
#
# 0.Transcribed:ساسوسپگئیساو
# 0.LMCorrected:ساسوسپگئیساو
#
# 0.GroundTruth:مذہب عشق یعنی عشق کا مذہب
#
# 0.Transcribed:ایتکی کام
# 0.LMCorrected:ایک کام
#
# 0.GroundTruth:اس پر غالب نے
#
# 0.Transcribed:ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:پانچ
#
# 0.Transcribed:وائیس
# 0.LMCorrected:بائیس
#
# 0.GroundTruth:دو ہزار سات
#
# 0.Transcribed:اساہ
# 0.LMCorrected:اساس
#
# 0.GroundTruth:اور روایات کے ساتھ برقرار رہتا ہے
#
# 0.Transcribed:نوکسدرتہ
# 0.LMCorrected:نوکسدرتہ
#
# 0.GroundTruth:سسرال کی طرف سے آسودہ حالی کے باعث خوشیوں کی نوید یا امید پیدا ہوتی ہے
#
# 0.Transcribed:اسرس ال باسک روویتہتی
# 0.LMCorrected:اساس ال ایک روویتہتی
#
# 0.GroundTruth:انيس سو پچاسی
#
# 0.Transcribed:انس س
# 0.LMCorrected:انس س
#
# 0.GroundTruth:میں ڈرائیور ہوں
#
# 0.Transcribed:تیبیووں
# 0.LMCorrected:تیبیووں
#
# 0.GroundTruth:اسی سال یہ کام کرنا شروع کیا ہے
#
# 0.Transcribed:یی ان اوکی
# 0.LMCorrected:یا ان اسکی
#
# 0.GroundTruth:انيس سو اکاسي
#
# 0.Transcribed:بی سای
# 0.LMCorrected:بی سی
#
# 0.GroundTruth:دو ہزار چودہ
#
# 0.Transcribed:دوس ار
# 0.LMCorrected:دو ار
#
# 0.GroundTruth:دس
#
# 0.Transcribed:یا
# 0.LMCorrected:یا
#
# 0.GroundTruth:صفر
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:دو ہزار سات
#
# 0.Transcribed:چن     ے
# 0.LMCorrected:ان کے
#
# 0.GroundTruth:میں نے دسویں تک پڑھا ہے
#
# 0.Transcribed: سوی ڑھا
# 0.LMCorrected:سو تھا
#
# 0.GroundTruth:دو ہزار اٹھارہ
#
# 0.Transcribed:یوزرکر
# 0.LMCorrected:یوزرکر
#
# 0.GroundTruth:پچیس
#
# 0.Transcribed:پاا
# 0.LMCorrected:پاس
#
# 0.GroundTruth:اکسٹھ
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:تئیس
#
# 0.Transcribed:یس
# 0.LMCorrected:یس
#
# 0.GroundTruth:دو ہزار چودہ
#
# 0.Transcribed:دز
# 0.LMCorrected:دل
#
# 0.GroundTruth:موضوعاتی اعتبار سے دونوں کے مرثیے مضبوط ہیں اور ان میں کسی کو پہلے یا دوسرے مقام پر رکھنا مرثیہ گو ناقدین کے لیے ممکن نہیں
#
# 0.Transcribed: س ے  ں وتے سقام ریورای ک یے ک
# 0.LMCorrected:س کے و ہوتے مقام ریورای ک یے ک
#
# 0.GroundTruth:انتالیس
#
# 0.Transcribed: بی لست
# 0.LMCorrected:بی لغت
#
# 0.GroundTruth:سترہ
#
# 0.Transcribed:انسرا
# 0.LMCorrected:انسان
#
# 0.GroundTruth:بائیس
#
# 0.Transcribed:یب
# 0.LMCorrected:یا
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:نس
# 0.LMCorrected:اس
#
# 0.GroundTruth:اکہتر
#
# 0.Transcribed:ی ہو
# 0.LMCorrected:ی ہو
#
# 0.GroundTruth:بیس
#
# 0.Transcribed:تچ
# 0.LMCorrected:تو
#
# 0.GroundTruth:انيس سو چھیانوے
#
# 0.Transcribed:ان سا
# 0.LMCorrected:ان سا
#
# 0.GroundTruth:دو ہزار ایک
#
# 0.Transcribed:سچ وی
# 0.LMCorrected:سچ کی
#
# 0.GroundTruth:وہ فلسفہ جِس کے مطابق ہم یہ خیال کرتے ہیں کہ کائنات میں دوئی کا تصور نہیں دو نہیں ہو سکتے
#
# 0.Transcribed:سسا ہت  کاا ہویں وسونہیں ی و ست
# 0.LMCorrected:سزا ہے کیا ہیں وسونہیں ی و ست
#
# 0.GroundTruth:میں گیارہویں پاس ہو
#
# 0.Transcribed:می جی س
# 0.LMCorrected:می جی س
#
# 0.GroundTruth:سترہ
#
# 0.Transcribed: سوا
# 0.LMCorrected:سوا
#
# 0.GroundTruth:بلکہ میر کہتے ہیں دور بیٹھا غبار میر ان سے
#
# 0.Transcribed:تکوا باوس
# 0.LMCorrected:کا اوس
#
# 0.GroundTruth:میں الیکٹریشن کا کام جانتا ہوں
#
# 0.Transcribed:پرش کا کام ات
# 0.LMCorrected:پر کا کام اس
#
# 0.GroundTruth:میرا پیشہ پلمبر ہے
#
# 0.Transcribed:یراپیشہت باے
# 0.LMCorrected:یراپیشہت بات
#
# 0.GroundTruth:چوبیس
#
# 0.Transcribed:چواس
# 0.LMCorrected:تواس
#
# 0.GroundTruth:یا انسان
#
# 0.Transcribed: س
# 0.LMCorrected:س
#
# 0.GroundTruth:چھیالیس
#
# 0.Transcribed:اچس
# 0.LMCorrected:اس
#
# 0.GroundTruth:انيس سو اکانوے
#
# 0.Transcribed:سا کاہ
# 0.LMCorrected:سا کا
#
# 0.GroundTruth:میں لاہور میں رہتا ہوں
#
# 0.Transcribed: سیاوی غہں ٹ
# 0.LMCorrected:سیاسی غم و
#
# 0.GroundTruth:میں نے  دو ہزار دس میں میٹرک  کیا ہے
#
# 0.Transcribed:ما ری
# 0.LMCorrected:کا ری
#
# 0.GroundTruth:چھیاسی
#
# 0.Transcribed:دوس
# 0.LMCorrected:دور
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:اا
# 0.LMCorrected:کا
#
# 0.GroundTruth:پچاس
#
# 0.Transcribed:کاہ  دپن ی
# 0.LMCorrected:کا دکن ی
#
# 0.GroundTruth:انيس سو تراسی
#
# 0.Transcribed:اس سای
# 0.LMCorrected:اس سال
#
# 0.GroundTruth:میرا تجربہ دو سال ہے
#
# 0.Transcribed:میا  دو ساہ
# 0.LMCorrected:میں دو سال
#
# 0.GroundTruth:انيس سو پچاسی
#
# 0.Transcribed:اااس
# 0.LMCorrected:اساس
#
# 0.GroundTruth:دو ہزار آٹھ
#
# 0.Transcribed:دو
# 0.LMCorrected:دو
#
# 0.GroundTruth:اور دوسرا یہ
#
# 0.Transcribed:اساے
# 0.LMCorrected:اسے
#
# 0.GroundTruth:باسٹھ
#
# 0.Transcribed:بس
# 0.LMCorrected:بس
#
# 0.GroundTruth:پندرہ
#
# 0.Transcribed:ار
# 0.LMCorrected:ار
#
# 0.GroundTruth:اب یہ سوال کے زبان کب پیدا ہوئی
#
# 0.Transcribed:سا اتری
# 0.LMCorrected:سا اتنی
#
# 0.GroundTruth:ایک ناوک نے تیری مژگاں کے
#
# 0.Transcribed:کتتیویچ
# 0.LMCorrected:کتتیویچ
#
# 0.GroundTruth:چھ
#
# 0.Transcribed:کچو
# 0.LMCorrected:کو
#
# 0.GroundTruth:انيس سو بياسي
#
# 0.Transcribed:اسنی
# 0.LMCorrected:اپنی
#
# 0.GroundTruth:انيس سو پچانوے
#
# 0.Transcribed:ساچنویے
# 0.LMCorrected:ساچنویے
#
# 0.GroundTruth:چوہتر
#
# 0.Transcribed:ےکا
# 0.LMCorrected:کا
#
# 0.GroundTruth:ستاون
#
# 0.Transcribed:ت س
# 0.LMCorrected:ت س
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:نس
# 0.LMCorrected:اس
#
# 0.GroundTruth:دکن سے مسلمانوں کے یا عربوں کے تعلقات 712 سے بھی قبل سے قائم تھے
#
# 0.Transcribed:کرسے سمانوواتات ساسوا سکاے
# 0.LMCorrected:کرتے سمانوواتات سالوں سکتے
#
# 0.GroundTruth:جس کی تصویر میر تقی میر کی شاعری میں بخوبی دیکھی جا سکتی ہے
#
# 0.Transcribed:سی س ک شامیں ستی
# 0.LMCorrected:سی س ک شامیں ستی
#
# 0.GroundTruth:دو ہزار چار
#
# 0.Transcribed:دچ
# 0.LMCorrected:دل
#
# 0.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 0.Transcribed:ن ستجوب
# 0.LMCorrected:ن جستجو
#
# 0.GroundTruth:کوئی بتاؤ کہ وہ شوخِ تند خو کیا ہے
#
# 0.Transcribed: سس وکاے
# 0.LMCorrected:اس کے
#
# 0.GroundTruth:چھیالیس
#
# 0.Transcribed:چاس
# 0.LMCorrected:اس
#
# 0.GroundTruth:چورانوے
#
# 0.Transcribed:کارہی
# 0.LMCorrected:جارہی
#
# 0.GroundTruth:اور اس
#
# 0.Transcribed:اایس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:میں نے پانچ سال کام کیا ہے
#
# 0.Transcribed:یہ تایسکاکیاا
# 0.LMCorrected:یہ تایسکاکیاا
#
# 0.GroundTruth:میرا تجربہ آٹھ سال ہے
#
# 0.Transcribed:نیبااٹل ے
# 0.LMCorrected:نیبااٹل کے
#
# 0.GroundTruth:چوراسی
#
# 0.Transcribed:اس
# 0.LMCorrected:اس
#
# 0.GroundTruth:انيس سو نواسی
#
# 0.Transcribed:س س
# 0.LMCorrected:س س
#
# 0.GroundTruth:دو ہزار پندرہ
#
# 0.Transcribed:وی ا
# 0.LMCorrected:کی ا
#
# 0.GroundTruth:نوے
#
# 0.Transcribed:نر
# 0.LMCorrected:پر
#
# 0.GroundTruth:پچاس
#
# 0.Transcribed:چپس
# 0.LMCorrected:آپس
#
# 0.GroundTruth:دو ہزار سترہ
#
# 0.Transcribed: ازر
# 0.LMCorrected:اور
#
# 0.GroundTruth:میں پانچ سال سے یہ کام کر رہا ہوں
#
# 0.Transcribed:سہ ککاو
# 0.LMCorrected:سہ کا
#
# 0.GroundTruth:انيس سو نواسی
#
# 0.Transcribed:ان ساسی
# 0.LMCorrected:ان اسی
#
# 0.GroundTruth:گیارہ
#
# 0.Transcribed:کی
# 0.LMCorrected:کی
#
# 0.GroundTruth:میرا پیشہ الیکٹریشن ہے
#
# 0.Transcribed:تسای س
# 0.LMCorrected:تھا س
#
# 0.GroundTruth:ان مجالس کے آخر میں مرثیے پڑھے جاتے تھے ان کا مقصد بین اور سوزوگداز کی تاثیر میں اضافہ ہوتا تھا
#
# 0.Transcribed:سسمیں  تے پن ماص ے سگاسسیوساہتد
# 0.LMCorrected:قسمیں کے پن مان ہے سگاسسیوساہتد
#
# 0.GroundTruth:دو ہزار چودہ
#
# 0.Transcribed:و ااس
# 0.LMCorrected:و اس
#
# 0.GroundTruth:انيس سو بياسي
#
# 0.Transcribed:ار سابی
# 0.LMCorrected:ار ساری
#
# 0.GroundTruth:ایک تو یہ کیا کہ انہوں نے نہ صرف
#
# 0.Transcribed:تی ا ے ن
# 0.LMCorrected:کی ا ب ن
#
# 0.GroundTruth:میں نے دو ہزار بیس میں بی اے مکمل کی ہے
#
# 0.Transcribed: وا وی و بی لکیے
# 0.LMCorrected:وا کی و بی کیے
#
# 0.GroundTruth:حسد کا متضاد
#
# 0.Transcribed:سای زا
# 0.LMCorrected:سال کا
#
# 0.GroundTruth:انيس سو اٹھانوے
#
# 0.Transcribed:ا انرو
# 0.LMCorrected:ا انرز
#
# 0.GroundTruth:پچیس
#
# 0.Transcribed:ب
# 0.LMCorrected:ب
#
# 0.GroundTruth:سو ہم آنا پسند ہو جائیں تو ہمارے لئے خودی کی شناخت بھی ممکن ہو جاتی ہے
#
# 0.Transcribed:سو تلی شس رونسی جی
# 0.LMCorrected:سو تھی اس روشنی جی
#
# 0.GroundTruth:میں نے دسویں جماعت تک پڑھا ہے
#
# 0.Transcribed:سں ن یاا  پٹھاسے
# 0.LMCorrected:سے ن یا اٹھاسی
#
# 0.GroundTruth:انيس سو بانوے
#
# 0.Transcribed:انیس س
# 0.LMCorrected:انیس س
#
# 0.GroundTruth:انہتر
#
# 0.Transcribed:پوان
# 0.LMCorrected:جوان
#
# 0.GroundTruth:دو ہزار چار
#
# 0.Transcribed:ی
# 0.LMCorrected:ی
#
# 0.GroundTruth:میر کی شاعری کا ایک اور اہم پہلو ان کے ہاں پایا جانے والا احساس محرومی ہے
#
# 0.Transcribed:شساسا یواناا لوااساس ووی ے
# 0.LMCorrected:حساس توانا لوااساس ولی نے
#
# 0.GroundTruth:میرا پیشہ ڈرائیور ہے
#
# 0.Transcribed:راہ ترش ہل
# 0.LMCorrected:راہ تر ہے
#
# 0.GroundTruth:میں ان پڑھ ہوں
#
# 0.Transcribed:سسمف ک باڑھا
# 0.LMCorrected:ستم ک بڑھا
#
# 0.GroundTruth:چودہ
#
# 0.Transcribed:چالی
# 0.LMCorrected:حالی
#
# 0.GroundTruth:جنگ آزادی کے بعد سے کرتے ہیں لیکن بہرحال اگر ہم دونوں ادوار کا مجموعی مطالعہ بھی کرے تو غالب کی شاعری کا سب سے  میچور اور موثر ترین دور ہے
#
# 0.Transcribed:نشتے و کاویسکر ا ساسے گشر وسری ار
# 0.LMCorrected:نے و کاویسکر ا اسے گھر دوسری ار
#
# 0.GroundTruth:دو ہزار پندرہ
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:اٹھارہ
#
# 0.Transcribed:سپاا
# 0.LMCorrected:سال
#
# 0.GroundTruth:اگر
#
# 0.Transcribed:ہ
# 0.LMCorrected:ہ
#
# 0.GroundTruth:جدید غزل گو ہونے کا بھی
#
# 0.Transcribed:چ کاس گوکای
# 0.LMCorrected:و کا گویا
#
# 0.GroundTruth:پینتالیس
#
# 0.Transcribed:ری
# 0.LMCorrected:ری
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے دس سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed:واا سس
# 0.LMCorrected:وفا سے
#
# 0.GroundTruth:انيس سو چوراسی
#
# 0.Transcribed:انساررا
# 0.LMCorrected:انساررا
#
# 0.GroundTruth:سو
#
# 0.Transcribed:و
# 0.LMCorrected:و
#
# 0.GroundTruth:میری عمر اٹھارہ سال ہے
#
# 0.Transcribed:و ا  ہے
# 0.LMCorrected:و ا ہے
#
# 0.GroundTruth:انہتر
#
# 0.Transcribed:ون
# 0.LMCorrected:ون
#
# 0.GroundTruth:تئیس
#
# 0.Transcribed:سا ر
# 0.LMCorrected:سا ر
#
# 0.GroundTruth:تینتالیس
#
# ...
#
# 0.GroundTruth:میں ان پڑھ ہوں
#
# 0.Transcribed:چی  ک
# 0.LMCorrected:کی ک
#
# 0.GroundTruth:پچاسی
#
# 0.Transcribed:اسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:انسٹھ
#
# 0.Transcribed:تس
# 0.LMCorrected:اس
#
# 0.GroundTruth:سترہ
#
# 0.Transcribed: س
# 0.LMCorrected:س
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:ااس
# 0.LMCorrected:اس
#
# 0.GroundTruth:زبان کیا ہے
#
# 0.Transcribed: کا
# 0.LMCorrected:کا
#
# 0.GroundTruth:اکیاسی
#
# 0.Transcribed:ستک
# 0.LMCorrected:تک
#
# 0.GroundTruth:اس کا نتیجہ منطقی نتیجہ وہی ہوا جو ہونا چاہیے تھا یا جو ہوتا ہے
#
# 0.Transcribed:اسیا  تیزوہ مسا اساے
# 0.LMCorrected:اسی ریزہ سا اسے
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:ارا
# 0.LMCorrected:انا
#
# 0.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 0.Transcribed:چی ای ا اہ
# 0.LMCorrected:کی ای ا اس
#
# 0.GroundTruth:انیس
#
# 0.Transcribed:ہن
# 0.LMCorrected:ہے
#
# 0.GroundTruth:کیوں کہ اگر سینے میں دل نہ رہے تو یہ ممکن نہیں کہ زبان پر الفاظ اتر سکیں
#
# 0.Transcribed: ارسس وش ما ساسے
# 0.LMCorrected:اس وش کا اسے
#
# 0.GroundTruth:اردو ادب کی
#
# 0.Transcribed: کی
# 0.LMCorrected:کی
#
# 0.GroundTruth:دو ہزار انیس
#
# 0.Transcribed:دا  سا ارس
# 0.LMCorrected:دا سا درس
#
# 0.GroundTruth:تین
#
# 0.Transcribed:چچااان
# 0.LMCorrected:چچااان
#
# 0.GroundTruth:بیالیس
#
# 0.Transcribed:بیا
# 0.LMCorrected:یا
#
# 0.GroundTruth:دو ہزار نو
#
# 0.Transcribed:رایشر
# 0.LMCorrected:رایشر
#
# 0.GroundTruth:اکیس
#
# 0.Transcribed:ک س
# 0.LMCorrected:ک س
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:ویسپایسہجروکیہ
# 0.LMCorrected:ویسپایسہجروکیہ
#
# 0.GroundTruth:چونتیس
#
# 0.Transcribed:تیسس اٹ
# 0.LMCorrected:تیس اس
#
# 0.GroundTruth:بائیس
#
# 0.Transcribed:بایس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:انيس سو ستانوے
#
# 0.Transcribed:ا ن
# 0.LMCorrected:ا ن
#
# 0.GroundTruth:یہ وہ فلسفہ ہے عزیز طلباء
#
# 0.Transcribed:سساسب
# 0.LMCorrected:حساس
#
# 0.GroundTruth:میں کارپینٹر کا کام جانتا ہوں
#
# 0.Transcribed:سیسکاتدت چس
# 0.LMCorrected:سیسکاتدت اس
#
# 0.GroundTruth:دو ہزار سات
#
# 0.Transcribed:بزارسا
# 0.LMCorrected:بارہا
#
# 0.GroundTruth:انيس سو اٹھانوے
#
# 0.Transcribed:نیک سا ن
# 0.LMCorrected:نیک سا ن
#
# 0.GroundTruth:پچپن
#
# 0.Transcribed:سدور
# 0.LMCorrected:دور
#
# 0.GroundTruth:چار حصوں میں تقسیم کیا جاتا ہے یا یوں کہہ لیجئے کہ اس صنف کے بنیادی طور پر چار اجزاء ہوتے ہیں
#
# 0.Transcribed:اس
# 0.LMCorrected:اس
#
# 0.GroundTruth:پندرہ
#
# 0.Transcribed:چ د  ہا
# 0.LMCorrected:و د ہا
#
# 0.GroundTruth:دو ہزار چار
#
# 0.Transcribed:دی زچ
# 0.LMCorrected:دی سچ
#
# 0.GroundTruth:میں اسلام آباد میں رہتا ہوں
#
# 0.Transcribed:ں  سلا  ا یا
# 0.LMCorrected:و سال ا یا
#
# 0.GroundTruth:میرا نام دلدار ہے
#
# 0.Transcribed:نی اہ
# 0.LMCorrected:نی اس
#
# 0.GroundTruth:اب ہم بات کرتے ہیں پنجاب میں اردو کی
#
# 0.Transcribed:اس سا ودوٹ
# 0.LMCorrected:اس سا دور
#
# 0.GroundTruth:اس بلند آہنگی کی مثال ہمیں ذوق کے علاوہ سودا کے ہاں ملتی ہے اور ان دو شعرا کے ہاں
#
# 0.Transcribed:سرساکںساغکا ساوتیے رہی گواسراکہ
# 0.LMCorrected:سرساکںساغکا ساتویں رہی گواسراکہ
#
# 0.GroundTruth:انيس سو چورانوے
#
# 0.Transcribed:انس س چراو
# 0.LMCorrected:انس س چراغ
#
# 0.GroundTruth:انتالیس
#
# 0.Transcribed:ن ر
# 0.LMCorrected:ن ر
#
# 0.GroundTruth:نو
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:کس بھی نہیں تھی یہ مہارت لی نہیں گئی تھی یہ مہارت اللہ تبارک و تعالیٰ کی طرف سے ودیعت کی گئی تھی
#
# 0.Transcribed:یرکی ت  آکاکار اہاکے سویتیت
# 0.LMCorrected:ترکی ت آشکار اشارے سویتیت
#
# 0.GroundTruth:اکیاسی
#
# 0.Transcribed:ااسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:چھپن
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:انتیس
#
# 0.Transcribed: پو
# 0.LMCorrected:کو
#
# 0.GroundTruth:میں بارہویں پاس ہوں
#
# 0.Transcribed:میسبی سپات
# 0.LMCorrected:میری سات
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:دو ہزار سولہ
#
# 0.Transcribed: زار سآ
# 0.LMCorrected:زار سے
#
# 0.GroundTruth:تب کریں
#
# 0.Transcribed:اک
# 0.LMCorrected:اک
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:ماو الی ہاسلیں کہ
# 0.LMCorrected:مان اسی نسلیں کہ
#
# 0.GroundTruth:چھپن
#
# 0.Transcribed:ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:بیاسی
#
# 0.Transcribed:براسی
# 0.LMCorrected:تراسی
#
# 0.GroundTruth:سات
#
# 0.Transcribed:انسرر
# 0.LMCorrected:انسان
#
# 0.GroundTruth:میرا پانچ سال کا تجربہ ہے
#
# 0.Transcribed:میا پچ س کاہے
# 0.LMCorrected:میں پر س کاہے
#
# 0.GroundTruth:تو کسی نے غالب کی توجہ ذوق کی طرف مبذول کی
#
# 0.Transcribed:سے غا ک اریزاسسم ووکی
# 0.LMCorrected:سے یا ک اریزاسسم کی
#
# 0.GroundTruth:چوالیس
#
# 0.Transcribed:تچی
# 0.LMCorrected:تھی
#
# 0.GroundTruth:ستائیس
#
# 0.Transcribed:ااا ر   ل
# 0.LMCorrected:انا ر ل
#
# 0.GroundTruth:اڑتالیس
#
# 0.Transcribed:الیس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 0.Transcribed:ماسا وسوا ہ
# 0.LMCorrected:مانا سوا ہ
#
# 0.GroundTruth:اٹھانوے
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:دو
#
# 0.Transcribed:سین
# 0.LMCorrected:سی
#
# 0.GroundTruth:اٹھارویں صدی کا زمانہ ہے
#
# 0.Transcribed:سی ز ہے
# 0.LMCorrected:سی ز ہے
#
# 0.GroundTruth:کہ یہی آپ کی کامیابی اور آپ کے مراتب میں اضافہ کرے
#
# 0.Transcribed:  الی مااس اسر
# 0.LMCorrected:حالی اس اور
#
# 0.GroundTruth:میں یہ دعویٰ نہیں کرسکتا کہ یہ تشریح مکمل تھی
#
# 0.Transcribed:ساتر موکی
# 0.LMCorrected:ساتھ موسی
#
# 0.GroundTruth:دو ہزار پانچ
#
# 0.Transcribed:ین  اس
# 0.LMCorrected:یا اس
#
# 0.GroundTruth:سیر حاصل انداز میں جائزہ لے چکے ہیں
#
# 0.Transcribed: ا میرا
# 0.LMCorrected:ا میرا
#
# 0.GroundTruth:انيس سو تراسی
#
# 0.Transcribed:اسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:میں ڈرائیور ہوں
#
# 0.Transcribed:ما ا ہو
# 0.LMCorrected:یا ا ہو
#
# 0.GroundTruth:ناول نگاری
#
# 0.Transcribed:ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:میں نے دس سال کام کیا ہے
#
# 0.Transcribed:ں وسکااکی ا
# 0.LMCorrected:و وسکااکی ا
#
# 0.GroundTruth:اٹھہتر
#
# 0.Transcribed:ودس
# 0.LMCorrected:دس
#
# 0.GroundTruth:انيس سو چھیاسی
#
# 0.Transcribed:ایپن ااسی
# 0.LMCorrected:ایپک اسی
#
# 0.GroundTruth:میں پلمبر ہوں
#
# 0.Transcribed:تیہ
# 0.LMCorrected:یہ
#
# 0.GroundTruth:چھتیس
#
# 0.Transcribed:چاتی
# 0.LMCorrected:جاتی
#
# 0.GroundTruth:چالیس
#
# 0.Transcribed: ااانی
# 0.LMCorrected:اپنی
#
# 0.GroundTruth:انيس سو اٹھاسی
#
# 0.Transcribed:اساارسی
# 0.LMCorrected:اساارسی
#
# 0.GroundTruth:ستانوے
#
# 0.Transcribed:اسنیس
# 0.LMCorrected:انیس
#
# 0.GroundTruth:اب یہاں مسئلہ یہ ہے کہ عموما شاعر غزل میں محبوب سے مخاطب ہوتا ہے
#
# 0.Transcribed:سیے نا سا ہس غاے دوتہے
# 0.LMCorrected:سے نا سا ہے اے ہوتے
#
# 0.GroundTruth:میری عمر بائیس سال ہے
#
# 0.Transcribed:اوامی سا
# 0.LMCorrected:والی سا
#
# 0.GroundTruth:میرا تعلق لاہور سے ہے
#
# 0.Transcribed: وہ راور
# 0.LMCorrected:وہ اور
#
# 0.GroundTruth:دو ہزار
#
# 0.Transcribed:ری
# 0.LMCorrected:ری
#
# 0.GroundTruth:بدآموزی ناراضی عدو
#
# 0.Transcribed:اس بںاس رو
# 0.LMCorrected:اس بات رو
#
# 0.GroundTruth:انتیس
#
# 0.Transcribed: ا
# 0.LMCorrected:ا
#
# 0.GroundTruth:میں ڈرائیور ہوں
#
# 0.Transcribed:ارسو
# 0.LMCorrected:اردو
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:ااہ
# 0.LMCorrected:شاہ
#
# 0.GroundTruth:دو ہزار نو
#
# 0.Transcribed:ندسر
# 0.LMCorrected:نظر
#
# 0.GroundTruth:یہ صنف خالصتن عربی شاعری سے فارسی اور فارسی سے اردو تک پہنچی
#
# 0.Transcribed:اسسسنی جےک س ک آ ک آکسسبی کاہ
# 0.LMCorrected:انسانی جھک س ک آ ک آکسسبی کا
#
# 0.GroundTruth:انيس سو ستانوے
#
# 0.Transcribed:نسساس
# 0.LMCorrected:احساس
#
# 0.GroundTruth:سب سے پہلے ہے کرشمہ
#
# 0.Transcribed:س کریش
# 0.LMCorrected:س کریں
#
# 0.GroundTruth:بارہ
#
# 0.Transcribed:کارتب
# 0.LMCorrected:کرتے
#
# 0.GroundTruth:اگلے شعر میں غالب کہتے ہیں کہ یہ رشک ہے کہ وہ ہوتا ہے ہم سخن تم سے یہ رشک ہے کہ وہ ہوتا ہے ہم سخن تم سے
#
# 0.Transcribed:سالےے تحا  و  ہو ا سغن کاسے
# 0.LMCorrected:والے تھا و ہو ا سخن اسے
#
# 0.GroundTruth:تین
#
# 0.Transcribed:انگس سا ای
# 0.LMCorrected:انیس سا ای
#
# 0.GroundTruth:میرا تجربہ پانچ سال ہے
#
# 0.Transcribed:نیاس
# 0.LMCorrected:قیاس
#
# 0.GroundTruth:اردو غزل میں کیا کیا
#
# 0.Transcribed:سرں کی
# 0.LMCorrected:سر کی
#
# 0.GroundTruth:میں نے انٹر تک تعلیم حاصل کی ہے
#
# 0.Transcribed:ب ان س ا ہکالکیہ ے
# 0.LMCorrected:ب ان س ا ہکالکیہ کے
#
# 0.GroundTruth:ستائیس
#
# 0.Transcribed:اسل
# 0.LMCorrected:اسل
#
# 0.GroundTruth:پندرہ
#
# 0.Transcribed:زاای
# 0.LMCorrected:زاری
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:ی
# 0.LMCorrected:ی
#
# 0.GroundTruth:عزیز طلبہ اردو غزل
#
# 0.Transcribed:س ن ووغس
# 0.LMCorrected:س ن کورس
#
# 0.GroundTruth:انيس سو ترانوے
#
# 0.Transcribed:ا لی
# 0.LMCorrected:ا لی
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے سات سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed:لاکرکو کک ا کاہی اس
# 0.LMCorrected:لاکرکو کی ا کافی اس
#
# 0.GroundTruth:چھہتر
#
# 0.Transcribed:رساڈر ہوری
# 0.LMCorrected:ساغر ہوتی
#
# 0.GroundTruth:دو ہزار ایک
#
# 0.Transcribed:ااد
# 0.LMCorrected:ادا
#
# 0.GroundTruth:پانچ
#
# 0.Transcribed:نیس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:دو ہزار پانچ
#
# 0.Transcribed:ان سر اس
# 0.LMCorrected:ان سر اس
#
# 0.GroundTruth:پچاسی
#
# 0.Transcribed:چاسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:چالیس
#
# 0.Transcribed:چوس
# 0.LMCorrected:چور
#
# 0.GroundTruth:اس بلندی پر نہیں جہاں تک انسانی عقل انسانی احساس پہنچ ہی نہیں سکتا
#
# 0.Transcribed:ے اا ق سنسسوریسدا
# 0.LMCorrected:ہے یا ق سنسسوریسدا
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:می ا  اویایل  ے
# 0.LMCorrected:می ا اوائل کے
#
# 0.GroundTruth:چھپن
#
# 0.Transcribed:چان
# 0.LMCorrected:ان
#
# 0.GroundTruth:اٹھارہ
#
# 0.Transcribed:ج پچ
# 0.LMCorrected:ج پر
#
# 0.GroundTruth:اکہتر
#
# 0.Transcribed:بیس
# 0.LMCorrected:بیس
#
# 0.GroundTruth:میں نے ایف ایس سی تک تعلیم حاصل کی ہے
#
# 0.Transcribed:میاسرا کان ای
# 0.LMCorrected:میرا کا ای
#
# 0.GroundTruth:ستاسی
#
# 0.Transcribed:اسی
# 0.LMCorrected:اسی
#
# 0.GroundTruth:انيس سو ننانوے
#
# 0.Transcribed:نس ساو
# 0.LMCorrected:دس سال
#
# 0.GroundTruth:میں پلمبر ہوں
#
# 0.Transcribed:د اا
# 0.LMCorrected:د کا
#
# 0.GroundTruth:کہ تو کیا ہے
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:ستاون
#
# 0.Transcribed:سہ
# 0.LMCorrected:سہ
#
# 0.GroundTruth:میں نے کوئی تعلیم حاصل نہیں کی ہے
#
# 0.Transcribed:  او
# 0.LMCorrected:او
#
# 0.GroundTruth:اردو
#
# 0.Transcribed:
# 0.LMCorrected:
#
# 0.GroundTruth:ستاون
#
# 0.Transcribed: ساری
# 0.LMCorrected:ساری
#
# 0.GroundTruth:ستانوے
#
# 0.Transcribed:س
# 0.LMCorrected:س
#
# 0.GroundTruth:میں ڈیلیوری بوائے کا کام جانتا ہوں
#
# 0.Transcribed:شکی ویککااب پوزاس  ہیب
# 0.LMCorrected:کی ویککااب پاس ہی
#
# 0.GroundTruth:سترہ
#
# 0.Transcribed: سا
# 0.LMCorrected:سا
#
# 0.GroundTruth:ستر
#
# 0.Transcribed: س
# 0.LMCorrected:س
#
# 0.GroundTruth:بلکہ مطلب اس کا یہ ہوتا ہے کہ ہم ان کو نہیں جان پائے تو ہم محروم ہو گئے
#
# 0.Transcribed: مورستری اتاو ہگ
# 0.LMCorrected:مورستری اتا ہے
#
# 0.GroundTruth:چھیالیس
#
# 0.Transcribed:ریس
# 0.LMCorrected:ایس
#
# 0.GroundTruth:دس
#
# 0.Transcribed:او
# 0.LMCorrected:او
#
# 0.GroundTruth:میں نے دو ہزار انیس میں بارہویں مکمل کی ہے
#
# 0.Transcribed: می دو ہزاوس بوری کا ک
# 0.LMCorrected:می دو ہزار بیری کا ک
#
# 0.GroundTruth:دوسرے کا احساس
#
# 0.Transcribed:و  کساس
# 0.LMCorrected:و حساس
#
# 0.GroundTruth:انتیس
#
# 0.Transcribed:ویسا
# 0.LMCorrected:ویسا
#
# 0.GroundTruth:میں پلمبر کا کام جانتا ہوں
#
# 0.Transcribed:د  ک کان ا
# 0.LMCorrected:د ک کا ا
#
# 0.GroundTruth:دو ہزار بارہ
#
# 0.Transcribed:یا
# 0.LMCorrected:یا
#
# 0.GroundTruth:چوبیس
#
# 0.Transcribed:چاویسک
# 0.LMCorrected:چالیس
#
# 0.GroundTruth:چھیاسی
#
# 0.Transcribed:زس
# 0.LMCorrected:اس
#
# 0.GroundTruth:انيس سو بياسي
#
# 0.Transcribed:ا سوی
# 0.LMCorrected:ا سو
#
# 0.GroundTruth:میں پلمبر کا کام جانتا ہوں
#
# 0.Transcribed: سس اساسصر
# 0.LMCorrected:سے اساس
#
# 0.GroundTruth:بلکہ یقینا شاعری سے اگر وہ موثر ہو تو معاشرتوں کو بے دار کرنے کا کام لیا جا سکتا ہے
#
# 0.Transcribed:اسانو وما وتارکالستاہ
# 0.LMCorrected:اسان وفا وتارکالستاہ
#
# 0.GroundTruth:میرا پیشہ کارپینٹر ہے
#
# 0.Transcribed:می اساے
# 0.LMCorrected:می اسے
#
# 0.GroundTruth:میری عمر اٹھارہ سال ہے
#
# 0.Transcribed:یااے
# 0.LMCorrected:یا
#
# 0.GroundTruth:میں کراچی میں رہتا ہوں
#
# 0.Transcribed:پسیراز
# 0.LMCorrected:سیراب
#
# 0.GroundTruth:جو وجود کے رنگت سے آزاد تھی
#
# 0.Transcribed:وکرانسات
# 0.LMCorrected:وکرانسات
#
# 0.GroundTruth:چھیانوے
#
# 0.Transcribed:ٹےنس
# 0.LMCorrected:ہنس
#
# 0.GroundTruth:دو ہزار اٹھارہ
#
# 0.Transcribed:چفو وا را
# 0.LMCorrected:رفو وا کا
#
# 0.GroundTruth:تیرہ
#
# 0.Transcribed:چی
# 0.LMCorrected:کی
#
# 0.GroundTruth:اناسی
#
# 0.Transcribed:نس
# 0.LMCorrected:اس
#
# 0.GroundTruth:چھیالیس
#
# 0.Transcribed:ں رت
# 0.LMCorrected:و رخ
#
# 0.GroundTruth:میں ان پڑھ ہوں
#
# 0.Transcribed:تیاس ا ری
# 0.LMCorrected:قیاس ا ری
#
# 0.GroundTruth:چنانچہ حالی نے اگرچہ ابتدا میں اس طرح کے شعر کہے جیسے
#
# 0.Transcribed:چ اتسایسراسس
# 0.LMCorrected:و اتسایسراسس
#
# 0.GroundTruth:چالیس
#
# 0.Transcribed: د س
# 0.LMCorrected:د س
#
# 0.GroundTruth:اپنے وضع کردہ رستے کے مطابق چلنے کے خواہشمند ہوتے ہیں
#
# 0.Transcribed:زک تج مواوی سوتے
# 0.LMCorrected:تک تو ماوی ہوتے
#
# 0.GroundTruth:زمانہ بدل گیا تھا
#
# 0.Transcribed:وای
# 0.LMCorrected:وہی
#
# 0.GroundTruth:ستر
#
# 0.Transcribed:چساساہہو
# 0.LMCorrected:چساساہہو
#
# 0.GroundTruth:جہاں سے ذوق ابراہیم ذوق کی سواری جا رہی تھی پالکی میں ان کو لے جایا جا رہا تھا
#
# 0.Transcribed:بس   زاکی  ار کی ار ولجر
# 0.LMCorrected:بس زاری ار کی ار ولی
#
# 0.GroundTruth:وہ شخص کہ جس کو کتنی ہی اولادیں دی گی اللہ تبارک و تعالی نے کتنی ہی الادوں سے نوازا لیکن کوئی بھی عالم شباب کو بھی نہ پہنچ سکی
#
# 0.Transcribed:سات  انتسہزکو رواکومسی
# 0.LMCorrected:سات انتسہزکو رواکومسی
#
# 0.GroundTruth:اٹھاون
#
# 0.Transcribed:ہی
# 0.LMCorrected:ہی
#
# 0.GroundTruth:دو ہزار بارہ
#
# 0.Transcribed:اا چھی اہے
# 0.LMCorrected:کا بھی ہے
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے چھ سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed:ک ا ی  سااا دوا
# 0.LMCorrected:ک ا ی سارا دوا
#
# 0.GroundTruth:انيس سو چھیانوے
#
# 0.Transcribed:انسا
# 0.LMCorrected:انسان
#
# 0.GroundTruth:انيس سو چھیاسی
#
# 0.Transcribed:ادنسسی
# 0.LMCorrected:ادوسری
#
# 0.GroundTruth:انيس سو نوے
#
# 0.Transcribed: سا ا
# 0.LMCorrected:سا ا
#
# 0.GroundTruth:پینتیس
#
# 0.Transcribed:د تا  تیت
# 0.LMCorrected:د تا تین
#
# 0.GroundTruth:سترہ
#
# 0.Transcribed:سرہ
# 0.LMCorrected:سر
#
# 0.GroundTruth:اٹھاسی
#
# 0.Transcribed:سیٹ
# 0.LMCorrected:سی
#
# 0.GroundTruth:اور مشاعرے کا آغاز غالب کی اسی غزل سے کیا جائے
#
# 0.Transcribed:شغا کسے
# 0.LMCorrected:آغا کسے
#
# 0.GroundTruth:ترانوے
#
# 0.Transcribed:زرا
# 0.LMCorrected:برا
#
# 0.GroundTruth:یعنی ایک وہ دور کہ جس میں مایوسی آغاز پر تھی
#
# 0.Transcribed:یسو کسمسے آسدت
# 0.LMCorrected:سو کیسے مسدس
#
# 0.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 0.Transcribed:مسکمی کوک تجرباہ ہے
# 0.LMCorrected:مکمل کو تجربہ ہے
#
# 0.GroundTruth:ننانوے
#
# 0.Transcribed:ب
# 0.LMCorrected:ب
#
# 0.GroundTruth:انيس سو چورانوے
#
# 0.Transcribed:انسچر
# 0.LMCorrected:انسان
#
# 0.GroundTruth:ستاون
#
# 0.Transcribed:کتارہے
# 0.LMCorrected:جارہے
#
# 0.GroundTruth:اپنے خاص انداز میں
#
# 0.Transcribed:تاازی
# 0.LMCorrected:تعالی
#
# 0.GroundTruth:دس
#
# 0.Transcribed:رس
# 0.LMCorrected:اس
#
# 0.GroundTruth:دو ہزار چھ
#
# 0.Transcribed:د ہزا
# 0.LMCorrected:د ہوا
#
# 0.GroundTruth:چورانوے
#
# 0.Transcribed:دچرنسا
# 0.LMCorrected:دچرنسا
#
# 0.GroundTruth:انيس سو نوے
#
# 0.Transcribed:کسرنناو
# 0.LMCorrected:کسرنناو
#
# 0.GroundTruth:تراسی
#
# 0.Transcribed:سی
# 0.LMCorrected:سی
#
# 0.GroundTruth:مجھے یہ کام کرتے ہوئے تین سال کا عرصہ ہو گیا ہے
#
# 0.Transcribed:سیکاریویکو اس
# 0.LMCorrected:سیکاریویکو اس
#
# 0.GroundTruth:میرا نام احمد ہے
#
# 0.Transcribed:بی ی
# 0.LMCorrected:بی ی
#
# 0.GroundTruth:میرا اس کام میں کوئی تجربہ نہیں ہے
#
# 0.Transcribed:میراسی سر و
# 0.LMCorrected:میرا سر و
#
# 0.GroundTruth:دو ہزار پندرہ
#
# 0.Transcribed:دورر
# 0.LMCorrected:دور
#
# 0.GroundTruth:میں نے دو ہزار گیارہ میں گیارہویں کی ہے
#
# 0.Transcribed:ی ووااااراا ہویںے تزکا
# 0.LMCorrected:ی ووااااراا ہونے کا
#
# 0.GroundTruth:چھہتر
#
# 0.Transcribed:اسک ج
# 0.LMCorrected:ایک ج
#
# 0.GroundTruth:پھر اسے سوتیلے بھائی کے ظلم و تشدد کا سامنا کرنا پڑے
#
# 0.Transcribed:سری کز دو سا کا پے
# 0.LMCorrected:سی کی دو سا کا پے
#
# 0.GroundTruth:ستاسی
#
# 0.Transcribed:سای
# 0.LMCorrected:اسی
#
# 0.GroundTruth:ہماری کسی بھی زبان کے الفابیٹ ہو اردو کی ا ب ہو یا انگلش کی اے بی سی بہرحال آوازوں کے اشارے آوازوں کے علامت
#
# 0.Transcribed:مراسہووسمیں ہیویسیسشاریسچلا
# 0.LMCorrected:مراسہووسمیں ہیویسیسشاریسچلا
#
# 0.GroundTruth:میں الیکٹریشن کا کام جانتا ہوں
#
# 0.Transcribed:اراااس
# 0.LMCorrected:اراااس
#
# 0.GroundTruth:میرا تعلق اسلام آباد سے ہے
#
# 0.Transcribed:انپیبا
# 0.LMCorrected:انڈیا
#
# 0.GroundTruth:دو ہزار بارہ
#
# 0.Transcribed:ااس
# 0.LMCorrected:اس
#
# 0.GroundTruth:میں نے دو ہزار دس میں میٹرک کیا ہے
#
# 0.Transcribed:می  دوس سممارٹک کا
# 0.LMCorrected:می دو سممارٹک کا
#
# 0.GroundTruth:اکبر کے والد ایک دین دار عالم تھے
#
# 0.Transcribed:کالف لے
# 0.LMCorrected:کالج لے
#
# 0.GroundTruth:چون
#
# 0.Transcribed:اتی
# 0.LMCorrected:اتی
#
# 0.GroundTruth:مطلوب کا لہذا دیکھنے محسوس کرنے کے بغیر
#
# 0.Transcribed:اکا اہ انے اسسن
# 0.LMCorrected:اکا اس نے احسن
#
# 0.GroundTruth:انيس سو پچانوے
#
# 0.Transcribed:ن سپار
# 0.LMCorrected:ن پر
#
# 0.GroundTruth:نوے
#
# 0.Transcribed:تا یدو
# 0.LMCorrected:تا دو
# SHUFFLING as reached end of data
#
# 0.GroundTruth:دو ہزار بیس
#
# 0.Transcribed:ا ہاس
# 0.LMCorrected:ا اس
#
# 0.GroundTruth:سینتیس
#
# 0.Transcribed: اساننیس
# 0.LMCorrected:اساننیس
# ########################################################
# Completed Validation Test: WER & LER results
# Test WER average is   : 1.0902530278728864
# Test LER average is   : 16.359513274336283
# Test normalised LER is: 0.811423457387682
# ########################################################
